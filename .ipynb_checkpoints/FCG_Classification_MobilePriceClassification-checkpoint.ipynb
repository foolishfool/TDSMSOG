# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])
dataread.label_encoding(csv,"blue")
dataread.label_encoding(csv,"dual_sim")
dataread.label_encoding(csv,"fc")
dataread.label_encoding(csv,"four_g")
dataread.label_encoding(csv,"mobile_wt")
dataread.label_encoding(csv,"n_cores")
dataread.label_encoding(csv,"sc_h")
dataread.label_encoding(csv,"sc_w")
dataread.label_encoding(csv,"talk_time")
dataread.label_encoding(csv,"three_g")
dataread.label_encoding(csv,"touch_screen")
dataread.label_encoding(csv,"wifi")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"price_range")
# Out:
# continuous_feature_num 8
# discrete_feature_num 12
# self.data_discrete_indexes ['blue', 'dual_sim', 'fc', 'four_g', 'm_dep', 'n_cores', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
import experiment
scope_num = 50
topology_ratio = 0.5

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 2, choosen_index268
# key 1, choosen_index356
# key 0, choosen_index1209
# key 3, choosen_index42
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24949139909678475
# precision_score_fcg 0.23106031560252882
# f1_score_fcg 0.2124998212426814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 2, choosen_index1363
# key 1, choosen_index259
# key 0, choosen_index71
# key 3, choosen_index1308
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24949139909678475
# precision_score_fcg 0.23106031560252882
# f1_score_fcg 0.2124998212426814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 2, choosen_index518
# key 1, choosen_index440
# key 0, choosen_index514
# key 3, choosen_index711
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.2304845448832743
# precision_score_fcg 0.2511583923114239
# f1_score_fcg 0.21373101339558961
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 2, choosen_index1063
# key 1, choosen_index1221
# key 0, choosen_index36
# key 3, choosen_index442
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.2633333333333333
# recall_score_fcg 0.26370953553835325
# precision_score_fcg 0.24225651087776268
# f1_score_fcg 0.22773214584397883
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 2, choosen_index1009
# key 1, choosen_index358
# key 0, choosen_index841
# key 3, choosen_index874
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.241493314805597
# precision_score_fcg 0.23224409778660693
# f1_score_fcg 0.21040065765299337
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 2, choosen_index832
# key 1, choosen_index508
# key 0, choosen_index487
# key 3, choosen_index125
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.29333333333333333
# recall_score_fcg 0.29369575416373445
# precision_score_fcg 0.31394700901727074
# f1_score_fcg 0.27007704536613103
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 2, choosen_index469
# key 1, choosen_index1385
# key 0, choosen_index351
# key 3, choosen_index506
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.21333333333333335
# recall_score_fcg 0.20502125611949293
# precision_score_fcg 0.1950482562868517
# f1_score_fcg 0.18001499775699895
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 2, choosen_index1360
# key 1, choosen_index1027
# key 0, choosen_index71
# key 3, choosen_index576
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25166666666666665
# recall_score_fcg 0.25706150030800096
# precision_score_fcg 0.2623240277569825
# f1_score_fcg 0.22338248464250726
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 2, choosen_index30
# key 1, choosen_index124
# key 0, choosen_index885
# key 3, choosen_index101
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25
# recall_score_fcg 0.25221957369995934
# precision_score_fcg 0.22749692475481686
# f1_score_fcg 0.21435371442297158
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 2, choosen_index241
# key 1, choosen_index1177
# key 0, choosen_index265
# key 3, choosen_index1195
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.2304845448832743
# precision_score_fcg 0.2511583923114239
# f1_score_fcg 0.21373101339558961
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 2, choosen_index1101
# key 1, choosen_index964
# key 0, choosen_index767
# key 3, choosen_index373
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25
# recall_score_fcg 0.25221957369995934
# precision_score_fcg 0.22749692475481686
# f1_score_fcg 0.21435371442297158
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 2, choosen_index456
# key 1, choosen_index1340
# key 0, choosen_index210
# key 3, choosen_index116
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25630584901468295
# precision_score_fcg 0.26517951053887756
# f1_score_fcg 0.22724198455905528
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 2, choosen_index979
# key 1, choosen_index1153
# key 0, choosen_index1306
# key 3, choosen_index116
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.29333333333333333
# recall_score_fcg 0.29369575416373445
# precision_score_fcg 0.31394700901727074
# f1_score_fcg 0.27007704536613103
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 2, choosen_index1197
# key 1, choosen_index319
# key 0, choosen_index1256
# key 3, choosen_index578
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24949139909678475
# precision_score_fcg 0.23106031560252882
# f1_score_fcg 0.2124998212426814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 2, choosen_index39
# key 1, choosen_index927
# key 0, choosen_index611
# key 3, choosen_index189
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24506069669247008
# precision_score_fcg 0.22026556978953926
# f1_score_fcg 0.208758293521762
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 2, choosen_index295
# key 1, choosen_index704
# key 0, choosen_index459
# key 3, choosen_index808
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.28296144361865855
# precision_score_fcg 0.29633194011242986
# f1_score_fcg 0.2528391140285758
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 2, choosen_index323
# key 1, choosen_index27
# key 0, choosen_index885
# key 3, choosen_index290
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.2513455315543655
# precision_score_fcg 0.2671278187168395
# f1_score_fcg 0.226184257957681
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 2, choosen_index44
# key 1, choosen_index1192
# key 0, choosen_index330
# key 3, choosen_index24
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25630584901468295
# precision_score_fcg 0.26517951053887756
# f1_score_fcg 0.22724198455905528
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 2, choosen_index918
# key 1, choosen_index1071
# key 0, choosen_index717
# key 3, choosen_index846
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.28296144361865855
# precision_score_fcg 0.29633194011242986
# f1_score_fcg 0.2528391140285758
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 2, choosen_index513
# key 1, choosen_index785
# key 0, choosen_index1339
# key 3, choosen_index581
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.275
# recall_score_fcg 0.2799236767877883
# precision_score_fcg 0.2955674141185461
# f1_score_fcg 0.25179767704026207
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 2, choosen_index646
# key 1, choosen_index1372
# key 0, choosen_index988
# key 3, choosen_index874
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24506069669247008
# precision_score_fcg 0.22026556978953926
# f1_score_fcg 0.208758293521762
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 2, choosen_index737
# key 1, choosen_index1149
# key 0, choosen_index1222
# key 3, choosen_index121
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23345234400180032
# precision_score_fcg 0.242281394846721
# f1_score_fcg 0.20335090571891618
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 2, choosen_index212
# key 1, choosen_index706
# key 0, choosen_index1266
# key 3, choosen_index786
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.235
# recall_score_fcg 0.2384126614621178
# precision_score_fcg 0.24033308666875908
# f1_score_fcg 0.20440863232029047
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 2, choosen_index850
# key 1, choosen_index247
# key 0, choosen_index1301
# key 3, choosen_index290
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.235
# recall_score_fcg 0.2384126614621178
# precision_score_fcg 0.24033308666875908
# f1_score_fcg 0.20440863232029047
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 2, choosen_index344
# key 1, choosen_index419
# key 0, choosen_index1001
# key 3, choosen_index439
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24506069669247008
# precision_score_fcg 0.22026556978953926
# f1_score_fcg 0.208758293521762
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 2, choosen_index559
# key 1, choosen_index1078
# key 0, choosen_index592
# key 3, choosen_index50
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.28296144361865855
# precision_score_fcg 0.29633194011242986
# f1_score_fcg 0.2528391140285758
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 2, choosen_index877
# key 1, choosen_index489
# key 0, choosen_index1266
# key 3, choosen_index354
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.2633333333333333
# recall_score_fcg 0.26370953553835325
# precision_score_fcg 0.24225651087776268
# f1_score_fcg 0.22773214584397883
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 2, choosen_index423
# key 1, choosen_index418
# key 0, choosen_index1001
# key 3, choosen_index78
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23345234400180032
# precision_score_fcg 0.242281394846721
# f1_score_fcg 0.20335090571891618
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 2, choosen_index392
# key 1, choosen_index856
# key 0, choosen_index1060
# key 3, choosen_index1195
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.24918180686908908
# precision_score_fcg 0.2267323987609331
# f1_score_fcg 0.21331227743465783
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 2, choosen_index256
# key 1, choosen_index231
# key 0, choosen_index807
# key 3, choosen_index366
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24949139909678475
# precision_score_fcg 0.23106031560252882
# f1_score_fcg 0.2124998212426814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 31
# key 2, choosen_index2
# key 1, choosen_index292
# key 0, choosen_index674
# key 3, choosen_index16
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.2633333333333333
# recall_score_fcg 0.26370953553835325
# precision_score_fcg 0.24225651087776268
# f1_score_fcg 0.22773214584397883
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 32
# key 2, choosen_index37
# key 1, choosen_index275
# key 0, choosen_index973
# key 3, choosen_index1287
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.2304845448832743
# precision_score_fcg 0.2511583923114239
# f1_score_fcg 0.21373101339558961
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 33
# key 2, choosen_index186
# key 1, choosen_index914
# key 0, choosen_index827
# key 3, choosen_index1043
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.2633333333333333
# recall_score_fcg 0.2563844881939319
# precision_score_fcg 0.2851663046668712
# f1_score_fcg 0.24318764278165814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 34
# key 2, choosen_index737
# key 1, choosen_index1148
# key 0, choosen_index837
# key 3, choosen_index1193
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25166666666666665
# recall_score_fcg 0.25706150030800096
# precision_score_fcg 0.2623240277569825
# f1_score_fcg 0.22338248464250726
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 35
# key 2, choosen_index134
# key 1, choosen_index947
# key 0, choosen_index1294
# key 3, choosen_index525
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25630584901468295
# precision_score_fcg 0.26517951053887756
# f1_score_fcg 0.22724198455905528
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 36
# key 2, choosen_index1108
# key 1, choosen_index626
# key 0, choosen_index1383
# key 3, choosen_index1300
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23166666666666666
# recall_score_fcg 0.22336050273768043
# precision_score_fcg 0.2127112805334794
# f1_score_fcg 0.1998013062711922
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 37
# key 2, choosen_index1024
# key 1, choosen_index866
# key 0, choosen_index1249
# key 3, choosen_index526
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23666666666666666
# recall_score_fcg 0.237372204628978
# precision_score_fcg 0.22577726881521315
# f1_score_fcg 0.20584667374009757
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 38
# key 2, choosen_index798
# key 1, choosen_index825
# key 0, choosen_index1328
# key 3, choosen_index907
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25630584901468295
# precision_score_fcg 0.26517951053887756
# f1_score_fcg 0.22724198455905528
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 39
# key 2, choosen_index952
# key 1, choosen_index458
# key 0, choosen_index1299
# key 3, choosen_index1303
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.241493314805597
# precision_score_fcg 0.23224409778660693
# f1_score_fcg 0.21040065765299337
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 40
# key 2, choosen_index1336
# key 1, choosen_index891
# key 0, choosen_index534
# key 3, choosen_index495
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.2633333333333333
# recall_score_fcg 0.2563844881939319
# precision_score_fcg 0.2851663046668712
# f1_score_fcg 0.24318764278165814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 41
# key 2, choosen_index950
# key 1, choosen_index656
# key 0, choosen_index409
# key 3, choosen_index558
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25
# recall_score_fcg 0.25221957369995934
# precision_score_fcg 0.22749692475481686
# f1_score_fcg 0.21435371442297158
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 42
# key 2, choosen_index218
# key 1, choosen_index440
# key 0, choosen_index987
# key 3, choosen_index135
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.29333333333333333
# recall_score_fcg 0.29369575416373445
# precision_score_fcg 0.31394700901727074
# f1_score_fcg 0.27007704536613103
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 43
# key 2, choosen_index723
# key 1, choosen_index904
# key 0, choosen_index169
# key 3, choosen_index911
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.235
# recall_score_fcg 0.2384126614621178
# precision_score_fcg 0.24033308666875908
# f1_score_fcg 0.20440863232029047
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 44
# key 2, choosen_index666
# key 1, choosen_index964
# key 0, choosen_index1032
# key 3, choosen_index511
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25
# recall_score_fcg 0.25221957369995934
# precision_score_fcg 0.22749692475481686
# f1_score_fcg 0.21435371442297158
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 45
# key 2, choosen_index1036
# key 1, choosen_index1158
# key 0, choosen_index571
# key 3, choosen_index255
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.21333333333333335
# recall_score_fcg 0.20502125611949293
# precision_score_fcg 0.1950482562868517
# f1_score_fcg 0.18001499775699895
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 46
# key 2, choosen_index806
# key 1, choosen_index1134
# key 0, choosen_index502
# key 3, choosen_index808
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.21333333333333335
# recall_score_fcg 0.20502125611949293
# precision_score_fcg 0.1950482562868517
# f1_score_fcg 0.18001499775699895
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 47
# key 2, choosen_index1211
# key 1, choosen_index79
# key 0, choosen_index605
# key 3, choosen_index1391
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25630584901468295
# precision_score_fcg 0.26517951053887756
# f1_score_fcg 0.22724198455905528
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 48
# key 2, choosen_index449
# key 1, choosen_index1372
# key 0, choosen_index1020
# key 3, choosen_index149
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23345234400180032
# precision_score_fcg 0.242281394846721
# f1_score_fcg 0.20335090571891618
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 49
# key 2, choosen_index1034
# key 1, choosen_index292
# key 0, choosen_index827
# key 3, choosen_index1017
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.275
# recall_score_fcg 0.2799236767877883
# precision_score_fcg 0.2955674141185461
# f1_score_fcg 0.25179767704026207
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 50
# key 2, choosen_index854
# key 1, choosen_index1079
# key 0, choosen_index981
# key 3, choosen_index1135
# accuracy_score_baseline 0.295
# recall_score_baseline 0.2926789278228813
# precision_score_baseline 0.29345101077514735
# f1_score_baseline 0.29078998941982925
# accuracy_score_fcg 0.25166666666666665
# recall_score_fcg 0.25706150030800096
# precision_score_fcg 0.2623240277569825
# f1_score_fcg 0.22338248464250726
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.295
# all_recall_score_baseline mean 0.2926789278228813
# all_precision_score_baseline mean 0.29345101077514735
# all_f1_score_baseline mean 0.2907899894198293
# all_accuracy_score_fcg mean 0.2504
# all_recall_score_fcg mean 0.2510963070397769
# all_precision_score_fcg mean 0.2502053895419501
# all_f1_score_fcg mean 0.22104848867191187
# len plot_unit 50  len (all_test_score_baseline_accuracy) 50
# Accuracy Score T-Test
#                       Variable      N    Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline   50.0  0.2950  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg   50.0  0.2504  0.018858  0.002667   0.245041
# 2                     combined  100.0  0.2727  0.026045  0.002604   0.267532
#
#    Interval
# 0       NaN
# 1  0.255759
# 2  0.277868
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0446
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   16.7235
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    3.3447
# 7                                       Hedge's g =    3.3190
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8605
# Recall Score T-Test
#                     Variable      N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline   50.0  0.292679  0.000000  0.000000        NaN
# 1       all_recall_score_fcg   50.0  0.251096  0.020829  0.002946   0.245177
# 2                   combined  100.0  0.271888  0.025522  0.002552   0.266823
#
#    Interval
# 0       NaN
# 1  0.257016
# 2  0.276952
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0416
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   14.1166
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.8233
# 7                                       Hedge's g =    2.8017
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8187
# Precision Score T-Test
#                        Variable      N      Mean        SD        SE  \
# 0  all_precision_score_baseline   50.0  0.293451  0.000000  0.000000
# 1       all_precision_score_fcg   50.0  0.250205  0.030705  0.004342
# 2                      combined  100.0  0.271828  0.030642  0.003064
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.241479  0.258932
# 2   0.265748  0.277908
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.0432
# 1                              Degrees of freedom =   98.0000
# 2                                               t =    9.9591
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    1.9918
# 7                                       Hedge's g =    1.9765
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7092
# F1 Score T-Test
#                 Variable      N      Mean            SD            SE  \
# 0  all_f1_score_baseline   50.0  0.290790  5.607473e-17  7.930164e-18
# 1       all_f1_score_fcg   50.0  0.221048  2.136142e-02  3.020961e-03
# 2               combined  100.0  0.255919  3.813269e-02  3.813269e-03
#
#    95% Conf.  Interval
# 0   0.290790  0.290790
# 1   0.214978  0.227119
# 2   0.248353  0.263486
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  6.970000e-02
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =   2.308590e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   4.617200e+00
# 7                                       Hedge's g =   4.581700e+00
# 8                                  Glass's delta1 =   1.243724e+15
# 9                                Point-Biserial r =   9.191000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
