# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 import experiment
#       7 warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# ----> 8 dataread = dataset_read.DATAREAD()
#
# NameError: name 'dataset_read' is not defined

# %%
csv = pd.read_csv("bi.csv")


dataread.label_encoding(csv,"fNAME")
dataread.label_encoding(csv,"lNAME")
dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"country")
dataread.label_encoding(csv,"residence")
dataread.label_encoding(csv,"prevEducation")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"prevEducation")

# %%
import experiment
class_num= 3
dim_num = 10
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 6
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 33
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# best purity baseline  0.5217391304347826
# best ari  baseline 0.0007254554247944543
# best nmi  baseline0.26082149889469514
# best purity proposed 0.6521739130434783
# best ari proposed  0.1904
# best nmi proposed 0.44717247614830785
# all_purity_score_baseline mean 0.5217391304347826
# all_ari_score_ba seline mean 0.0007254554247944543
# all_nmi_score_baseline mean 0.26082149889469514
# all_purity_score_tdsmsog mean 0.552536231884058
# all_ari_score_tdsmsog mean 0.045426669089692555
# all_nmi_score_tdsmsog mean 0.3393411766385232
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  24.0  0.521739  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  24.0  0.552536  0.048786  0.009958   0.531936
# 2                   combined  48.0  0.537138  0.037508  0.005414   0.526246
#
#    Interval
# 0       NaN
# 1  0.573137
# 2  0.548029
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0308
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -3.0926
# 3                           Two side test p value =    0.0034
# 4                          Difference < 0 p value =    0.0017
# 5                          Difference > 0 p value =    0.9983
# 6                                       Cohen's d =   -0.8927
# 7                                       Hedge's g =   -0.8781
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.4149
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  24.0  0.000725  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  24.0  0.045427  0.069977  0.014284   0.015878
# 2                combined  48.0  0.023076  0.053912  0.007782   0.007422
#
#    Interval
# 0       NaN
# 1  0.074975
# 2  0.038730
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.0447
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -3.1295
# 3                           Two side test p value =    0.0030
# 4                          Difference < 0 p value =    0.0015
# 5                          Difference > 0 p value =    0.9985
# 6                                       Cohen's d =   -0.9034
# 7                                       Hedge's g =   -0.8886
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.4190
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  24.0  0.260821  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  24.0  0.339341  0.061629  0.012580   0.313318
# 2                combined  48.0  0.300081  0.058590  0.008457   0.283069
#
#    Interval
# 0       NaN
# 1  0.365365
# 2  0.317094
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0785
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -6.2417
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.8018
# 7                                       Hedge's g =   -1.7723
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.6772
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment
class_num= 3
dim_num = 10
scope_num = 100
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
# initila self.weigts shape (3, 10)
#  NO Error Data, Finish Training!
# total split_number 5
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# initila self.weigts shape (3, 10)
# ***************************SOG ************************
# initila self.weigts shape (3, 30)
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 8
# initila self.weigts shape (8, 10)
# ***************************SOG ************************
# initila self.weigts shape (8, 80)
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 13
# initila self.weigts shape (13, 10)
# ***************************SOG ************************
# initila self.weigts shape (13, 130)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# initila self.weigts shape (18, 10)
# ***************************SOG ************************
# initila self.weigts shape (18, 180)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 23
# initila self.weigts shape (23, 10)
# ***************************SOG ************************
# initila self.weigts shape (23, 230)
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 28
# initila self.weigts shape (28, 10)
# ***************************SOG ************************
# initila self.weigts shape (28, 280)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 33
# initila self.weigts shape (33, 10)
# ***************************SOG ************************
# initila self.weigts shape (33, 330)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 38
# initila self.weigts shape (38, 10)
# ***************************SOG ************************
# initila self.weigts shape (38, 380)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 43
# initila self.weigts shape (43, 10)
# ***************************SOG ************************
# initila self.weigts shape (43, 430)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 48
# initila self.weigts shape (48, 10)
# ***************************SOG ************************
# initila self.weigts shape (48, 480)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 53
# initila self.weigts shape (53, 10)
# ***************************SOG ************************
# initila self.weigts shape (53, 530)
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 58
# initila self.weigts shape (58, 10)
# ***************************SOG ************************
# initila self.weigts shape (58, 580)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 63
# initila self.weigts shape (63, 10)
# ***************************SOG ************************
# initila self.weigts shape (63, 630)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 68
# initila self.weigts shape (68, 10)
# ***************************SOG ************************
# initila self.weigts shape (68, 680)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 73
# initila self.weigts shape (73, 10)
# ***************************SOG ************************
# initila self.weigts shape (73, 730)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 78
# initila self.weigts shape (78, 10)
# ***************************SOG ************************
# initila self.weigts shape (78, 780)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 83
# initila self.weigts shape (83, 10)
# ***************************SOG ************************
# initila self.weigts shape (83, 830)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 88
# initila self.weigts shape (88, 10)
# ***************************SOG ************************
# initila self.weigts shape (88, 880)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 93
# initila self.weigts shape (93, 10)
# ***************************SOG ************************
# initila self.weigts shape (93, 930)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 98
# initila self.weigts shape (98, 10)
# ***************************SOG ************************
# initila self.weigts shape (98, 980)
#  NO Error Data, Finish Training!
# total split_number 2
# all_purity_score_baseline mean 0.5217391304347827
# all_ari_score_baseline mean 0.05253882586187906
# all_nmi_score_baseline mean 0.4562802794393871
# all_purity_score_tdsmsog mean 0.5108695652173914
# all_ari_score_tdsmsog mean 0.045513334203024905
# all_nmi_score_tdsmsog mean 0.3897595291668943
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  20.0  0.521739  1.139065e-16  2.547026e-17
# 1   all_purity_score_tdsmsog  20.0  0.510870  6.746692e-02  1.508606e-02
# 2                   combined  40.0  0.516304  4.741130e-02  7.496384e-03
#
#    95% Conf.  Interval
# 0   0.521739  0.521739
# 1   0.479294  0.542445
# 2   0.501141  0.531467
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  1.090000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   7.205000e-01
# 3                           Two side test p value =   4.756000e-01
# 4                          Difference < 0 p value =   7.622000e-01
# 5                          Difference > 0 p value =   2.378000e-01
# 6                                       Cohen's d =   2.278000e-01
# 7                                       Hedge's g =   2.233000e-01
# 8                                  Glass's delta1 =   9.542535e+13
# 9                                Point-Biserial r =   1.161000e-01
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  20.0  0.052539  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  20.0  0.045513  0.074598  0.016681   0.010600
# 2                combined  40.0  0.049026  0.052189  0.008252   0.032335
#
#    Interval
# 0       NaN
# 1  0.080426
# 2  0.065717
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...   0.0070
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.4212
# 3                           Two side test p value =    0.6760
# 4                          Difference < 0 p value =    0.6620
# 5                          Difference > 0 p value =    0.3380
# 6                                       Cohen's d =    0.1332
# 7                                       Hedge's g =    0.1305
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.0682
# NMI Score T-Test
#                  Variable     N     Mean            SD            SE  \
# 0  all_nmi_score_baseline  20.0  0.45628  1.139065e-16  2.547026e-17
# 1   all_nmi_score_tdsmsog  20.0  0.38976  6.666138e-02  1.490594e-02
# 2                combined  40.0  0.42302  5.744142e-02  9.082286e-03
#
#    95% Conf.  Interval
# 0   0.456280  0.456280
# 1   0.358561  0.420958
# 2   0.404649  0.441391
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  6.650000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   4.462700e+00
# 3                           Two side test p value =   1.000000e-04
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.411200e+00
# 7                                       Hedge's g =   1.383200e+00
# 8                                  Glass's delta1 =   5.839944e+14
# 9                                Point-Biserial r =   5.864000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
class_num= 3
dim_num = 10
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 6
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 33
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# best purity baseline  0.5217391304347826
# best ari  baseline 0
# best nmi  baseline0.28077759881874464
# best purity proposed 0.6521739130434783
# best ari proposed  0.2536873156342183
# best nmi proposed 0.46121872094797933
# all_purity_score_baseline mean 0.5217391304347826
# all_ari_score_ba seline mean -0.04834254143646408
# all_nmi_score_baseline mean 0.28077759881874464
# all_purity_score_tdsmsog mean 0.5797101449275363
# all_ari_score_tdsmsog mean 0.08168056789536095
# all_nmi_score_tdsmsog mean 0.3601726650411541
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  24.0  0.521739  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  24.0  0.579710  0.037744  0.007704   0.563772
# 2                   combined  48.0  0.550725  0.039436  0.005692   0.539274
#
#    Interval
# 0       NaN
# 1  0.595648
# 2  0.562176
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0580
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -7.5243
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.1721
# 7                                       Hedge's g =   -2.1365
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7428
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  24.0 -0.048343  7.088135e-18  1.446859e-18
# 1   all_ari_score_tdsmsog  24.0  0.081681  6.650769e-02  1.357583e-02
# 2                combined  48.0  0.016669  8.050471e-02  1.161985e-02
#
#    95% Conf.  Interval
# 0  -0.048343 -0.048343
# 1   0.053597  0.109764
# 2  -0.006707  0.040045
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -1.300000e-01
# 1                              Degrees of freedom =   4.600000e+01
# 2                                               t =  -9.577500e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.764800e+00
# 7                                       Hedge's g =  -2.719500e+00
# 8                                  Glass's delta1 =  -1.834377e+16
# 9                                Point-Biserial r =  -8.161000e-01
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  24.0  0.280778  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  24.0  0.360173  0.051885  0.010591   0.338264
# 2                combined  48.0  0.320475  0.054100  0.007809   0.304766
#
#    Interval
# 0       NaN
# 1  0.382082
# 2  0.336184
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0794
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -7.4965
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.1641
# 7                                       Hedge's g =   -2.1286
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7415
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
