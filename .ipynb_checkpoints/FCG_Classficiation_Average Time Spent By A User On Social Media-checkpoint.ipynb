# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# continuous_feature_num 2
# discrete_feature_num 9
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 2, choosen_index199
# key 8, choosen_index230
# key 5, choosen_index400
# key 1, choosen_index165
# key 7, choosen_index347
# key 6, choosen_index491
# key 9, choosen_index84
# key 3, choosen_index121
# key 4, choosen_index449
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11
# recall_score_fcg 0.10835467951937963
# precision_score_fcg 0.1020553841672453
# f1_score_fcg 0.10091780919962236
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 2, choosen_index443
# key 8, choosen_index431
# key 5, choosen_index355
# key 1, choosen_index179
# key 7, choosen_index204
# key 6, choosen_index634
# key 9, choosen_index242
# key 3, choosen_index474
# key 4, choosen_index139
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.09666666666666666
# recall_score_fcg 0.09706009144149202
# precision_score_fcg 0.1040290896998214
# f1_score_fcg 0.0970554352032454
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 2, choosen_index156
# key 8, choosen_index181
# key 5, choosen_index302
# key 1, choosen_index179
# key 7, choosen_index693
# key 6, choosen_index90
# key 9, choosen_index106
# key 3, choosen_index217
# key 4, choosen_index318
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.12
# recall_score_fcg 0.12149512726936086
# precision_score_fcg 0.11302793747005538
# f1_score_fcg 0.10877875260930457
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 2, choosen_index643
# key 8, choosen_index62
# key 5, choosen_index400
# key 1, choosen_index99
# key 7, choosen_index435
# key 6, choosen_index304
# key 9, choosen_index37
# key 3, choosen_index154
# key 4, choosen_index221
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11
# recall_score_fcg 0.11008364369639703
# precision_score_fcg 0.10917909251242586
# f1_score_fcg 0.10752706141697949
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 2, choosen_index281
# key 8, choosen_index582
# key 5, choosen_index188
# key 1, choosen_index102
# key 7, choosen_index521
# key 6, choosen_index90
# key 9, choosen_index285
# key 3, choosen_index696
# key 4, choosen_index28
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.12659114622393206
# precision_score_fcg 0.12332710764769013
# f1_score_fcg 0.118735493924466
# Experiment number: 6
# key 2, choosen_index676
# key 8, choosen_index218
# key 5, choosen_index298
# key 1, choosen_index479
# key 7, choosen_index620
# key 6, choosen_index634
# key 9, choosen_index10
# key 3, choosen_index654
# key 4, choosen_index501
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.14
# recall_score_fcg 0.14043977713192246
# precision_score_fcg 0.134811570434063
# f1_score_fcg 0.1341961725716277
# Experiment number: 7
# key 2, choosen_index133
# key 8, choosen_index352
# key 5, choosen_index543
# key 1, choosen_index134
# key 7, choosen_index40
# key 6, choosen_index591
# key 9, choosen_index683
# key 3, choosen_index545
# key 4, choosen_index450
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.12424221884810367
# precision_score_fcg 0.13548009767331426
# f1_score_fcg 0.12427397140810974
# Experiment number: 8
# key 2, choosen_index317
# key 8, choosen_index447
# key 5, choosen_index249
# key 1, choosen_index384
# key 7, choosen_index422
# key 6, choosen_index580
# key 9, choosen_index442
# key 3, choosen_index680
# key 4, choosen_index633
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11666666666666667
# recall_score_fcg 0.12459055765096433
# precision_score_fcg 0.10405608302262083
# f1_score_fcg 0.10911457257389211
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 2, choosen_index160
# key 8, choosen_index388
# key 5, choosen_index596
# key 1, choosen_index342
# key 7, choosen_index171
# key 6, choosen_index555
# key 9, choosen_index106
# key 3, choosen_index362
# key 4, choosen_index357
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.08666666666666667
# recall_score_fcg 0.0888692736073341
# precision_score_fcg 0.08464092915683476
# f1_score_fcg 0.08580915526850932
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 2, choosen_index378
# key 8, choosen_index130
# key 5, choosen_index566
# key 1, choosen_index292
# key 7, choosen_index244
# key 6, choosen_index219
# key 9, choosen_index12
# key 3, choosen_index636
# key 4, choosen_index589
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.09333333333333334
# recall_score_fcg 0.09395511709028999
# precision_score_fcg 0.09779057439193675
# f1_score_fcg 0.09197116191546789
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 2, choosen_index6
# key 8, choosen_index109
# key 5, choosen_index166
# key 1, choosen_index649
# key 7, choosen_index343
# key 6, choosen_index54
# key 9, choosen_index321
# key 3, choosen_index617
# key 4, choosen_index589
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.14333333333333334
# recall_score_fcg 0.14732571493226765
# precision_score_fcg 0.14279049028791033
# f1_score_fcg 0.13604522758277648
# Experiment number: 12
# key 2, choosen_index132
# key 8, choosen_index333
# key 5, choosen_index312
# key 1, choosen_index75
# key 7, choosen_index397
# key 6, choosen_index609
# key 9, choosen_index49
# key 3, choosen_index672
# key 4, choosen_index275
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11
# recall_score_fcg 0.1079520566286509
# precision_score_fcg 0.11089616402116402
# f1_score_fcg 0.10119675650256703
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 2, choosen_index409
# key 8, choosen_index585
# key 5, choosen_index232
# key 1, choosen_index96
# key 7, choosen_index66
# key 6, choosen_index270
# key 9, choosen_index47
# key 3, choosen_index651
# key 4, choosen_index681
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.10333333333333333
# recall_score_fcg 0.10046225020550535
# precision_score_fcg 0.10184678127125892
# f1_score_fcg 0.0981668644686747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 2, choosen_index78
# key 8, choosen_index582
# key 5, choosen_index638
# key 1, choosen_index342
# key 7, choosen_index675
# key 6, choosen_index483
# key 9, choosen_index106
# key 3, choosen_index520
# key 4, choosen_index577
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.14666666666666667
# recall_score_fcg 0.14061913297543419
# precision_score_fcg 0.14371178842373034
# f1_score_fcg 0.1402720592496923
# Experiment number: 15
# key 2, choosen_index629
# key 8, choosen_index380
# key 5, choosen_index209
# key 1, choosen_index479
# key 7, choosen_index403
# key 6, choosen_index25
# key 9, choosen_index513
# key 3, choosen_index689
# key 4, choosen_index530
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11
# recall_score_fcg 0.11160820953930586
# precision_score_fcg 0.0968341700584374
# f1_score_fcg 0.10034276928057276
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 2, choosen_index132
# key 8, choosen_index70
# key 5, choosen_index444
# key 1, choosen_index550
# key 7, choosen_index693
# key 6, choosen_index54
# key 9, choosen_index287
# key 3, choosen_index428
# key 4, choosen_index692
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11
# recall_score_fcg 0.11153343162951253
# precision_score_fcg 0.11738741576450622
# f1_score_fcg 0.1100706917197242
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 2, choosen_index263
# key 8, choosen_index319
# key 5, choosen_index427
# key 1, choosen_index490
# key 7, choosen_index536
# key 6, choosen_index580
# key 9, choosen_index547
# key 3, choosen_index546
# key 4, choosen_index275
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.09666666666666666
# recall_score_fcg 0.09377849448348634
# precision_score_fcg 0.09934786527923783
# f1_score_fcg 0.09292694188700662
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 2, choosen_index652
# key 8, choosen_index417
# key 5, choosen_index31
# key 1, choosen_index99
# key 7, choosen_index404
# key 6, choosen_index518
# key 9, choosen_index271
# key 3, choosen_index617
# key 4, choosen_index236
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.1
# recall_score_fcg 0.10034549867980086
# precision_score_fcg 0.10661956088595746
# f1_score_fcg 0.1018472904670501
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 2, choosen_index170
# key 8, choosen_index97
# key 5, choosen_index8
# key 1, choosen_index250
# key 7, choosen_index557
# key 6, choosen_index278
# key 9, choosen_index257
# key 3, choosen_index107
# key 4, choosen_index681
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.13
# recall_score_fcg 0.1321981119333071
# precision_score_fcg 0.1304566431603418
# f1_score_fcg 0.13055094011689114
# Experiment number: 20
# key 2, choosen_index281
# key 8, choosen_index402
# key 5, choosen_index364
# key 1, choosen_index588
# key 7, choosen_index592
# key 6, choosen_index405
# key 9, choosen_index369
# key 3, choosen_index496
# key 4, choosen_index44
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.09333333333333334
# recall_score_fcg 0.09450207254817324
# precision_score_fcg 0.09249998938223908
# f1_score_fcg 0.091089172349689
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 2, choosen_index126
# key 8, choosen_index581
# key 5, choosen_index565
# key 1, choosen_index398
# key 7, choosen_index421
# key 6, choosen_index414
# key 9, choosen_index106
# key 3, choosen_index696
# key 4, choosen_index358
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.10333333333333333
# recall_score_fcg 0.10307628790855344
# precision_score_fcg 0.0994335153289054
# f1_score_fcg 0.09910655869078862
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 2, choosen_index52
# key 8, choosen_index402
# key 5, choosen_index108
# key 1, choosen_index649
# key 7, choosen_index575
# key 6, choosen_index173
# key 9, choosen_index369
# key 3, choosen_index696
# key 4, choosen_index215
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.12821548774947164
# precision_score_fcg 0.12611292084976294
# f1_score_fcg 0.12328070404818238
# Experiment number: 23
# key 2, choosen_index13
# key 8, choosen_index417
# key 5, choosen_index410
# key 1, choosen_index250
# key 7, choosen_index297
# key 6, choosen_index200
# key 9, choosen_index389
# key 3, choosen_index103
# key 4, choosen_index234
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11333333333333333
# recall_score_fcg 0.11016403041296262
# precision_score_fcg 0.10053101821394504
# f1_score_fcg 0.10088362172573836
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 2, choosen_index629
# key 8, choosen_index143
# key 5, choosen_index108
# key 1, choosen_index493
# key 7, choosen_index301
# key 6, choosen_index64
# key 9, choosen_index10
# key 3, choosen_index320
# key 4, choosen_index485
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.11333333333333333
# recall_score_fcg 0.11543063889418957
# precision_score_fcg 0.11702277579470562
# f1_score_fcg 0.10928316194447624
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 2, choosen_index105
# key 8, choosen_index699
# key 5, choosen_index26
# key 1, choosen_index213
# key 7, choosen_index403
# key 6, choosen_index233
# key 9, choosen_index603
# key 3, choosen_index95
# key 4, choosen_index234
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12010609441110026
# precision_score_baseline 0.11949942571744573
# f1_score_baseline 0.11499827526928863
# accuracy_score_fcg 0.10666666666666667
# recall_score_fcg 0.1052637143696528
# precision_score_fcg 0.10186647790880109
# f1_score_fcg 0.10213965914594073
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 2, choosen_index282
# key 8, choosen_index538
# key 5, choosen_index303
# key 1, choosen_index560
# key 7, choosen_index237
# key 6, choosen_index64
# key 9, choosen_index119
# key 3, choosen_index690
# key 4, choosen_index208
