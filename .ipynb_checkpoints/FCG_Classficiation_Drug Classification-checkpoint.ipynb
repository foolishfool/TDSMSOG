# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("drug200.csv")
#csv = csv.drop(columns=['ID'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"BP")
dataread.label_encoding(csv,"Cholesterol")
dataread.label_encoding(csv,"Drug")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Drug")
# Out:
# continuous_feature_num 2
# discrete_feature_num 3
# self.data_discrete_indexes ['Sex', 'BP', 'Cholesterol']

# %%
#import experiment
#scope_num = 30
#topology_ratio = 2
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# y 1
# new current_loss 0.15569750874966284
# y 2
# y 3
# new current_loss 0.15569106118346368
# y 4
# new current_loss 0.15568412548477828
# y 5
# new current_loss 0.15568139018834645
# y 6
# y 7
# y 8
# y 9
# y 10
# y 11
# y 12
# y 13
# y 14
# y 15
# y 16
# y 17
# y 18
# y 19
# y 20
# y 21
# y 22
# y 23
# y 24
# y 25
# y 26
# y 27
# y 28
# y 29
# y 30
# y 31
# y 32
# y 33
# y 34
# y 35
# y 36
# y 37
# y 38
# y 39
# y 40
# y 41
# y 42
# y 43
# y 44
# y 45
# y 46
# y 47
# y 48
# y 49
# y 50
# y 51
# y 52
# y 53
# new current_loss 0.15567992888956997
# y 54
# y 55
# y 56
# y 57
# y 58
# y 59
# y 60
# y 61
# new current_loss 0.1556793178007501
# y 62
# y 63
# y 64
# y 65
# y 66
# y 67
# y 68
# y 69
# y 70
# y 71
# y 72
# y 73
# y 74
# y 75
# y 76
# y 77
# y 78
# y 79
# y 80
# y 81
# y 82
# y 83
# y 84
# y 85
# y 86
# y 87
# y 88
# y 89
# y 90
# y 91
# y 92
# y 93
# y 94
# y 95
# y 96
# y 97
# y 98
# y 99
# y 100
# Experiment number: 1
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5863247863247862
# precision_score_baseline 0.4594117647058823
# f1_score_baseline 0.43415016356192826
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 2
# accuracy_score_baseline 0.35
# recall_score_baseline 0.4593406593406593
# precision_score_baseline 0.2873529411764706
# f1_score_baseline 0.30396825396825394
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 3
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5291819291819292
# precision_score_baseline 0.33441176470588235
# f1_score_baseline 0.3616605616605616
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 4
# accuracy_score_baseline 0.18333333333333332
# recall_score_baseline 0.1763125763125763
# precision_score_baseline 0.15029411764705883
# f1_score_baseline 0.14924812030075188
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 5
# accuracy_score_baseline 0.4
# recall_score_baseline 0.48241758241758237
# precision_score_baseline 0.3401260504201681
# f1_score_baseline 0.36035437430786266
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 6
# accuracy_score_baseline 0.38333333333333336
# recall_score_baseline 0.5037851037851038
# precision_score_baseline 0.39294117647058824
# f1_score_baseline 0.40152967808515594
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 7
# accuracy_score_baseline 0.3333333333333333
# recall_score_baseline 0.2851037851037851
# precision_score_baseline 0.3311764705882353
# f1_score_baseline 0.284917102481362
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 8
# accuracy_score_baseline 0.43333333333333335
# recall_score_baseline 0.5995115995115995
# precision_score_baseline 0.4734593837535014
# f1_score_baseline 0.4305166098269546
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 9
# accuracy_score_baseline 0.2833333333333333
# recall_score_baseline 0.315995115995116
# precision_score_baseline 0.2373529411764706
# f1_score_baseline 0.25895281189398833
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 10
# accuracy_score_baseline 0.43333333333333335
# recall_score_baseline 0.5940170940170939
# precision_score_baseline 0.4734640522875817
# f1_score_baseline 0.4480437209848974
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 11
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5291819291819292
# precision_score_baseline 0.32999999999999996
# f1_score_baseline 0.36116901020126824
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 12
# accuracy_score_baseline 0.43333333333333335
# recall_score_baseline 0.5808302808302808
# precision_score_baseline 0.4447058823529412
# f1_score_baseline 0.47298683988150475
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 13
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.25
# recall_score_baseline 0.4026862026862027
# precision_score_baseline 0.26418300653594773
# f1_score_baseline 0.26519989231390495
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 14
# accuracy_score_baseline 0.18333333333333332
# recall_score_baseline 0.1763125763125763
# precision_score_baseline 0.15029411764705883
# f1_score_baseline 0.14924812030075188
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 15
# accuracy_score_baseline 0.35
# recall_score_baseline 0.48840048840048844
# precision_score_baseline 0.3978291316526611
# f1_score_baseline 0.33711001642036126
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 16
# accuracy_score_baseline 0.31666666666666665
# recall_score_baseline 0.473015873015873
# precision_score_baseline 0.2473529411764706
# f1_score_baseline 0.30162907268170425
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 17
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.4434676434676435
# precision_score_baseline 0.38735294117647057
# f1_score_baseline 0.3822021116138763
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 18
# accuracy_score_baseline 0.38333333333333336
# recall_score_baseline 0.4411477411477412
# precision_score_baseline 0.29000000000000004
# f1_score_baseline 0.3162538002921783
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 19
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.31666666666666665
# recall_score_baseline 0.44664224664224667
# precision_score_baseline 0.3723529411764706
# f1_score_baseline 0.3244454719686918
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 20
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.6126984126984127
# precision_score_baseline 0.33441176470588235
# f1_score_baseline 0.4113337642749407
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 21
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.510989010989011
# precision_score_baseline 0.32999999999999996
# f1_score_baseline 0.3682661841931071
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 22
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5291819291819292
# precision_score_baseline 0.33441176470588235
# f1_score_baseline 0.3616605616605616
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 23
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.31666666666666665
# recall_score_baseline 0.30378510378510376
# precision_score_baseline 0.3002941176470588
# f1_score_baseline 0.27249742002063987
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 24
# accuracy_score_baseline 0.43333333333333335
# recall_score_baseline 0.5940170940170939
# precision_score_baseline 0.4734640522875817
# f1_score_baseline 0.4480437209848974
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 25
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5863247863247862
# precision_score_baseline 0.4594117647058823
# f1_score_baseline 0.43415016356192826
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 26
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.5291819291819292
# precision_score_baseline 0.32999999999999996
# f1_score_baseline 0.36116901020126824
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 27
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.6126984126984127
# precision_score_baseline 0.32999999999999996
# f1_score_baseline 0.4108422128156473
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 28
# accuracy_score_baseline 0.4166666666666667
# recall_score_baseline 0.6126984126984127
# precision_score_baseline 0.32999999999999996
# f1_score_baseline 0.4108422128156473
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 29
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.35
# recall_score_baseline 0.4593406593406593
# precision_score_baseline 0.28294117647058825
# f1_score_baseline 0.3034767025089605
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# Experiment number: 30
# accuracy_score_baseline 0.43333333333333335
# recall_score_baseline 0.4247863247863248
# precision_score_baseline 0.4182352941176471
# f1_score_baseline 0.3946217940745984
# accuracy_score_fcg 0.5
# recall_score_fcg 0.6511599511599512
# precision_score_fcg 0.4984640522875817
# f1_score_fcg 0.5256194785606549
# all_accuracy_score_baseline mean 0.37166666666666653
# all_recall_score_baseline mean 0.4763125763125763
# all_precision_score_baseline mean 0.3429077186430128
# all_f1_score_baseline mean 0.3506829826619384
# all_accuracy_score_fcg mean 0.5
# all_recall_score_fcg mean 0.6511599511599511
# all_precision_score_fcg mean 0.4984640522875819
# all_f1_score_fcg mean 0.5256194785606549
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.371667  0.071405  0.013037   0.345004
# 1       all_accuracy_score_fcg  30.0  0.500000  0.000000  0.000000        NaN
# 2                     combined  60.0  0.435833  0.081812  0.010562   0.414699
#
#    Interval
# 0  0.398330
# 1       NaN
# 2  0.456968
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.1283
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -9.8440
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.5417
# 7                                       Hedge's g =   -2.5087
# 8                                  Glass's delta1 =   -1.7973
# 9                                Point-Biserial r =   -0.7909
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.476313  1.219139e-01  2.225834e-02
# 1       all_recall_score_fcg  30.0  0.651160  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.563736  1.227925e-01  1.585244e-02
#
#    95% Conf.  Interval
# 0   0.430789  0.521836
# 1   0.651160  0.651160
# 2   0.532016  0.595457
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.1748
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -7.8554
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.0282
# 7                                       Hedge's g =   -2.0019
# 8                                  Glass's delta1 =   -1.4342
# 9                                Point-Biserial r =   -0.7180
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.342908  8.627178e-02  1.575100e-02
# 1       all_precision_score_fcg  30.0  0.498464  1.693804e-16  3.092449e-17
# 2                      combined  60.0  0.420686  9.904702e-02  1.278691e-02
#
#    95% Conf.  Interval
# 0   0.310693  0.375122
# 1   0.498464  0.498464
# 2   0.395099  0.446272
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.1556
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -9.8760
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.5500
# 7                                       Hedge's g =   -2.5168
# 8                                  Glass's delta1 =   -1.8031
# 9                                Point-Biserial r =   -0.7919
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.350683  0.080451  0.014688   0.320642
# 1       all_f1_score_fcg  30.0  0.525619  0.000000  0.000000        NaN
# 2               combined  60.0  0.438151  0.104698  0.013516   0.411105
#
#    Interval
# 0  0.380724
# 1       NaN
# 2  0.465198
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.1749
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -11.9099
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.0751
# 7                                       Hedge's g =   -3.0352
# 8                                  Glass's delta1 =   -2.1744
# 9                                Point-Biserial r =   -0.8425
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
