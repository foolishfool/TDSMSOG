# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]*0.1)


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")
# Out:
# continuous_feature_num 2
# discrete_feature_num 16
# self.data_discrete_indexes ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'Qchat-10-Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD', 'Who completed the test']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 1, choosen_index495
# key 0, choosen_index672
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 2
# key 1, choosen_index402
# key 0, choosen_index91
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 3
# key 1, choosen_index400
# key 0, choosen_index347
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 4
# key 1, choosen_index388
# key 0, choosen_index546
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 5
# key 1, choosen_index41
# key 0, choosen_index439
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 6
# key 1, choosen_index201
# key 0, choosen_index626
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 7
# key 1, choosen_index518
# key 0, choosen_index168
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 8
# key 1, choosen_index335
# key 0, choosen_index439
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 9
# key 1, choosen_index145
# key 0, choosen_index507
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 10
# key 1, choosen_index364
# key 0, choosen_index318
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 11
# key 1, choosen_index488
# key 0, choosen_index243
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 12
# key 1, choosen_index483
# key 0, choosen_index46
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 13
# key 1, choosen_index159
# key 0, choosen_index4
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 14
# key 1, choosen_index234
# key 0, choosen_index519
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 15
# key 1, choosen_index416
# key 0, choosen_index301
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 16
# key 1, choosen_index701
# key 0, choosen_index382
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 17
# key 1, choosen_index356
# key 0, choosen_index626
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 18
# key 1, choosen_index711
# key 0, choosen_index324
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 19
# key 1, choosen_index191
# key 0, choosen_index466
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 20
# key 1, choosen_index551
# key 0, choosen_index151
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 21
# key 1, choosen_index572
# key 0, choosen_index365
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 22
# key 1, choosen_index162
# key 0, choosen_index508
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 23
# key 1, choosen_index718
# key 0, choosen_index4
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 24
# key 1, choosen_index288
# key 0, choosen_index67
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 25
# key 1, choosen_index460
# key 0, choosen_index501
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 26
# key 1, choosen_index453
# key 0, choosen_index455
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 27
# key 1, choosen_index180
# key 0, choosen_index662
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 28
# key 1, choosen_index643
# key 0, choosen_index329
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 29
# key 1, choosen_index483
# key 0, choosen_index559
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 30
# key 1, choosen_index627
# key 0, choosen_index150
# accuracy_score_baseline 0.9746835443037974
# recall_score_baseline 0.9761111111111112
# precision_score_baseline 0.9664368650217707
# f1_score_baseline 0.9710463624702217
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# all_accuracy_score_baseline mean 0.9746835443037974
# all_recall_score_baseline mean 0.9761111111111115
# all_precision_score_baseline mean 0.9664368650217706
# all_f1_score_baseline mean 0.9710463624702218
# all_accuracy_score_fcg mean 1.0
# all_recall_score_fcg mean 1.0
# all_precision_score_fcg mean 1.0
# all_f1_score_fcg mean 1.0
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.974684  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  30.0  1.000000  0.000000  0.000000        NaN
# 2                     combined  60.0  0.987342  0.012765  0.001648   0.984044
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.990639
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0253
# 1                              Degrees of freedom =   58.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.976111  3.387608e-16  6.184897e-17
# 1       all_recall_score_fcg  30.0  1.000000  0.000000e+00  0.000000e+00
# 2                   combined  60.0  0.988056  1.204524e-02  1.555034e-03
#
#    95% Conf.  Interval
# 0   0.976111  0.976111
# 1        NaN       NaN
# 2   0.984944  0.991167
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -2.390000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.862455e+14
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -9.972817e+13
# 7                                       Hedge's g =  -9.843300e+13
# 8                                  Glass's delta1 =  -7.051846e+13
# 9                                Point-Biserial r =  -1.000000e+00
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.966437  1.129203e-16  2.061632e-17
# 1       all_precision_score_fcg  30.0  1.000000  0.000000e+00  0.000000e+00
# 2                      combined  60.0  0.983218  1.692319e-02  2.184774e-03
#
#    95% Conf.  Interval
# 0   0.966437  0.966437
# 1        NaN       NaN
# 2   0.978847  0.987590
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -3.360000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.627988e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.203448e+14
# 7                                       Hedge's g =  -4.148858e+14
# 8                                  Glass's delta1 =  -2.972286e+14
# 9                                Point-Biserial r =  -1.000000e+00
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.971046  1.129203e-16  2.061632e-17
# 1       all_f1_score_fcg  30.0  1.000000  0.000000e+00  0.000000e+00
# 2               combined  60.0  0.985523  1.459899e-02  1.884721e-03
#
#    95% Conf.  Interval
# 0   0.971046  0.971046
# 1        NaN       NaN
# 2   0.981752  0.989294
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco... -2.900000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.404403e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.626154e+14
# 7                                       Hedge's g =  -3.579061e+14
# 8                                  Glass's delta1 =  -2.564078e+14
# 9                                Point-Biserial r =  -1.000000e+00
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
