# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv = csv.sample(int(csv.shape[0]*0.01))


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
csv_training = csv
dataread.initializedataset(csv,csv_training,csv_test,"General_Health")
# Out:
# continuous_feature_num 7
# discrete_feature_num 11
# self.data_discrete_indexes ['Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
import experiment
scope_num = 30
topology_ratio =6

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 0, choosen_index929
# key 2, choosen_index1187
# key 4, choosen_index942
# key 3, choosen_index1518
# key 1, choosen_index1176
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.31101511879049676
# recall_score_fcg 0.25950754074198573
# precision_score_fcg 0.26819566094606684
# f1_score_fcg 0.21760899615997772
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 0, choosen_index985
# key 2, choosen_index2436
# key 4, choosen_index1728
# key 3, choosen_index2438
# key 1, choosen_index3032
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.22786177105831534
# recall_score_fcg 0.22562035989562124
# precision_score_fcg 0.25295985322675535
# f1_score_fcg 0.20745935770065344
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 0, choosen_index1234
# key 2, choosen_index2468
# key 4, choosen_index1449
# key 3, choosen_index1494
# key 1, choosen_index1905
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2958963282937365
# recall_score_fcg 0.2810056412809026
# precision_score_fcg 0.27934005537289863
# f1_score_fcg 0.23397139036464076
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 0, choosen_index447
# key 2, choosen_index1065
# key 4, choosen_index2230
# key 3, choosen_index1518
# key 1, choosen_index1526
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.31965442764578833
# recall_score_fcg 0.25826525225231045
# precision_score_fcg 0.2239070390407627
# f1_score_fcg 0.2196122111023112
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 0, choosen_index426
# key 2, choosen_index2838
# key 4, choosen_index1201
# key 3, choosen_index2269
# key 1, choosen_index1897
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.29265658747300216
# recall_score_fcg 0.2689391676848123
# precision_score_fcg 0.2181710602049039
# f1_score_fcg 0.19908201422061383
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 0, choosen_index384
# key 2, choosen_index1755
# key 4, choosen_index1144
# key 3, choosen_index1479
# key 1, choosen_index705
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.19870410367170627
# recall_score_fcg 0.17512267523417352
# precision_score_fcg 0.1571581296569525
# f1_score_fcg 0.15119774661762653
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 0, choosen_index1986
# key 2, choosen_index1987
# key 4, choosen_index1115
# key 3, choosen_index1706
# key 1, choosen_index1656
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.26673866090712745
# recall_score_fcg 0.2503333936678885
# precision_score_fcg 0.2392385517730775
# f1_score_fcg 0.2234262996138507
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 0, choosen_index2636
# key 2, choosen_index2331
# key 4, choosen_index1154
# key 3, choosen_index380
# key 1, choosen_index519
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.3304535637149028
# recall_score_fcg 0.2528807035009126
# precision_score_fcg 0.2726118578791369
# f1_score_fcg 0.24458276815140872
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 0, choosen_index531
# key 2, choosen_index2778
# key 4, choosen_index1244
# key 3, choosen_index1039
# key 1, choosen_index745
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.3002159827213823
# recall_score_fcg 0.3353317581704839
# precision_score_fcg 0.29388569677468784
# f1_score_fcg 0.2789791020103536
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 0, choosen_index2556
# key 2, choosen_index938
# key 4, choosen_index2626
# key 3, choosen_index1343
# key 1, choosen_index1307
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.24946004319654427
# recall_score_fcg 0.2839948543243715
# precision_score_fcg 0.2539531735358381
# f1_score_fcg 0.20337736975330145
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 0, choosen_index1670
# key 2, choosen_index2701
# key 4, choosen_index146
# key 3, choosen_index3015
# key 1, choosen_index672
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.31317494600431967
# recall_score_fcg 0.29643890587593924
# precision_score_fcg 0.2693707047539
# f1_score_fcg 0.2638559629883704
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 0, choosen_index950
# key 2, choosen_index284
# key 4, choosen_index12
# key 3, choosen_index537
# key 1, choosen_index1484
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2580993520518359
# recall_score_fcg 0.23902345074868717
# precision_score_fcg 0.25215002844960577
# f1_score_fcg 0.22765312080283814
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 0, choosen_index2175
# key 2, choosen_index1084
# key 4, choosen_index97
# key 3, choosen_index2334
# key 1, choosen_index2401
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.14038876889848811
# recall_score_fcg 0.14308964422005735
# precision_score_fcg 0.19277725306500498
# f1_score_fcg 0.1404070641677129
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 0, choosen_index606
# key 2, choosen_index3084
# key 4, choosen_index1930
# key 3, choosen_index1455
# key 1, choosen_index2094
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.27645788336933047
# recall_score_fcg 0.3164168600604638
# precision_score_fcg 0.23910109425227005
# f1_score_fcg 0.22790004126634286
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 0, choosen_index93
# key 2, choosen_index2242
# key 4, choosen_index224
# key 3, choosen_index1140
# key 1, choosen_index346
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.3002159827213823
# recall_score_fcg 0.2862697859631657
# precision_score_fcg 0.2596698539875959
# f1_score_fcg 0.2577041874113764
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 0, choosen_index1372
# key 2, choosen_index2922
# key 4, choosen_index2907
# key 3, choosen_index286
# key 1, choosen_index2544
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.27645788336933047
# recall_score_fcg 0.28067158393290803
# precision_score_fcg 0.22997493235421854
# f1_score_fcg 0.21129141890082148
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 0, choosen_index0
# key 2, choosen_index1029
# key 4, choosen_index175
# key 3, choosen_index600
# key 1, choosen_index1821
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.26997840172786175
# recall_score_fcg 0.3124960233063767
# precision_score_fcg 0.25570485366100315
# f1_score_fcg 0.22826452751502574
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 0, choosen_index834
# key 2, choosen_index827
# key 4, choosen_index1143
# key 3, choosen_index1116
# key 1, choosen_index2964
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.23974082073434125
# recall_score_fcg 0.3045811726020785
# precision_score_fcg 0.20992346669991893
# f1_score_fcg 0.19511927125126427
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 0, choosen_index2053
# key 2, choosen_index1931
# key 4, choosen_index1493
# key 3, choosen_index9
# key 1, choosen_index1550
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.0939524838012959
# recall_score_fcg 0.10296501242245393
# precision_score_fcg 0.17540100104500148
# f1_score_fcg 0.09502930385430722
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 0, choosen_index972
# key 2, choosen_index2276
# key 4, choosen_index731
# key 3, choosen_index1556
# key 1, choosen_index359
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2991360691144708
# recall_score_fcg 0.30047388267945757
# precision_score_fcg 0.242361061291615
# f1_score_fcg 0.21924158461412518
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 0, choosen_index72
# key 2, choosen_index2477
# key 4, choosen_index3059
# key 3, choosen_index1706
# key 1, choosen_index2398
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.22894168466522677
# recall_score_fcg 0.29263206264450664
# precision_score_fcg 0.22338187257560155
# f1_score_fcg 0.1986113087370315
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 0, choosen_index129
# key 2, choosen_index1462
# key 4, choosen_index830
# key 3, choosen_index286
# key 1, choosen_index1915
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2570194384449244
# recall_score_fcg 0.24196215515030847
# precision_score_fcg 0.20965476785899972
# f1_score_fcg 0.2102513560063901
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 0, choosen_index3018
# key 2, choosen_index1432
# key 4, choosen_index594
# key 3, choosen_index1518
# key 1, choosen_index1951
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.24946004319654427
# recall_score_fcg 0.2498125879430011
# precision_score_fcg 0.26715167130575684
# f1_score_fcg 0.21021671059167613
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 0, choosen_index1866
# key 2, choosen_index1153
# key 4, choosen_index1074
# key 3, choosen_index747
# key 1, choosen_index95
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2937365010799136
# recall_score_fcg 0.2931436220988237
# precision_score_fcg 0.23649744825834143
# f1_score_fcg 0.21598742108369207
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 0, choosen_index2267
# key 2, choosen_index818
# key 4, choosen_index762
# key 3, choosen_index2261
# key 1, choosen_index642
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.3250539956803456
# recall_score_fcg 0.25673413578291626
# precision_score_fcg 0.24806166426031112
# f1_score_fcg 0.2403276095271209
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 0, choosen_index3087
# key 2, choosen_index912
# key 4, choosen_index990
# key 3, choosen_index2342
# key 1, choosen_index2544
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2678185745140389
# recall_score_fcg 0.2431517306320691
# precision_score_fcg 0.25498600561189544
# f1_score_fcg 0.2343871508054503
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 0, choosen_index1711
# key 2, choosen_index1876
# key 4, choosen_index867
# key 3, choosen_index2717
# key 1, choosen_index811
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.234341252699784
# recall_score_fcg 0.23732871558506202
# precision_score_fcg 0.21688901305738034
# f1_score_fcg 0.16105565364929908
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 0, choosen_index2947
# key 2, choosen_index1543
# key 4, choosen_index2616
# key 3, choosen_index2402
# key 1, choosen_index2036
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.2602591792656587
# recall_score_fcg 0.2357871439991898
# precision_score_fcg 0.24591807507534041
# f1_score_fcg 0.21563972215502497
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 0, choosen_index1295
# key 2, choosen_index2061
# key 4, choosen_index2896
# key 3, choosen_index1000
# key 1, choosen_index861
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.21706263498920086
# recall_score_fcg 0.2194991046782983
# precision_score_fcg 0.23619985344582753
# f1_score_fcg 0.20633333835078038
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 0, choosen_index49
# key 2, choosen_index2188
# key 4, choosen_index500
# key 3, choosen_index896
# key 1, choosen_index203
# accuracy_score_baseline 0.5032397408207343
# recall_score_baseline 0.41867704205533973
# precision_score_baseline 0.503775400255949
# f1_score_baseline 0.4357457708428016
# accuracy_score_fcg 0.31965442764578833
# recall_score_fcg 0.27020696907207614
# precision_score_fcg 0.24028237010095407
# f1_score_fcg 0.2344329269853191
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.5032397408207345
# all_recall_score_baseline mean 0.4186770420553396
# all_precision_score_baseline mean 0.5037754002559489
# all_f1_score_baseline mean 0.43574577084280164
# all_accuracy_score_fcg mean 0.26378689704823616
# all_recall_score_fcg mean 0.25712286320504335
# all_precision_score_fcg mean 0.2388292689840541
# all_f1_score_fcg mean 0.21243356454529028
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.503240  2.258405e-16  4.123265e-17
# 1       all_accuracy_score_fcg  30.0  0.263787  5.288265e-02  9.655006e-03
# 2                     combined  60.0  0.383513  1.263011e-01  1.630540e-02
#
#    95% Conf.  Interval
# 0   0.503240  0.503240
# 1   0.244040  0.283534
# 2   0.350886  0.416140
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  2.395000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.480090e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   6.403600e+00
# 7                                       Hedge's g =   6.320400e+00
# 8                                  Glass's delta1 =   1.060274e+15
# 9                                Point-Biserial r =   9.559000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.418677  1.129203e-16  2.061632e-17
# 1       all_recall_score_fcg  30.0  0.257123  4.967698e-02  9.069734e-03
# 2                   combined  60.0  0.337900  8.859186e-02  1.143716e-02
#
#    95% Conf.  Interval
# 0   0.418677  0.418677
# 1   0.238573  0.275673
# 2   0.315014  0.360786
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re...  1.616000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.781240e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   4.599200e+00
# 7                                       Hedge's g =   4.539400e+00
# 8                                  Glass's delta1 =   1.430693e+15
# 9                                Point-Biserial r =   9.195000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.503775  1.129203e-16  2.061632e-17
# 1       all_precision_score_fcg  30.0  0.238829  3.000473e-02  5.478089e-03
# 2                      combined  60.0  0.371302  1.352371e-01  1.745903e-02
#
#    95% Conf.  Interval
# 0   0.503775  0.503775
# 1   0.227625  0.250033
# 2   0.336367  0.406238
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  2.649000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   4.836470e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.248770e+01
# 7                                       Hedge's g =   1.232550e+01
# 8                                  Glass's delta1 =   2.346312e+15
# 9                                Point-Biserial r =   9.878000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.435746  5.646013e-17  1.030816e-17
# 1       all_f1_score_fcg  30.0  0.212434  3.692420e-02  6.741405e-03
# 2               combined  60.0  0.324090  1.155359e-01  1.491562e-02
#
#    95% Conf.  Interval
# 0   0.435746  0.435746
# 1   0.198646  0.226221
# 2   0.294244  0.353936
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  2.233000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   3.312550e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   8.553000e+00
# 7                                       Hedge's g =   8.441900e+00
# 8                                  Glass's delta1 =   3.955220e+15
# 9                                Point-Biserial r =   9.746000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
