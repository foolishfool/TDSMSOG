# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# continuous_feature_num 1
# discrete_feature_num 10
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
import experiment
scope_num = 30
topology_ratio =4

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# total_num 100
# y 1 new current_loss 0.017174550493245556
# total_num 100
# y 2 new current_loss 0.017172536083058475
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# y 7 new current_loss 0.017171687783226353
# total_num 100
# y 8 new current_loss 0.017171117887328495
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# y 24 new current_loss 0.01717047322495084
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# y 59 new current_loss 0.01716995689706331
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# total_num 100
# Experiment number: 1
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 2
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 4
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 7
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 9
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 12
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 14
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 15
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 20
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 21
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 22
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 28
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Experiment number: 29
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5382205513784462
# precision_score_baseline 0.538244514106583
# f1_score_baseline 0.5382084340585549
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46177944862155385
# precision_score_baseline 0.4617554858934169
# f1_score_baseline 0.46151436849111266
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5357590404582886
# precision_score_fcg 0.53995399539954
# f1_score_fcg 0.52463133640553
# all_accuracy_score_baseline mean 0.5051282051282051
# all_recall_score_baseline mean 0.5050960735171262
# all_precision_score_baseline mean 0.5050992685475444
# all_f1_score_baseline mean 0.50497433897933
# all_accuracy_score_fcg mean 0.5384615384615384
# all_recall_score_fcg mean 0.5357590404582885
# all_precision_score_fcg mean 0.5399539953995399
# all_f1_score_fcg mean 0.5246313364055301
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.505128  0.038770  0.007078   0.490651
# 1       all_accuracy_score_fcg  30.0  0.538462  0.000000  0.000000        NaN
# 2                     combined  60.0  0.521795  0.031958  0.004126   0.513539
#
#    Interval
# 0  0.519605
# 1       NaN
# 2  0.530050
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0333
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -4.7092
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.2159
# 7                                       Hedge's g =   -1.2001
# 8                                  Glass's delta1 =   -0.8598
# 9                                Point-Biserial r =   -0.5259
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.505096  3.852685e-02  7.034007e-03
# 1       all_recall_score_fcg  30.0  0.535759  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.520428  3.112263e-02  4.017915e-03
#
#    95% Conf.  Interval
# 0   0.490710  0.519482
# 1   0.535759  0.535759
# 2   0.512388  0.528467
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0307
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -4.3592
# 3                           Two side test p value =    0.0001
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.1256
# 7                                       Hedge's g =   -1.1109
# 8                                  Glass's delta1 =   -0.7959
# 9                                Point-Biserial r =   -0.4968
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.505099  3.855100e-02  7.038418e-03
# 1       all_precision_score_fcg  30.0  0.539954  1.129203e-16  2.061632e-17
# 2                      combined  60.0  0.522527  3.223904e-02  4.162042e-03
#
#    95% Conf.  Interval
# 0   0.490704  0.519494
# 1   0.539954  0.539954
# 2   0.514198  0.530855
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0349
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -4.9521
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.2786
# 7                                       Hedge's g =   -1.2620
# 8                                  Glass's delta1 =   -0.9041
# 9                                Point-Biserial r =   -0.5451
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.504974  3.865434e-02  7.057285e-03
# 1       all_f1_score_fcg  30.0  0.524631  1.129203e-16  2.061632e-17
# 2               combined  60.0  0.514803  2.885573e-02  3.725259e-03
#
#    95% Conf.  Interval
# 0   0.490541  0.519408
# 1   0.524631  0.524631
# 2   0.507349  0.522257
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0197
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -2.7853
# 3                           Two side test p value =    0.0072
# 4                          Difference < 0 p value =    0.0036
# 5                          Difference > 0 p value =    0.9964
# 6                                       Cohen's d =   -0.7192
# 7                                       Hedge's g =   -0.7098
# 8                                  Glass's delta1 =   -0.5085
# 9                                Point-Biserial r =   -0.3435
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
