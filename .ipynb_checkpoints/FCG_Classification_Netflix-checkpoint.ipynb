248, 1249, 1252, 1253, 1256, 1258, 1261, 1262, 1263, 1266, 1267, 1272, 1274, 1276, 1280, 1284, 1286, 1289, 1293, 1297, 1299, 1302, 1306, 1308, 1310, 1314, 1316, 1319, 1320, 1322, 1323, 1326, 1331, 1333, 1337, 1340, 1342, 1344, 1347, 1348, 1350, 1352, 1355, 1356, 1357, 1359, 1361, 1363, 1365, 1368, 1369, 1370, 1373, 1374, 1378, 1381, 1383, 1386, 1389, 1390, 1392, 1394, 1397, 1398, 1400, 1401, 1402, 1406, 1409, 1411, 1413, 1415, 1417, 1420, 1422, 1425, 1426, 1429, 1430, 1433, 1435, 1443, 1444, 1446, 1448, 1451, 1453, 1455, 1456, 1460, 1464, 1466, 1469, 1471, 1473, 1476, 1477, 1480, 1481, 1483, 1485, 1487, 1490, 1494, 1496, 1497, 1499, 1503, 1505, 1508, 1511, 1514, 1518, 1520, 1522, 1526, 1527, 1530, 1531, 1532, 1534, 1536, 1538, 1540, 1542, 1545, 1547, 1548, 1549, 1551, 1552, 1553, 1556, 1561, 1564, 1566, 1569, 1573, 1574, 1575, 1579, 1581, 1582, 1584, 1587, 1589, 1590, 1593, 1595, 1597, 1599, 1601, 1603, 1606, 1610, 1615, 1617, 1619, 1621, 1623, 1624, 1626, 1627, 1628, 1630, 1631, 1634, 1637, 1642, 1644, 1645, 1652, 1655, 1657, 1659, 1661, 1663, 1664, 1666, 1668, 1669, 1672, 1676, 1678, 1682, 1684, 1687, 1690, 1693, 1696, 1697, 1701, 1703, 1705, 1706, 1707, 1709, 1712, 1713, 1715, 1717, 1718, 1721, 1723, 1725, 1727, 1729, 1730, 1734, 1736, 1739, 1741, 1744, 1746, 1749], 1: [1, 4, 8, 10, 13, 17, 20, 22, 26, 29, 33, 36, 38, 43, 45, 47, 57, 59, 62, 66, 68, 69, 78, 81, 86, 87, 89, 92, 96, 101, 103, 106, 109, 112, 115, 118, 121, 127, 130, 132, ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 topology_ratio =3
#       7 experiment = experiment.Experiment()
# ----> 8 experiment.Ttest(dataread,scope_num,topology_ratio)
#
# File C:\JupyterDoc\FCG\experiment.py:85, in Experiment.Ttest(self, dataread, scope_num, topology_ratio)
#      83 while y <= scope_num:
#      84     print("Experiment number: {}".format(y))
# ---> 85     self.InitializedExperimentDataList(
#      86                             dataread,
#      87                             all_test_score_baseline_accuracy,
#      88                             all_test_score_baseline_recall,
#      89                             all_test_score_baseline_precision,
#      90                             all_test_score_baseline_f1,
#      91                             all_test_score_fcg_accuracy,
#      92                             all_test_score_fcg_recall,
#      93                             all_test_score_fcg_precision,
#      94                             all_test_score_fcg_f1,
#      95                             topology_ratio
#      96                             )
#      97     y =y + 1
#      98     if(y<= scope_num):
#
# File C:\JupyterDoc\FCG\experiment.py:51, in Experiment.InitializedExperimentDataList(self, dataread, test_score_baseline_accuracy, test_score_baseline_recall, test_score_baseline_precision, test_score_baseline_f1, test_score_fcg_accuracy, test_score_fcg_recall, test_score_fcg_precision, test_score_fcg_f1, topology_ratio)
#      26 def InitializedExperimentDataList(self,
#      27                                 dataread,
#      28                                 test_score_baseline_accuracy,
#    (...)
#      36                                 topology_ratio
#      37                               ):
#      40     Comparision = FCG.FCG(
#      41              dataread.data_train,
#      42              dataread.data_train_continuous,
#    (...)
#      47              dataread.label_train,
#      48              dataread.label_test,topology_ratio)
# ---> 51     Comparision.do_FCG(topology_ratio)
#      56     test_score_baseline_accuracy.append(Comparision.accuracy_score_baseline)
#      57     test_score_baseline_recall.append(Comparision.recall_score_baseline)
#
# File C:\JupyterDoc\FCG\FCG.py:517, in FCG.do_FCG(self, topology_distance_ratio, lr, sigma)
#     512  self.train_new_embedding_fcg_fuzzy = self.getEmbeddingWithClassProbablity_fuzzy(self.data_train_discrete_unnormalized)
#     514 # print(f"self.train_new_embedding_fcg_fuzzy {self.train_new_embedding_fcg_fuzzy}")
#     515
#     516  # get centeried of Fuzzy Memebership Distribution in each class
# --> 517  self.getCentroidsBySOM(  self.train_new_embedding_fcg_fuzzy,True )
#     518  #self.getCnetroidByGruopMean(  self.train_new_embedding_fcg_fuzzy )
#     519
#     520 # print(f"centeroid_dic {self.centeroid_dic}")
#     521  # ______________finish training ________________
#     522  self.test_new_embedding_fcg_fuzzy = self.getEmbeddingWithClassProbablity_fuzzy(self.data_test_discrete_unnormalized)
#
# File C:\JupyterDoc\FCG\FCG.py:484, in FCG.getCentroidsBySOM(self, X, manually_choose)
#     481 # self.getCnetroidByGruopMean(X)
#     482  #___update cenroid_____
#     483  for x in X:
# --> 484      bmu_index_sequence_dic = self.find_bmu_sequence_withJSD(x)
#     485      self._updateDeltaCentroid_dic(x, bmu_index_sequence_dic)
#
# File C:\JupyterDoc\FCG\FCG.py:430, in FCG.find_bmu_sequence_withJSD(self, x)
#     427  all_jsd_dic ={}
#     428  for  key in self.centroid_dic :
#     429   #   print(f"self.centroid_dic[key] {self.centroid_dic[key]}")
# --> 430      all_jsd_dic[key] = self.JSD(self.converted_x_dic[key],self.centroid_dic[key])
#     431  sorted_bmu_index_dic = sorted(all_jsd_dic.items(), key=lambda x:x[1])
#     432 # print(f" dict(sorted_bmu_index_dic) { dict(sorted_bmu_index_dic)}")
#
# File C:\JupyterDoc\FCG\FCG.py:412, in FCG.JSD(self, P, Q)
#     410 _Q = Q/ norm(Q, ord=1)
#     411 _M = 0.5 * (_P + _Q)
# --> 412 return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_entropy.py:139, in entropy(pk, qk, base, axis)
#     137     qk = np.asarray(qk)
#     138     pk, qk = np.broadcast_arrays(pk, qk)
# --> 139     qk = 1.0*qk / np.sum(qk, axis=axis, keepdims=True)
#     140     vec = special.rel_entr(pk, qk)
#     141 S = np.sum(vec, axis=axis)
#
# File <__array_function__ internals>:180, in sum(*args, **kwargs)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:2296, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2293         return out
#    2294     return res
# -> 2296 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2297                       initial=initial, where=where)
#
# KeyboardInterrupt:
