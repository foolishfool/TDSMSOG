# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv_training,csv_test,"Subscription Type")

# %%
import experiment
class_num= 3
dim_num = 7
scope_num = 100
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 3
# ***************************SOG ************************
# test_score_W0_p0.42933333333333334
# test_score_W0_n 0.01955687700554278
# test_score_W0_a  0.024360459023617366
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.44133333333333336
# test_score_W_combine_n 0.022972424293211106
# test_score_W_combine_a 0.022271762212137468
# Not good ari result for discrete features  !!!!!
# neuron number: 8
# ***************************SOG ************************
# test_score_W0_p0.432
# test_score_W0_n 0.021247529253730878
# test_score_W0_a  0.015184969734100327
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.488
# test_score_W_combine_n 0.04963233599269106
# test_score_W_combine_a 0.061648844198901515
# neuron number: 13
# ***************************SOG ************************
# test_score_W0_p0.4573333333333333
# test_score_W0_n 0.039171360856362296
# test_score_W0_a  0.02421439424991136
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.45866666666666667
# test_score_W_combine_n 0.033351830048116635
# test_score_W_combine_a 0.04130603707126713
# Not good nmi result for discrete features !!!!!
# neuron number: 18
# ***************************SOG ************************
# test_score_W0_p0.44533333333333336
# test_score_W0_n 0.019866824368156545
# test_score_W0_a  0.026897585828168383
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.472
# test_score_W_combine_n 0.03467111090541173
# test_score_W_combine_a 0.054170973436099355
# neuron number: 23
# ***************************SOG ************************
# test_score_W0_p0.48
# test_score_W0_n 0.07355308620249465
# test_score_W0_a  0.03773402480364056
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.488
# test_score_W_combine_n 0.046794720658927015
# test_score_W_combine_a 0.06611315206758131
# Not good nmi result for discrete features !!!!!
# neuron number: 28
# ***************************SOG ************************
# test_score_W0_p0.47733333333333333
# test_score_W0_n 0.035565743176711795
# test_score_W0_a  0.04636603536816292
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.48933333333333334
# test_score_W_combine_n 0.04822370937939871
# test_score_W_combine_a 0.062494649362594086
# neuron number: 33
# ***************************SOG ************************
# test_score_W0_p0.476
# test_score_W0_n 0.03682731608881873
# test_score_W0_a  0.04443646877607128
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.48933333333333334
# test_score_W_combine_n 0.044859162883021844
# test_score_W_combine_a 0.06270877241173269
# neuron number: 38
# ***************************SOG ************************
# test_score_W0_p0.45466666666666666
# test_score_W0_n 0.02391766176815595
# test_score_W0_a  0.029786463941555198
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.5066666666666667
# test_score_W_combine_n 0.058723658016101736
# test_score_W_combine_a 0.07327066147011313
# neuron number: 43
# ***************************SOG ************************
# test_score_W0_p0.45066666666666666
# test_score_W0_n 0.02903136388829278
# test_score_W0_a  0.031014884997329035
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.4826666666666667
# test_score_W_combine_n 0.04187527923020736
# test_score_W_combine_a 0.05433785932803717
# neuron number: 48
# ***************************SOG ************************
# test_score_W0_p0.4666666666666667
# test_score_W0_n 0.03097200455882438
# test_score_W0_a  0.03344737142946932
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.516
# test_score_W_combine_n 0.06881918799294294
# test_score_W_combine_a 0.08895058346665821
# neuron number: 53
# ***************************SOG ************************
# test_score_W0_p0.44266666666666665
# test_score_W0_n 0.01884063475251733
# test_score_W0_a  0.021487341884751387
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.492
# test_score_W_combine_n 0.049133064897246066
# test_score_W_combine_a 0.06350685812658398
# neuron number: 58
# ***************************SOG ************************
# test_score_W0_p0.49866666666666665
# test_score_W0_n 0.05178793621046952
# test_score_W0_a  0.05710994783629896
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.5026666666666667
# test_score_W_combine_n 0.05566121269150426
# test_score_W_combine_a 0.07220827282528416
# neuron number: 63
# ***************************SOG ************************
# test_score_W0_p0.4786666666666667
# test_score_W0_n 0.03914234456350811
# test_score_W0_a  0.045736165337834686
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.512
# test_score_W_combine_n 0.06141556328740654
# test_score_W_combine_a 0.07914308940373377
# neuron number: 68
# ***************************SOG ************************
# test_score_W0_p0.4746666666666667
# test_score_W0_n 0.035054283371079305
# test_score_W0_a  0.044676606691107096
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.5093333333333333
# test_score_W_combine_n 0.05616563443757349
# test_score_W_combine_a 0.0744995839069132
# neuron number: 73
# ***************************SOG ************************
# test_score_W0_p0.4746666666666667
# test_score_W0_n 0.035739456013143635
# test_score_W0_a  0.03818725720026066
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.4866666666666667
# test_score_W_combine_n 0.043875512587824905
# test_score_W_combine_a 0.06014869744867547
# neuron number: 78
# ***************************SOG ************************
# test_score_W0_p0.492
# test_score_W0_n 0.046286678435734877
# test_score_W0_a  0.051979329464782204
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.5133333333333333
# test_score_W_combine_n 0.057571203773609185
# test_score_W_combine_a 0.07551306804649639
# neuron number: 83
# ***************************SOG ************************
# test_score_W0_p0.4493333333333333
# test_score_W0_n 0.023409666730883134
# test_score_W0_a  0.028897883599373224
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.49333333333333335
# test_score_W_combine_n 0.05508308197779429
# test_score_W_combine_a 0.06414911849706303
# neuron number: 88
# ***************************SOG ************************
# test_score_W0_p0.5053333333333333
# test_score_W0_n 0.054636197178583375
# test_score_W0_a  0.06295445410394016
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.5346666666666666
# test_score_W_combine_n 0.07757378503198907
# test_score_W_combine_a 0.1017451215225072
# neuron number: 93
# ***************************SOG ************************
# test_score_W0_p0.496
# test_score_W0_n 0.048940535123708544
# test_score_W0_a  0.05739817056890594
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.49466666666666664
# test_score_W_combine_n 0.051647016851105225
# test_score_W_combine_a 0.07032109752604646
# Not good purity result for discrete features  !!!!!
# neuron number: 98
# ***************************SOG ************************
# test_score_W0_p0.5066666666666667
# test_score_W0_n 0.05539822281332247
# test_score_W0_a  0.06330299684742022
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.532
# test_score_W_combine_n 0.07608863723575185
# test_score_W_combine_a 0.08627413701779382
# all_purity_score_baseline mean 0.4694
# all_ari_score_baseline mean 0.039258640584335015
# all_nmi_score_baseline mean 0.03694728611800206
# all_purity_score_tdsmsog mean 0.4951333333333333
# all_ari_score_tdsmsog mean 0.06673911696731097
# all_nmi_score_tdsmsog mean 0.05170690660859175
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  20.0  0.469400  0.023549  0.005266   0.458379
# 1   all_purity_score_tdsmsog  20.0  0.495133  0.022400  0.005009   0.484650
# 2                   combined  40.0  0.482267  0.026161  0.004136   0.473900
#
#    Interval
# 0  0.480421
# 1  0.505617
# 2  0.490633
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0257
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.5409
# 3                           Two side test p value =    0.0011
# 4                          Difference < 0 p value =    0.0005
# 5                          Difference > 0 p value =    0.9995
# 6                                       Cohen's d =   -1.1197
# 7                                       Hedge's g =   -1.0975
# 8                                  Glass's delta1 =   -1.0927
# 9                                Point-Biserial r =   -0.4981
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  20.0  0.039259  0.014321  0.003202   0.032556
# 1   all_ari_score_tdsmsog  20.0  0.066739  0.017066  0.003816   0.058752
# 2                combined  40.0  0.052999  0.020867  0.003299   0.046325
#
#    Interval
# 0  0.045961
# 1  0.074726
# 2  0.059673
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.0275
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -5.5163
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.7444
# 7                                       Hedge's g =   -1.7098
# 8                                  Glass's delta1 =   -1.9190
# 9                                Point-Biserial r =   -0.6668
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  20.0  0.036947  0.014656  0.003277   0.030088
# 1   all_nmi_score_tdsmsog  20.0  0.051707  0.013545  0.003029   0.045367
# 2                combined  40.0  0.044327  0.015808  0.002499   0.039271
#
#    Interval
# 0  0.043807
# 1  0.058046
# 2  0.049383
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0148
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.3075
# 3                           Two side test p value =    0.0021
# 4                          Difference < 0 p value =    0.0010
# 5                          Difference > 0 p value =    0.9990
# 6                                       Cohen's d =   -1.0459
# 7                                       Hedge's g =   -1.0251
# 8                                  Glass's delta1 =   -1.0071
# 9                                Point-Biserial r =   -0.4728

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
