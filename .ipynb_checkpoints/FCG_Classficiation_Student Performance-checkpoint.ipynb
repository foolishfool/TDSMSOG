# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("student_data.csv")
#csv = csv.drop(columns=['CLIENTNUM'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"school")
dataread.label_encoding(csv,"sex")
dataread.label_encoding(csv,"address")
dataread.label_encoding(csv,"famsize")
dataread.label_encoding(csv,"Pstatus")
dataread.label_encoding(csv,"Mjob")
dataread.label_encoding(csv,"Fjob")
dataread.label_encoding(csv,"reason")
dataread.label_encoding(csv,"guardian")
dataread.label_encoding(csv,"famsup")
dataread.label_encoding(csv,"paid")
dataread.label_encoding(csv,"activities")
dataread.label_encoding(csv,"nursery")
dataread.label_encoding(csv,"higher")
dataread.label_encoding(csv,"internet")
dataread.label_encoding(csv,"romantic")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"reason")
# Out:
# continuous_feature_num 0
# discrete_feature_num 22
# self.data_discrete_indexes ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 1, choosen_index3909
# key 0, choosen_index395
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 1, choosen_index3506
# key 0, choosen_index1807
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 1, choosen_index5015
# key 0, choosen_index1791
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 1, choosen_index3259
# key 0, choosen_index1789
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 1, choosen_index3085
# key 0, choosen_index5492
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 1, choosen_index2718
# key 0, choosen_index1342
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 1, choosen_index5409
# key 0, choosen_index300
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 1, choosen_index2413
# key 0, choosen_index793
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 1, choosen_index4508
# key 0, choosen_index1855
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 1, choosen_index3854
# key 0, choosen_index1811
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 1, choosen_index5096
# key 0, choosen_index1202
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 1, choosen_index3585
# key 0, choosen_index619
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 1, choosen_index4435
# key 0, choosen_index1794
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 1, choosen_index3852
# key 0, choosen_index2437
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.9856380796060731
# recall_score_fcg 0.9853581226841877
# precision_score_fcg 0.985863484606928
# f1_score_fcg 0.9855905249360193
# Not good precision_score_ !!!!!
# Experiment number: 15
# key 1, choosen_index5236
# key 0, choosen_index59
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 1, choosen_index5219
# key 0, choosen_index1692
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 1, choosen_index3649
# key 0, choosen_index1182
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 1, choosen_index2699
# key 0, choosen_index601
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 1, choosen_index4649
# key 0, choosen_index1590
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 1, choosen_index4749
# key 0, choosen_index1541
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 1, choosen_index2133
# key 0, choosen_index2595
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 1, choosen_index4395
# key 0, choosen_index2290
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 1, choosen_index4268
# key 0, choosen_index831
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 1, choosen_index5405
# key 0, choosen_index505
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 1, choosen_index4290
# key 0, choosen_index2251
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 1, choosen_index3148
# key 0, choosen_index1662
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 1, choosen_index5145
# key 0, choosen_index1927
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 1, choosen_index2699
# key 0, choosen_index95
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 1, choosen_index2708
# key 0, choosen_index5237
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 1, choosen_index5264
# key 0, choosen_index1654
# accuracy_score_baseline 0.9852277390233894
# recall_score_baseline 0.9844020797227037
# precision_score_baseline 0.9863532979529948
# f1_score_baseline 0.985159709216096
# accuracy_score_fcg 0.014361920393926959
# recall_score_fcg 0.014641877315812294
# precision_score_fcg 0.014136515393072003
# f1_score_fcg 0.01434183868656009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.9852277390233897
# all_recall_score_baseline mean 0.9844020797227034
# all_precision_score_baseline mean 0.9863532979529948
# all_f1_score_baseline mean 0.9851597092160957
# all_accuracy_score_fcg mean 0.046737792367665155
# all_recall_score_fcg mean 0.046999085494758154
# all_precision_score_fcg mean 0.04652741436686718
# all_f1_score_fcg mean 0.04671679489487541
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.985228  2.258405e-16  4.123265e-17
# 1       all_accuracy_score_fcg  30.0  0.046738  1.773300e-01  3.237587e-02
# 2                     combined  60.0  0.515983  4.892641e-01  6.316372e-02
#
#    95% Conf.  Interval
# 0   0.985228  0.985228
# 1  -0.019478  0.112954
# 2   0.389592  0.642373
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  9.385000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.898730e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   7.484500e+00
# 7                                       Hedge's g =   7.387300e+00
# 8                                  Glass's delta1 =   4.155543e+15
# 9                                Point-Biserial r =   9.672000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.984402  2.258405e-16  4.123265e-17
# 1       all_recall_score_fcg  30.0  0.046999  1.772277e-01  3.235721e-02
# 2                   combined  60.0  0.515701  4.887158e-01  6.309294e-02
#
#    95% Conf.  Interval
# 0   0.984402  0.984402
# 1  -0.019179  0.113177
# 2   0.389452  0.641949
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re...  9.374000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.897050e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   7.480100e+00
# 7                                       Hedge's g =   7.383000e+00
# 8                                  Glass's delta1 =   4.150730e+15
# 9                                Point-Biserial r =   9.671000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.986353  0.000000  0.000000
# 1       all_precision_score_fcg  30.0  0.046527  0.177412  0.032391
# 2                      combined  60.0  0.516440  0.489930  0.063250
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1  -0.019719  0.112774
# 2   0.389878  0.643003
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.9398
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   29.0151
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    7.4917
# 7                                       Hedge's g =    7.3944
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.9672
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.985160  2.258405e-16  4.123265e-17
# 1       all_f1_score_fcg  30.0  0.046717  1.773249e-01  3.237496e-02
# 2               combined  60.0  0.515938  4.892403e-01  6.316065e-02
#
#    95% Conf.  Interval
# 0   0.985160  0.985160
# 1  -0.019497  0.112931
# 2   0.389554  0.642322
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  9.384000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.898670e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   7.484300e+00
# 7                                       Hedge's g =   7.387100e+00
# 8                                  Glass's delta1 =   4.155335e+15
# 9                                Point-Biserial r =   9.672000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
