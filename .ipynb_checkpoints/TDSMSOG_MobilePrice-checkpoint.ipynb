# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])
dataread.label_encoding(csv,"blue")
dataread.label_encoding(csv,"dual_sim")
dataread.label_encoding(csv,"fc")
dataread.label_encoding(csv,"four_g")
dataread.label_encoding(csv,"mobile_wt")
dataread.label_encoding(csv,"n_cores")
dataread.label_encoding(csv,"sc_h")
dataread.label_encoding(csv,"sc_w")
dataread.label_encoding(csv,"talk_time")
dataread.label_encoding(csv,"three_g")
dataread.label_encoding(csv,"touch_screen")
dataread.label_encoding(csv,"wifi")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"price_range")

# %%
import experiment
class_num= 3
dim_num = 20
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 13
# neuron number: 3
# ***************************SOG ************************
# test_score_W0_p0.14666666666666667
# test_score_W0_n 0.023153887221294606
# test_score_W0_a  -0.002760491810194653
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.15
# test_score_W_combine_n 0.027634910420304443
# test_score_W_combine_a -0.0006871678315354076
# neuron number: 4
# ***************************SOG ************************
# test_score_W0_p0.17
# test_score_W0_n 0.031586062501840914
# test_score_W0_a  0.001081067060797278
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.15
# test_score_W_combine_n 0.023122574551543557
# test_score_W_combine_a 0.000376573106018352
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 5
# ***************************SOG ************************
# test_score_W0_p0.18333333333333332
# test_score_W0_n 0.04656273145080567
# test_score_W0_a  0.003677891261977443
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.19
# test_score_W_combine_n 0.05670096651024749
# test_score_W_combine_a 0.009427767658812645
# neuron number: 6
# ***************************SOG ************************
# test_score_W0_p0.17
# test_score_W0_n 0.02224154032884872
# test_score_W0_a  -0.003618656513755338
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.17333333333333334
# test_score_W_combine_n 0.023744710294431138
# test_score_W_combine_a 5.811495961187266e-05
# neuron number: 7
# ***************************SOG ************************
# test_score_W0_p0.19
# test_score_W0_n 0.04535619043804481
# test_score_W0_a  0.003082947830581215
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.19333333333333333
# test_score_W_combine_n 0.03153655151733697
# test_score_W_combine_a -0.0013647757751948028
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron number: 8
# ***************************SOG ************************
# test_score_W0_p0.17333333333333334
# test_score_W0_n 0.024076788922833145
# test_score_W0_a  -0.00037875896555044123
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.18
# test_score_W_combine_n 0.036574759112129804
# test_score_W_combine_a -0.0008776936011246662
# Not good ari result for discrete features  !!!!!
# neuron number: 9
# ***************************SOG ************************
# test_score_W0_p0.19333333333333333
# test_score_W0_n 0.05270603877306558
# test_score_W0_a  0.004956235717122858
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.17333333333333334
# test_score_W_combine_n 0.04527485096853433
# test_score_W_combine_a 0.002107848343635604
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 10
# ***************************SOG ************************
# test_score_W0_p0.2
# test_score_W0_n 0.04643839573232688
# test_score_W0_a  0.0011413133237854133
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.19
# test_score_W_combine_n 0.05039300281219058
# test_score_W_combine_a 0.0035818358870082522
# Not good purity result for discrete features  !!!!!
# neuron number: 11
# ***************************SOG ************************
# test_score_W0_p0.20333333333333334
# test_score_W0_n 0.044884717899602765
# test_score_W0_a  0.0010774356256139466
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.2
# test_score_W_combine_n 0.038120421649470645
# test_score_W_combine_a 0.0023665465924569357
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 12
# ***************************SOG ************************
# test_score_W0_p0.20333333333333334
# test_score_W0_n 0.05898143388723862
# test_score_W0_a  0.00015531986602295564
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.19666666666666666
# test_score_W_combine_n 0.052840130864609446
# test_score_W_combine_a 0.001243047793923072
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 13
# ***************************SOG ************************
# test_score_W0_p0.22333333333333333
# test_score_W0_n 0.06665008411047917
# test_score_W0_a  0.010755787917141997
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22
# test_score_W_combine_n 0.04867544803238661
# test_score_W_combine_a 0.01133775056894394
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 14
# ***************************SOG ************************
# test_score_W0_p0.21333333333333335
# test_score_W0_n 0.04529745792646182
# test_score_W0_a  0.004402393581396528
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.23333333333333334
# test_score_W_combine_n 0.062276355408025376
# test_score_W_combine_a 0.010959572534828427
# neuron number: 15
# ***************************SOG ************************
# test_score_W0_p0.21666666666666667
# test_score_W0_n 0.06984840482346938
# test_score_W0_a  0.008746333838953912
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.20666666666666667
# test_score_W_combine_n 0.03680767633372287
# test_score_W_combine_a 0.0016407507943273299
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 16
# ***************************SOG ************************
# test_score_W0_p0.21
# test_score_W0_n 0.06683858099902204
# test_score_W0_a  0.0006766473008905267
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.21666666666666667
# test_score_W_combine_n 0.054923497120473105
# test_score_W_combine_a 0.006447395960984361
# Not good nmi result for discrete features !!!!!
# neuron number: 17
# ***************************SOG ************************
# test_score_W0_p0.24
# test_score_W0_n 0.08627754251261228
# test_score_W0_a  0.014093891455273599
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22666666666666666
# test_score_W_combine_n 0.06022746022806275
# test_score_W_combine_a 0.009616438712396598
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 18
# ***************************SOG ************************
# test_score_W0_p0.22666666666666666
# test_score_W0_n 0.06924274025857644
# test_score_W0_a  0.008253616684477529
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22666666666666666
# test_score_W_combine_n 0.04697857164719336
# test_score_W_combine_a 0.007844521890234147
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron number: 19
# ***************************SOG ************************
# test_score_W0_p0.21333333333333335
# test_score_W0_n 0.05589745095939833
# test_score_W0_a  0.007574067456939679
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.21
# test_score_W_combine_n 0.055703371561682966
# test_score_W_combine_a 0.003438387718508868
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 20
# ***************************SOG ************************
# test_score_W0_p0.24
# test_score_W0_n 0.06626933613745997
# test_score_W0_a  0.02069559448984377
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.23
# test_score_W_combine_n 0.06428867568812387
# test_score_W_combine_a 0.007020336531669282
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 21
# ***************************SOG ************************
# test_score_W0_p0.25
# test_score_W0_n 0.0639737021886016
# test_score_W0_a  0.013033131856081383
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.24333333333333335
# test_score_W_combine_n 0.08893721170691393
# test_score_W_combine_a 0.017127229290324453
# Not good purity result for discrete features  !!!!!
# neuron number: 22
# ***************************SOG ************************
# test_score_W0_p0.26
# test_score_W0_n 0.0923463438276386
# test_score_W0_a  0.018365609716630003
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.24666666666666667
# test_score_W_combine_n 0.07127440922416982
# test_score_W_combine_a 0.018460519410529005
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 23
# ***************************SOG ************************
# test_score_W0_p0.22666666666666666
# test_score_W0_n 0.04930656366099599
# test_score_W0_a  0.008820694049547953
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.21333333333333335
# test_score_W_combine_n 0.06220548241326521
# test_score_W_combine_a 0.0049071690017421935
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 24
# ***************************SOG ************************
# test_score_W0_p0.25333333333333335
# test_score_W0_n 0.08234668853561983
# test_score_W0_a  0.020627089058078925
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.23666666666666666
# test_score_W_combine_n 0.07160234950060197
# test_score_W_combine_a 0.009108432934871296
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 25
# ***************************SOG ************************
# test_score_W0_p0.27
# test_score_W0_n 0.08394712600159825
# test_score_W0_a  0.022805687222075096
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.25333333333333335
# test_score_W_combine_n 0.07595486964721536
# test_score_W_combine_a 0.018285849786766395
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 26
# ***************************SOG ************************
# test_score_W0_p0.25333333333333335
# test_score_W0_n 0.08195316861080558
# test_score_W0_a  0.019681209346336978
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.25333333333333335
# test_score_W_combine_n 0.08798372758799025
# test_score_W_combine_a 0.021949300798141707
# neuron number: 27
# ***************************SOG ************************
# test_score_W0_p0.27
# test_score_W0_n 0.0867440180457304
# test_score_W0_a  0.02211511590151938
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.24666666666666667
# test_score_W_combine_n 0.08136438840061387
# test_score_W_combine_a 0.015437790875466532
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 28
# ***************************SOG ************************
# test_score_W0_p0.2633333333333333
# test_score_W0_n 0.08894203787799966
# test_score_W0_a  0.02416051845713604
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.26666666666666666
# test_score_W_combine_n 0.08300027957225126
# test_score_W_combine_a 0.02188157298566973
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron number: 29
# ***************************SOG ************************
# test_score_W0_p0.27
# test_score_W0_n 0.0891416791098842
# test_score_W0_a  0.030116556977133765
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.23666666666666666
# test_score_W_combine_n 0.06900391076926937
# test_score_W_combine_a 0.008773160649116932
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 30
# ***************************SOG ************************
# test_score_W0_p0.26666666666666666
# test_score_W0_n 0.08615875583059684
# test_score_W0_a  0.021243506911654785
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.26
# test_score_W_combine_n 0.07852625862786558
# test_score_W_combine_a 0.013112358684289102
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 31
# ***************************SOG ************************
# test_score_W0_p0.23666666666666666
# test_score_W0_n 0.08580449936177773
# test_score_W0_a  0.01528720966098906
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22666666666666666
# test_score_W_combine_n 0.06882570194462918
# test_score_W_combine_a 0.004843929510256625
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 32
# ***************************SOG ************************
# test_score_W0_p0.2733333333333333
# test_score_W0_n 0.08223720371260401
# test_score_W0_a  0.0222773422362871
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.26666666666666666
# test_score_W_combine_n 0.08319241751142437
# test_score_W_combine_a 0.026157854420515724
# Not good purity result for discrete features  !!!!!
# neuron number: 33
# ***************************SOG ************************
# test_score_W0_p0.2733333333333333
# test_score_W0_n 0.0965586627149824
# test_score_W0_a  0.023253190063988224
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.25666666666666665
# test_score_W_combine_n 0.0990100178391416
# test_score_W_combine_a 0.020038209776440448
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 34
# ***************************SOG ************************
# test_score_W0_p0.25333333333333335
# test_score_W0_n 0.08222716932191299
# test_score_W0_a  0.020817976470493087
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.26
# test_score_W_combine_n 0.07634313711652982
# test_score_W_combine_a 0.01849220318052413
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron number: 35
# ***************************SOG ************************
# test_score_W0_p0.30666666666666664
# test_score_W0_n 0.10177438131338734
# test_score_W0_a  0.03939480583437916
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.27
# test_score_W_combine_n 0.08108702282206333
# test_score_W_combine_a 0.021691425311047723
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 36
# ***************************SOG ************************
# test_score_W0_p0.29
# test_score_W0_n 0.09378475535120259
# test_score_W0_a  0.028036789641734457
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.28
# test_score_W_combine_n 0.10428408572147962
# test_score_W_combine_a 0.031373162417847655
# Not good purity result for discrete features  !!!!!
# neuron number: 37
# ***************************SOG ************************
# test_score_W0_p0.24666666666666667
# test_score_W0_n 0.06818651231100238
# test_score_W0_a  0.01394425536630909
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22
# test_score_W_combine_n 0.0625754504457526
# test_score_W_combine_a 0.014662239280253571
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 38
# ***************************SOG ************************
# test_score_W0_p0.24666666666666667
# test_score_W0_n 0.08207482053326118
# test_score_W0_a  0.017084251053678227
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.2633333333333333
# test_score_W_combine_n 0.09533701746650237
# test_score_W_combine_a 0.024636183267216286
# neuron number: 39
# ***************************SOG ************************
# test_score_W0_p0.28
# test_score_W0_n 0.10008896774465946
# test_score_W0_a  0.033859286522115103
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.29
# test_score_W_combine_n 0.09181003468129283
# test_score_W_combine_a 0.031430796548863486
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron number: 40
# ***************************SOG ************************
# test_score_W0_p0.3233333333333333
# test_score_W0_n 0.10960629059655097
# test_score_W0_a  0.04388609578878322
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.30666666666666664
# test_score_W_combine_n 0.10472093351962623
# test_score_W_combine_a 0.039958659713263366
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 41
# ***************************SOG ************************
# test_score_W0_p0.23333333333333334
# test_score_W0_n 0.08298431639335596
# test_score_W0_a  0.015405601092091676
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.22666666666666666
# test_score_W_combine_n 0.0592258854856753
# test_score_W_combine_a 0.008533839751923542
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 42
# ***************************SOG ************************
# test_score_W0_p0.32
# test_score_W0_n 0.11700070757225282
# test_score_W0_a  0.047495293285729996
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.29333333333333333
# test_score_W_combine_n 0.09682974515309922
# test_score_W_combine_a 0.03266542163481685
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 43
# ***************************SOG ************************
# test_score_W0_p0.22666666666666666
# test_score_W0_n 0.07417627047595274
# test_score_W0_a  0.013971637249572733
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.24333333333333335
# test_score_W_combine_n 0.06617527919284753
# test_score_W_combine_a 0.015815125079345394
# Not good nmi result for discrete features !!!!!
# neuron number: 44
# ***************************SOG ************************
# test_score_W0_p0.30666666666666664
# test_score_W0_n 0.12960266956443633
# test_score_W0_a  0.04146534846896879
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.31333333333333335
# test_score_W_combine_n 0.10843491330139708
# test_score_W_combine_a 0.042882358403928546
# Not good nmi result for discrete features !!!!!
# neuron number: 45
# ***************************SOG ************************
# test_score_W0_p0.30333333333333334
# test_score_W0_n 0.10105770654930535
# test_score_W0_a  0.0391557626018579
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.30333333333333334
# test_score_W_combine_n 0.10165218858846253
# test_score_W_combine_a 0.03892601781558818
# Not good ari result for discrete features  !!!!!
# neuron number: 46
# ***************************SOG ************************
# test_score_W0_p0.2866666666666667
# test_score_W0_n 0.09931711212480501
# test_score_W0_a  0.024994579007854827
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.2733333333333333
# test_score_W_combine_n 0.07532816200514235
# test_score_W_combine_a 0.016071511132050346
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 47
# ***************************SOG ************************
# test_score_W0_p0.21666666666666667
# test_score_W0_n 0.0484317370907406
# test_score_W0_a  0.00559900915810915
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.25
# test_score_W_combine_n 0.07037882555032042
# test_score_W_combine_a 0.016761135528170247
# neuron number: 48
# ***************************SOG ************************
# test_score_W0_p0.31666666666666665
# test_score_W0_n 0.12208133538511594
# test_score_W0_a  0.041443860468179
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.32
# test_score_W_combine_n 0.10660601341765871
# test_score_W_combine_a 0.04577151157567292
# Not good nmi result for discrete features !!!!!
# neuron number: 49
# ***************************SOG ************************
# test_score_W0_p0.3333333333333333
# test_score_W0_n 0.13237838957275758
# test_score_W0_a  0.05861108619778704
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.32666666666666666
# test_score_W_combine_n 0.12437422280509432
# test_score_W_combine_a 0.048167838357430354
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron number: 50
# ***************************SOG ************************
# test_score_W0_p0.33
# test_score_W0_n 0.14207680337550646
# test_score_W0_a  0.05933121086516669
# ***************************  TDSMSOG ************************
# test_score_W_combine_p 0.3233333333333333
# test_score_W_combine_n 0.12176162794713358
# test_score_W_combine_a 0.05526002022006859
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# all_purity_score_baseline mean 0.2459027777777778
# all_ari_score_baseline mean 0.018539507221908065
# all_nmi_score_baseline mean 0.07663791207580045
# all_purity_score_tdsmsog mean 0.24034722222222224
# all_ari_score_tdsmsog mean 0.016202501649742625
# all_nmi_score_tdsmsog mean 0.0704922813476229
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  48.0  0.245903  0.046184  0.006666   0.232492
# 1   all_purity_score_tdsmsog  48.0  0.240347  0.044132  0.006370   0.227533
# 2                   combined  96.0  0.243125  0.045018  0.004595   0.234003
#
#    Interval
# 0  0.259313
# 1  0.253162
# 2  0.252247
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...   0.0056
# 1                              Degrees of freedom =   94.0000
# 2                                               t =    0.6025
# 3                           Two side test p value =    0.5483
# 4                          Difference < 0 p value =    0.7259
# 5                          Difference > 0 p value =    0.2741
# 6                                       Cohen's d =    0.1230
# 7                                       Hedge's g =    0.1220
# 8                                  Glass's delta1 =    0.1203
# 9                                Point-Biserial r =    0.0620
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  48.0  0.018540  0.015817  0.002283   0.013947
# 1   all_ari_score_tdsmsog  48.0  0.016203  0.014300  0.002064   0.012050
# 2                combined  96.0  0.017371  0.015044  0.001535   0.014323
#
#    Interval
# 0  0.023132
# 1  0.020355
# 2  0.020419
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...   0.0023
# 1                              Degrees of freedom =   94.0000
# 2                                               t =    0.7593
# 3                           Two side test p value =    0.4496
# 4                          Difference < 0 p value =    0.7752
# 5                          Difference > 0 p value =    0.2248
# 6                                       Cohen's d =    0.1550
# 7                                       Hedge's g =    0.1538
# 8                                  Glass's delta1 =    0.1478
# 9                                Point-Biserial r =    0.0781
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  48.0  0.076638  0.028444  0.004106   0.068379
# 1   all_nmi_score_tdsmsog  48.0  0.070492  0.025319  0.003654   0.063141
# 2                combined  96.0  0.073565  0.026962  0.002752   0.068102
#
#    Interval
# 0  0.084897
# 1  0.077844
# 2  0.079028
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...   0.0061
# 1                              Degrees of freedom =   94.0000
# 2                                               t =    1.1181
# 3                           Two side test p value =    0.2664
# 4                          Difference < 0 p value =    0.8668
# 5                          Difference > 0 p value =    0.1332
# 6                                       Cohen's d =    0.2282
# 7                                       Hedge's g =    0.2264
# 8                                  Glass's delta1 =    0.2161
# 9                                Point-Biserial r =    0.1146

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
