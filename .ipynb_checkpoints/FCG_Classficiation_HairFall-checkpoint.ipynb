# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# continuous_feature_num 1
# discrete_feature_num 10
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 0, choosen_index180
# key 1, choosen_index144
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 2
# key 0, choosen_index66
# key 1, choosen_index220
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 3
# key 0, choosen_index477
# key 1, choosen_index418
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 4
# key 0, choosen_index162
# key 1, choosen_index360
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 0, choosen_index373
# key 1, choosen_index147
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 6
# key 0, choosen_index682
# key 1, choosen_index319
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 7
# key 0, choosen_index270
# key 1, choosen_index239
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 0, choosen_index447
# key 1, choosen_index543
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 0, choosen_index524
# key 1, choosen_index624
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 10
# key 0, choosen_index366
# key 1, choosen_index95
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 0, choosen_index413
# key 1, choosen_index35
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 12
# key 0, choosen_index594
# key 1, choosen_index377
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 13
# key 0, choosen_index297
# key 1, choosen_index509
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 0, choosen_index551
# key 1, choosen_index441
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 15
# key 0, choosen_index395
# key 1, choosen_index145
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 0, choosen_index342
# key 1, choosen_index614
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 17
# key 0, choosen_index448
# key 1, choosen_index18
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 0, choosen_index651
# key 1, choosen_index149
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 19
# key 0, choosen_index677
# key 1, choosen_index439
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 20
# key 0, choosen_index126
# key 1, choosen_index605
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 21
# key 0, choosen_index299
# key 1, choosen_index308
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 0, choosen_index173
# key 1, choosen_index340
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 23
# key 0, choosen_index490
# key 1, choosen_index425
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.47491638795986624
# recall_score_fcg 0.4861449040281157
# precision_score_fcg 0.4851521004345727
# f1_score_fcg 0.47027094124152247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 0, choosen_index477
# key 1, choosen_index146
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 25
# key 0, choosen_index552
# key 1, choosen_index402
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 26
# key 0, choosen_index189
# key 1, choosen_index46
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 27
# key 0, choosen_index382
# key 1, choosen_index226
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 28
# key 0, choosen_index583
# key 1, choosen_index37
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 29
# key 0, choosen_index166
# key 1, choosen_index139
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# Experiment number: 30
# key 0, choosen_index544
# key 1, choosen_index256
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5054744525547445
# precision_score_baseline 0.5054367281188473
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5250836120401338
# recall_score_fcg 0.5138550959718843
# precision_score_fcg 0.5148478995654273
# f1_score_fcg 0.5096775683665928
# all_accuracy_score_baseline mean 0.5050167224080266
# all_recall_score_baseline mean 0.5054744525547447
# all_precision_score_baseline mean 0.5054367281188471
# all_f1_score_baseline mean 0.5043458781362007
# all_accuracy_score_fcg mean 0.5100334448160536
# all_recall_score_fcg mean 0.5055420383887537
# all_precision_score_fcg mean 0.5059391598261711
# all_f1_score_fcg mean 0.4978555802290717
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.505017  1.129203e-16  2.061632e-17
# 1       all_accuracy_score_fcg  30.0  0.510033  2.338252e-02  4.269045e-03
# 2                     combined  60.0  0.507525  1.658723e-02  2.141402e-03
#
#    95% Conf.  Interval
# 0   0.505017  0.505017
# 1   0.501302  0.518765
# 2   0.503240  0.511810
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_... -5.000000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.175100e+00
# 3                           Two side test p value =   2.447000e-01
# 4                          Difference < 0 p value =   1.224000e-01
# 5                          Difference > 0 p value =   8.776000e-01
# 6                                       Cohen's d =  -3.034000e-01
# 7                                       Hedge's g =  -2.995000e-01
# 8                                  Glass's delta1 =  -4.442713e+13
# 9                                Point-Biserial r =  -1.525000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.505474  1.129203e-16  2.061632e-17
# 1       all_recall_score_fcg  30.0  0.505542  1.291549e-02  2.358035e-03
# 2                   combined  60.0  0.505508  9.054967e-03  1.168991e-03
#
#    95% Conf.  Interval
# 0   0.505474  0.505474
# 1   0.500719  0.510365
# 2   0.503169  0.507847
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -1.000000e-04
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -2.870000e-02
# 3                           Two side test p value =   9.772000e-01
# 4                          Difference < 0 p value =   4.886000e-01
# 5                          Difference > 0 p value =   5.114000e-01
# 6                                       Cohen's d =  -7.400000e-03
# 7                                       Hedge's g =  -7.300000e-03
# 8                                  Glass's delta1 =  -5.985271e+11
# 9                                Point-Biserial r =  -3.800000e-03
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.505437  2.258405e-16  4.123265e-17
# 1       all_precision_score_fcg  30.0  0.505939  1.384096e-02  2.527002e-03
# 2                      combined  60.0  0.505688  9.707049e-03  1.253175e-03
#
#    95% Conf.  Interval
# 0   0.505437  0.505437
# 1   0.500771  0.511107
# 2   0.503180  0.508196
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -5.000000e-04
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.988000e-01
# 3                           Two side test p value =   8.431000e-01
# 4                          Difference < 0 p value =   4.215000e-01
# 5                          Difference > 0 p value =   5.785000e-01
# 6                                       Cohen's d =  -5.130000e-02
# 7                                       Hedge's g =  -5.070000e-02
# 8                                  Glass's delta1 =  -2.224719e+12
# 9                                Point-Biserial r =  -2.610000e-02
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.504346  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.497856  0.018367  0.003353   0.490997
# 2               combined  60.0  0.501101  0.013286  0.001715   0.497669
#
#    Interval
# 0       NaN
# 1  0.504714
# 2  0.504533
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0065
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.9355
# 3                           Two side test p value =    0.0578
# 4                          Difference < 0 p value =    0.9711
# 5                          Difference > 0 p value =    0.0289
# 6                                       Cohen's d =    0.4997
# 7                                       Hedge's g =    0.4932
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.2463
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
