# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Hotel Reservations.csv")
csv = csv.drop(columns=['Booking_ID'])
csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"type_of_meal_plan")
dataread.label_encoding(csv,"room_type_reserved")
dataread.label_encoding(csv,"arrival_year")
dataread.label_encoding(csv,"market_segment_type")
dataread.label_encoding(csv,"booking_status")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv,csv_training,csv_test,"booking_status")
# Out:
# continuous_feature_num 3
# discrete_feature_num 14
# self.data_discrete_indexes ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'arrival_year', 'arrival_month', 'market_segment_type', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'no_of_special_requests']

# %%
import experiment
scope_num = 50
topology_ratio =3

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 1, choosen_index129
# key 0, choosen_index80
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.37272727272727274
# precision_score_fcg 0.38636363636363635
# f1_score_fcg 0.3770212765957447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 1, choosen_index63
# key 0, choosen_index112
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 1, choosen_index16
# key 0, choosen_index200
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6430303030303031
# precision_score_fcg 0.6580357142857143
# f1_score_fcg 0.5267634676518602
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 1, choosen_index230
# key 0, choosen_index223
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.5084848484848485
# precision_score_fcg 0.5078947368421052
# f1_score_fcg 0.5069451189898009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 1, choosen_index103
# key 0, choosen_index82
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5092592592592593
# recall_score_fcg 0.5533333333333333
# precision_score_fcg 0.546875
# f1_score_fcg 0.5041150480810881
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 1, choosen_index63
# key 0, choosen_index220
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 1, choosen_index21
# key 0, choosen_index10
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4444444444444444
# recall_score_fcg 0.5066666666666666
# precision_score_fcg 0.5062809288161401
# f1_score_fcg 0.4436813186813187
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 1, choosen_index60
# key 0, choosen_index139
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 1, choosen_index4
# key 0, choosen_index168
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5185185185185185
# recall_score_fcg 0.6278787878787879
# precision_score_fcg 0.6381492797904845
# f1_score_fcg 0.5178571428571428
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 1, choosen_index250
# key 0, choosen_index73
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.58
# precision_score_fcg 0.671875
# f1_score_fcg 0.3937449879711308
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 1, choosen_index26
# key 0, choosen_index151
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6345454545454545
# precision_score_fcg 0.6423076923076924
# f1_score_fcg 0.5274131274131274
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 1, choosen_index225
# key 0, choosen_index164
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.5084848484848485
# precision_score_fcg 0.5078947368421052
# f1_score_fcg 0.5069451189898009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 1, choosen_index91
# key 0, choosen_index80
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5740740740740741
# recall_score_fcg 0.6339393939393939
# precision_score_fcg 0.6186046511627907
# f1_score_fcg 0.5703908682116914
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 1, choosen_index179
# key 0, choosen_index56
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5740740740740741
# recall_score_fcg 0.6339393939393939
# precision_score_fcg 0.6186046511627907
# f1_score_fcg 0.5703908682116914
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 1, choosen_index150
# key 0, choosen_index205
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 1, choosen_index248
# key 0, choosen_index171
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4444444444444444
# recall_score_fcg 0.5066666666666666
# precision_score_fcg 0.5062809288161401
# f1_score_fcg 0.4436813186813187
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 1, choosen_index218
# key 0, choosen_index117
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6345454545454545
# precision_score_fcg 0.6423076923076924
# f1_score_fcg 0.5274131274131274
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 1, choosen_index79
# key 0, choosen_index233
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.4915151515151515
# precision_score_fcg 0.4921052631578947
# f1_score_fcg 0.43397199072085235
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 1, choosen_index19
# key 0, choosen_index93
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4722222222222222
# recall_score_fcg 0.35696969696969694
# precision_score_fcg 0.3419642857142857
# f1_score_fcg 0.3489159175039661
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 1, choosen_index122
# key 0, choosen_index247
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5185185185185185
# recall_score_fcg 0.6278787878787879
# precision_score_fcg 0.6381492797904845
# f1_score_fcg 0.5178571428571428
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 1, choosen_index104
# key 0, choosen_index27
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6430303030303031
# precision_score_fcg 0.6580357142857143
# f1_score_fcg 0.5267634676518602
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 1, choosen_index154
# key 0, choosen_index202
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5370370370370371
# recall_score_fcg 0.5054545454545455
# precision_score_fcg 0.5047619047619047
# f1_score_fcg 0.4983277591973244
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 1, choosen_index244
# key 0, choosen_index220
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.6272727272727272
# precision_score_fcg 0.6136363636363636
# f1_score_fcg 0.5617715617715617
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 1, choosen_index163
# key 0, choosen_index55
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6430303030303031
# precision_score_fcg 0.6580357142857143
# f1_score_fcg 0.5267634676518602
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 1, choosen_index150
# key 0, choosen_index229
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4444444444444444
# recall_score_fcg 0.5066666666666666
# precision_score_fcg 0.5062809288161401
# f1_score_fcg 0.4436813186813187
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 1, choosen_index90
# key 0, choosen_index138
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.37272727272727274
# precision_score_fcg 0.38636363636363635
# f1_score_fcg 0.3770212765957447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 1, choosen_index143
# key 0, choosen_index200
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.6272727272727272
# precision_score_fcg 0.6136363636363636
# f1_score_fcg 0.5617715617715617
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 1, choosen_index199
# key 0, choosen_index151
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.42592592592592593
# recall_score_fcg 0.3660606060606061
# precision_score_fcg 0.38139534883720927
# f1_score_fcg 0.37067669172932327
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 1, choosen_index20
# key 0, choosen_index162
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 1, choosen_index5
# key 0, choosen_index226
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4444444444444444
# recall_score_fcg 0.5066666666666666
# precision_score_fcg 0.5062809288161401
# f1_score_fcg 0.4436813186813187
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 31
# key 1, choosen_index126
# key 0, choosen_index34
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.4915151515151515
# precision_score_fcg 0.4921052631578947
# f1_score_fcg 0.43397199072085235
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 32
# key 1, choosen_index15
# key 0, choosen_index227
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.6345454545454545
# precision_score_fcg 0.6423076923076924
# f1_score_fcg 0.5274131274131274
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 33
# key 1, choosen_index198
# key 0, choosen_index43
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.4915151515151515
# precision_score_fcg 0.4921052631578947
# f1_score_fcg 0.43397199072085235
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 34
# key 1, choosen_index206
# key 0, choosen_index148
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4444444444444444
# recall_score_fcg 0.5066666666666666
# precision_score_fcg 0.5062809288161401
# f1_score_fcg 0.4436813186813187
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 35
# key 1, choosen_index57
# key 0, choosen_index247
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.6272727272727272
# precision_score_fcg 0.6136363636363636
# f1_score_fcg 0.5617715617715617
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 36
# key 1, choosen_index218
# key 0, choosen_index71
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5555555555555556
# recall_score_fcg 0.4933333333333333
# precision_score_fcg 0.49371907118385994
# f1_score_fcg 0.49275929549902153
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 37
# key 1, choosen_index235
# key 0, choosen_index31
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.6944444444444444
# recall_score_fcg 0.5
# precision_score_fcg 0.3472222222222222
# f1_score_fcg 0.4098360655737705
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 38
# key 1, choosen_index20
# key 0, choosen_index34
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.6944444444444444
# recall_score_fcg 0.516969696969697
# precision_score_fcg 0.6009615384615384
# f1_score_fcg 0.4618752831043334
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 39
# key 1, choosen_index210
# key 0, choosen_index185
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 40
# key 1, choosen_index158
# key 0, choosen_index11
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.58
# precision_score_fcg 0.671875
# f1_score_fcg 0.3937449879711308
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 41
# key 1, choosen_index72
# key 0, choosen_index138
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4722222222222222
# recall_score_fcg 0.35696969696969694
# precision_score_fcg 0.3419642857142857
# f1_score_fcg 0.3489159175039661
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 42
# key 1, choosen_index251
# key 0, choosen_index71
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.37272727272727274
# precision_score_fcg 0.38636363636363635
# f1_score_fcg 0.3770212765957447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 43
# key 1, choosen_index181
# key 0, choosen_index183
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5740740740740741
# recall_score_fcg 0.5236363636363637
# precision_score_fcg 0.5217391304347826
# f1_score_fcg 0.5208333333333333
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 44
# key 1, choosen_index145
# key 0, choosen_index167
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.6944444444444444
# recall_score_fcg 0.5
# precision_score_fcg 0.3472222222222222
# f1_score_fcg 0.4098360655737705
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 45
# key 1, choosen_index91
# key 0, choosen_index168
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.6272727272727272
# precision_score_fcg 0.6136363636363636
# f1_score_fcg 0.5617715617715617
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 46
# key 1, choosen_index90
# key 0, choosen_index183
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5277777777777778
# recall_score_fcg 0.4903030303030303
# precision_score_fcg 0.4914772727272727
# f1_score_fcg 0.48537793142109686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 47
# key 1, choosen_index235
# key 0, choosen_index92
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5648148148148148
# recall_score_fcg 0.5084848484848485
# precision_score_fcg 0.5078947368421052
# f1_score_fcg 0.5069451189898009
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 48
# key 1, choosen_index144
# key 0, choosen_index76
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4351851851851852
# recall_score_fcg 0.4915151515151515
# precision_score_fcg 0.4921052631578947
# f1_score_fcg 0.43397199072085235
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 49
# key 1, choosen_index30
# key 0, choosen_index174
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.5185185185185185
# recall_score_fcg 0.6278787878787879
# precision_score_fcg 0.6381492797904845
# f1_score_fcg 0.5178571428571428
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 50
# key 1, choosen_index78
# key 0, choosen_index243
# accuracy_score_baseline 0.6944444444444444
# recall_score_baseline 0.5848484848484848
# precision_score_baseline 0.6193181818181819
# f1_score_baseline 0.5874522514179882
# accuracy_score_fcg 0.4074074074074074
# recall_score_fcg 0.5733333333333334
# precision_score_fcg 0.6701030927835052
# f1_score_fcg 0.3817531305903399
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.6944444444444444
# all_recall_score_baseline mean 0.584848484848485
# all_precision_score_baseline mean 0.6193181818181819
# all_f1_score_baseline mean 0.5874522514179882
# all_accuracy_score_fcg mean 0.5131481481481481
# all_recall_score_fcg mean 0.5294909090909091
# all_precision_score_fcg mean 0.5314370528755789
# all_f1_score_fcg mean 0.47286285887805674
# len plot_unit 50  len (all_test_score_baseline_accuracy) 50
# Accuracy Score T-Test
#                       Variable      N      Mean        SD        SE  \
# 0  all_accuracy_score_baseline   50.0  0.694444  0.000000  0.000000
# 1       all_accuracy_score_fcg   50.0  0.513148  0.070071  0.009909
# 2                     combined  100.0  0.603796  0.103587  0.010359
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.493234  0.533062
# 2   0.583242  0.624350
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.1813
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   18.2952
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    3.6590
# 7                                       Hedge's g =    3.6310
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8795
# Recall Score T-Test
#                     Variable      N      Mean            SD            SE  \
# 0  all_recall_score_baseline   50.0  0.584848  1.121495e-16  1.586033e-17
# 1       all_recall_score_fcg   50.0  0.529491  8.484129e-02  1.199837e-02
# 2                   combined  100.0  0.557170  6.585228e-02  6.585228e-03
#
#    95% Conf.  Interval
# 0   0.584848  0.584848
# 1   0.505379  0.553603
# 2   0.544103  0.570236
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re...  5.540000e-02
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =   4.613800e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   9.228000e-01
# 7                                       Hedge's g =   9.157000e-01
# 8                                  Glass's delta1 =   4.936054e+14
# 9                                Point-Biserial r =   4.224000e-01
# Precision Score T-Test
#                        Variable      N      Mean        SD        SE  \
# 0  all_precision_score_baseline   50.0  0.619318  0.000000  0.000000
# 1       all_precision_score_fcg   50.0  0.531437  0.098440  0.013922
# 2                      combined  100.0  0.575378  0.082137  0.008214
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.503461  0.559413
# 2   0.559080  0.591675
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.0879
# 1                              Degrees of freedom =   98.0000
# 2                                               t =    6.3126
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    1.2625
# 7                                       Hedge's g =    1.2528
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.5377
# F1 Score T-Test
#                 Variable      N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline   50.0  0.587452  0.000000  0.000000        NaN
# 1       all_f1_score_fcg   50.0  0.472863  0.062463  0.008834   0.455111
# 2               combined  100.0  0.530158  0.072436  0.007244   0.515785
#
#    Interval
# 0       NaN
# 1  0.490615
# 2  0.544530
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.1146
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   12.9720
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.5944
# 7                                       Hedge's g =    2.5745
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7950
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
