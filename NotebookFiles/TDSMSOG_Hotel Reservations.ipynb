# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Hotel Reservations.csv")
csv = csv.drop(columns=['Booking_ID'])
csv = csv.sample(int(csv.shape[0]*1))


dataread.label_encoding(csv,"type_of_meal_plan")
dataread.label_encoding(csv,"room_type_reserved")
dataread.label_encoding(csv,"arrival_year")
dataread.label_encoding(csv,"market_segment_type")
dataread.label_encoding(csv,"booking_status")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv_training,csv_test,"booking_status")

# %%
import experiment
class_num= 2
dim_num = 17
scope_num = 20
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
# neuron number: 2
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 4
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 6
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 8
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 10
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 12
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 14
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 16
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 20
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# best purity baseline  0.8048152913067451
# best ari  baseline 0.3623608128138892
# best nmi  baseline0.24358797024387113
# best purity proposed 0.8302701709244624
# best ari proposed  0.4282211468120658
# best nmi proposed 0.30077902469916595
# all_purity_score_baseline mean 0.8048152913067451
# all_ari_score_ba seline mean 0.36236081281388915
# all_nmi_score_baseline mean 0.24358797024387108
# all_purity_score_tdsmsog mean 0.8254432718443784
# all_ari_score_tdsmsog mean 0.4152400162160137
# all_nmi_score_tdsmsog mean 0.28913019870041046
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  19.0  0.804815  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  19.0  0.825443  0.002428  0.000557   0.824273
# 2                   combined  38.0  0.815129  0.010589  0.001718   0.811649
#
#    Interval
# 0       NaN
# 1  0.826614
# 2  0.818610
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0206
# 1                              Degrees of freedom =   36.0000
# 2                                               t =  -37.0253
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =  -12.0126
# 7                                       Hedge's g =  -11.7606
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9871
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  19.0  0.362361  5.703229e-17  1.308410e-17
# 1   all_ari_score_tdsmsog  19.0  0.415240  6.446506e-03  1.478930e-03
# 2                combined  38.0  0.388800  2.716915e-02  4.407419e-03
#
#    95% Conf.  Interval
# 0   0.362361  0.362361
# 1   0.412133  0.418347
# 2   0.379870  0.397731
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -5.290000e-02
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -3.575500e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.160050e+01
# 7                                       Hedge's g =  -1.135710e+01
# 8                                  Glass's delta1 =  -9.271801e+14
# 9                                Point-Biserial r =  -9.862000e-01
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  19.0  0.243588  5.703229e-17  1.308410e-17
# 1   all_nmi_score_tdsmsog  19.0  0.289130  5.715175e-03  1.311151e-03
# 2                combined  38.0  0.266359  2.341854e-02  3.798989e-03
#
#    95% Conf.  Interval
# 0   0.243588  0.243588
# 1   0.286376  0.291885
# 2   0.258662  0.274057
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s... -4.550000e-02
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -3.473450e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.126940e+01
# 7                                       Hedge's g =  -1.103300e+01
# 8                                  Glass's delta1 =  -7.985342e+14
# 9                                Point-Biserial r =  -9.854000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
class_num= 2
dim_num = 17
scope_num = 20
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
# initila self.weigts shape (2, 17)
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.8020584451387612
#  self.test_score_W0_n 0.24149872684777737
#  self.test_score_W0_a 0.35694830159946156
# SOG TDSM !!!!!!!!!!!!!!
# initila self.weigts shape (2, 17)
# ***************************  TDSMSOG ************************
# Comparision.train_data_embedding_tdsmsog shape (25393, 51)
# initila self.weigts shape (2, 51)
#  NO Error Data, Finish Training!
# total split_number 1
#  self.test_score_W1_p 0.8252159529498254
#  self.test_score_W1_n 0.2908303090041112
#  self.test_score_W1_a 0.4154420866260863

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 2
dim_num = 17
scope_num = 100
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.809777614409116
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 6
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 10
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 12
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 14
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 16
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 18
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 20
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# all_purity_score_baseline mean 0.809777614409116
# all_ari_score_baseline mean 0.37606689940035143
# all_nmi_score_baseline mean 0.2576922993480978
# all_purity_score_tdsmsog mean 0.8245451203822827
# all_ari_score_tdsmsog mean 0.4131613000208902
# all_nmi_score_tdsmsog mean 0.28781971804831674
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  10.0  0.809778  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  10.0  0.824545  0.002562  0.000810   0.822712
# 2                   combined  20.0  0.817161  0.007778  0.001739   0.813521
#
#    Interval
# 0       NaN
# 1  0.826378
# 2  0.820802
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0148
# 1                              Degrees of freedom =   18.0000
# 2                                               t =  -18.2267
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -8.1512
# 7                                       Hedge's g =   -7.8068
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9740
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  10.0  0.376067  5.851389e-17  1.850372e-17
# 1   all_ari_score_tdsmsog  10.0  0.413161  6.653149e-03  2.103910e-03
# 2                combined  20.0  0.394614  1.957220e-02  4.376478e-03
#
#    95% Conf.  Interval
# 0   0.376067  0.376067
# 1   0.408402  0.417921
# 2   0.385454  0.403774
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -3.710000e-02
# 1                              Degrees of freedom =   1.800000e+01
# 2                                               t =  -1.763120e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.884900e+00
# 7                                       Hedge's g =  -7.551700e+00
# 8                                  Glass's delta1 =  -6.339418e+14
# 9                                Point-Biserial r =  -9.722000e-01
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  10.0  0.257692  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  10.0  0.287820  0.005655  0.001788   0.283774
# 2                combined  20.0  0.272756  0.015938  0.003564   0.265297
#
#    Interval
# 0       NaN
# 1  0.291865
# 2  0.280215
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0301
# 1                              Degrees of freedom =   18.0000
# 2                                               t =  -16.8469
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -7.5342
# 7                                       Hedge's g =   -7.2158
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9697
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
