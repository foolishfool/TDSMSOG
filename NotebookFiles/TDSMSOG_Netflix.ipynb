# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv_training,csv_test,"Subscription Type")

# %%
import experiment
class_num= 3
dim_num = 7
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 33
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# best purity baseline  0.39866666666666667
# best ari  baseline 0.007405814115091089
# best nmi  baseline0.008060934446528419
# best purity proposed 0.512
# best ari proposed  0.07522252492896254
# best nmi proposed 0.06527606295688373
# all_purity_score_baseline mean 0.39866666666666667
# all_ari_score_ba seline mean 0.007405814115091089
# all_nmi_score_baseline mean 0.008060934446528419
# all_purity_score_tdsmsog mean 0.458
# all_ari_score_tdsmsog mean 0.037196515344368075
# all_nmi_score_tdsmsog mean 0.033920755363885245
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  24.0  0.398667  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  24.0  0.458000  0.027623  0.005639   0.446336
# 2                   combined  48.0  0.428333  0.035669  0.005148   0.417976
#
#    Interval
# 0       NaN
# 1  0.469664
# 2  0.438690
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0593
# 1                              Degrees of freedom =   46.0000
# 2                                               t =  -10.5227
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.0376
# 7                                       Hedge's g =   -2.9878
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8405
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  24.0  0.007406  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  24.0  0.037197  0.016668  0.003402   0.030158
# 2                combined  48.0  0.022301  0.019041  0.002748   0.016772
#
#    Interval
# 0       NaN
# 1  0.044235
# 2  0.027830
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.0298
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -8.7560
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.5276
# 7                                       Hedge's g =   -2.4862
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7906
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  24.0  0.008061  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  24.0  0.033921  0.014299  0.002919   0.027883
# 2                combined  48.0  0.020991  0.016456  0.002375   0.016213
#
#    Interval
# 0       NaN
# 1  0.039959
# 2  0.025769
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0259
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -8.8596
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.5575
# 7                                       Hedge's g =   -2.5156
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7940
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 3
dim_num = 7
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.4013333333333333
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 13
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 18
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 23
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 28
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 33
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 38
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 43
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 48
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# all_purity_score_baseline mean 0.4013333333333334
# all_ari_score_baseline mean 0.011158708113904198
# all_nmi_score_baseline mean 0.012554016144981351
# all_purity_score_tdsmsog mean 0.44253333333333333
# all_ari_score_tdsmsog mean 0.026514599920632247
# all_nmi_score_tdsmsog mean 0.02462433401940744
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  10.0  0.401333  5.851389e-17  1.850372e-17
# 1   all_purity_score_tdsmsog  10.0  0.442533  1.560563e-02  4.934935e-03
# 2                   combined  20.0  0.421933  2.370767e-02  5.301197e-03
#
#    95% Conf.  Interval
# 0   0.401333  0.401333
# 1   0.431370  0.453697
# 2   0.410838  0.433029
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu... -4.120000e-02
# 1                              Degrees of freedom =   1.800000e+01
# 2                                               t =  -8.348600e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.733600e+00
# 7                                       Hedge's g =  -3.575900e+00
# 8                                  Glass's delta1 =  -7.041063e+14
# 9                                Point-Biserial r =  -8.915000e-01
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  10.0  0.011159  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  10.0  0.026515  0.008161  0.002581   0.020676
# 2                combined  20.0  0.018837  0.009675  0.002163   0.014309
#
#    Interval
# 0       NaN
# 1  0.032353
# 2  0.023365
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.0154
# 1                              Degrees of freedom =   18.0000
# 2                                               t =   -5.9499
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.6609
# 7                                       Hedge's g =   -2.5484
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8142
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  10.0  0.012554  1.828559e-18  5.782412e-19
# 1   all_nmi_score_tdsmsog  10.0  0.024624  5.799789e-03  1.834054e-03
# 2                combined  20.0  0.018589  7.367070e-03  1.647327e-03
#
#    95% Conf.  Interval
# 0   0.012554  0.012554
# 1   0.020475  0.028773
# 2   0.015141  0.022037
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s... -1.210000e-02
# 1                              Degrees of freedom =   1.800000e+01
# 2                                               t =  -6.581200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.943200e+00
# 7                                       Hedge's g =  -2.818900e+00
# 8                                  Glass's delta1 =  -6.601000e+15
# 9                                Point-Biserial r =  -8.405000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
