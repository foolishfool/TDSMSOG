# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve()             
CODES_DIR = BASE_DIR.parent / "Codes"
sys.path.insert(0, str(CODES_DIR))

import pandas as pd
import numpy as np
import dataset_read
import experiment
dataread = dataset_read.DATAREAD()
# Out:
# C:\Users\qiang\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
csv = pd.read_csv(r"..\Datasets\dummy_data.csv")

dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")

grouped = csv.groupby('time_spent')

for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    
# Calculate sparsity
total_elements = csv.size
zero_elements = (csv == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

print("Sparsity (%):", sparsity)

dataread.initializedataset(csv,"time_spent")
# Out:
# Category: 1
# 99
# Category: 2
# 112
# Category: 3
# 107
# Category: 4
# 120
# Category: 5
# 125
# Category: 6
# 110
# Category: 7
# 107
# Category: 8
# 109
# Category: 9
# 111
# Sparsity (%): 29.025000000000002

# %%
#N1
import experiment
class_num= 1
dim_num = 11
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,50,"Average")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM Mean: 0.4980
# TDSM  95% Purity Confidence Interval: (np.float64(0.4837339942388208), np.float64(0.5122660057611793))
# TDSM Mean: -0.0096
# TDSM  95% ARI Confidence Interval: (np.float64(-0.025046476389471314), np.float64(0.005811421805282298))
# TDSM Mean: 0.5413
# TDSM  95% NMI Confidence Interval: (np.float64(0.5273272399454664), np.float64(0.5552978262634446))
#  tdsm  seconds_difference 0.56090768
# tdsm perfection neuron numbers 9.0
# SOG TDSM !!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       6 scope_num = 2
#       7 experiment = experiment.Experiment()
# ----> 8 experiment.Ttest(dataread,class_num, dim_num,scope_num,50,"Average")
#
# File D:\JupyterDoc\TDSMSOG\Codes\experiment.py:235, in Experiment.Ttest(self, dataread, initial_neuron_num, dim_num, scope_num, nfolder, PltName)
#     231   print("SOG TDSM !!!!!!!!!!!!!!")
#     232 #  m, n = self.topology_som(y)
#     233 #  som = newSom.SOM(m= m, n= n, dim=dim_num)
# --> 235   self.InitializedExperimentDataList(initial_neuron_num,
#     236                           dataread,
#     237                           all_test_score_tdsmsog_purity,
#     238                           all_test_score_tdsmsog_ari,
#     239                           all_test_score_tdsmsog_nmi,
#     240                           dim_num,
#     241                           self.kfolders_index_train,
#     242                           self.kfolders_index_test,
#     243                           self.n_granules
#     244                           )
#     245   y =y +1
#     246   if(y<= scope_num):
#
# File D:\JupyterDoc\TDSMSOG\Codes\experiment.py:75, in Experiment.InitializedExperimentDataList(self, initial_neuron_num, dataread, all_test_score_tdsmsog_purity, all_test_score_tdsmsog_ari, all_test_score_tdsmsog_nmi, dim_num, train_indexes, test_indexes, n_granules)
#      67     start_time = datetime.now()
#      69  # k = 0
#      70   #for train, test in kfold.split(dataread.all_data):
#      71       # print(f" dataread.all_data { dataread.all_data.shape}")
# ---> 75     Comparision = TDSM_SOG.TDSMSOG(initial_neuron_num,
#      76             dataread,
#      77             dataread.all_label,
#      78             train_indexes[i],
#      79             test_indexes[i])
#      81     Comparision.do_SOGVSTDSMSOG(n_granules[i])
#      83    # print(f"train_indexes[0] {train_indexes[0]}")
#      84   #obtain sog encoding
#      85 #  Comparision.train_data_embedding_tdsmsog
#      86 #  Comparision.test_new_embedding_sog
#
# File D:\JupyterDoc\TDSMSOG\Codes\TDSM_SOG.py:66, in TDSMSOG.__init__(self, som, data_train, data_test, label_train, label_test)
#      63 self.som = som
#      64 #print(f"som weigth shape {som.weights.shape}")
#      65 # initial cluster numbers in TDSM_SOM, which is the neuron number in som
# ---> 66 self.predicted_classNum = int(som.m*som.n)
#      68 self.data_train = data_train
#      69 self.data_test = data_test
#
# AttributeError: 'int' object has no attribute 'm'
