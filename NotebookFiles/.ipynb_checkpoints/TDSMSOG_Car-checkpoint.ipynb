# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()
# Out:
# C:\Users\fooli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=19) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
    
print(X.shape)
# metadata 
#print(car_evaluation.metadata) 
  
# variable information 
#print(car_evaluation.variables)
# Out:
# (1728, 6)

# %%
#csv = pd.read_csv("car.data")

#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))
#Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'], dtype='object')
#Index(['class'], dtype='object')

dataread.label_encoding(X,"buying")
dataread.label_encoding(X,"maint")
dataread.label_encoding(X,"doors")
dataread.label_encoding(X,"persons")
dataread.label_encoding(X,"lug_boot")
dataread.label_encoding(X,"safety")
dataread.label_encoding(y,"class")
grouped = y.groupby('class')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = X.size
zero_elements = (X == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)
    

dataread.readucidata(X,y,"class")
# Out:
# Category: 0
# 384
# Category: 1
# 69
# Category: 2
# 1210
# Category: 3
# 65
# Sparsity (%): 29.166666666666668
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])

# %%
import experiment
class_num= 1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,20,"Car")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
# TDSM Mean: 0.7942
# TDSM  95% Purity Confidence Interval: (0.7370597671489866, 0.851298960463951)
# TDSM Mean: 0.2974
# TDSM  95% ARI Confidence Interval: (0.14831653611323758, 0.44643751225746764)
# TDSM Mean: 0.3026
# TDSM  95% NMI Confidence Interval: (0.1604294710380915, 0.444674730149498)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# TDSMSOM Mean: 0.9612
# TDSMSOM  95% Purity Confidence Interval: (0.9346453941223503, 0.9877283027501436)
# TDSMSOM Mean: 0.7671
# TDSMSOM  95% ARI Confidence Interval: (0.6295129181128082, 0.9046060999344704)
# TDSMSOM Mean: 0.7442
# TDSMSOM  95% NMI Confidence Interval: (0.6057084123407673, 0.8827259338452079)
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
# TDSM Mean: 0.7942
# TDSM  95% Purity Confidence Interval: (0.7370597671489866, 0.851298960463951)
# TDSM Mean: 0.2974
# TDSM  95% ARI Confidence Interval: (0.14831653611323758, 0.44643751225746764)
# TDSM Mean: 0.3026
# TDSM  95% NMI Confidence Interval: (0.1604294710380915, 0.444674730149498)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# TDSMSOM Mean: 0.9612
# TDSMSOM  95% Purity Confidence Interval: (0.9346453941223503, 0.9877283027501436)
# TDSMSOM Mean: 0.7671
# TDSMSOM  95% ARI Confidence Interval: (0.6295129181128082, 0.9046060999344704)
# TDSMSOM Mean: 0.7442
# TDSMSOM  95% NMI Confidence Interval: (0.6057084123407673, 0.8827259338452079)
# best purity baseline  0.7941793638064688
# best ari  baseline 0.2973770241853526
# best nmi  baseline0.3025521005937947
# best purity proposed 0.9611868484362469
# best ari proposed  0.7670595090236393
# best nmi proposed 0.7442171730929876
# all_purity_score_baseline mean 0.7941793638064688
# all_ari_score_ba seline mean 0.2973770241853526
# all_nmi_score_baseline mean 0.3025521005937947
# all_purity_score_tdsmsog mean 0.9611868484362469
# all_ari_score_tdsmsog mean 0.7670595090236393
# all_nmi_score_tdsmsog mean 0.7442171730929876
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
import experiment
class_num= 1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,20,"Car")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
# TDSM Mean: 0.7942
# TDSM  95% Purity Confidence Interval: (0.7370597671489866, 0.851298960463951)
# TDSM Mean: 0.2974
# TDSM  95% ARI Confidence Interval: (0.14831653611323758, 0.44643751225746764)
# TDSM Mean: 0.3026
# TDSM  95% NMI Confidence Interval: (0.1604294710380915, 0.444674730149498)
#  tdsm  seconds_difference 0.4515081500000001
# tdsm perfection neuron numbers 4.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# TDSMSOM Mean: 0.9612
# TDSMSOM  95% Purity Confidence Interval: (0.9346453941223503, 0.9877283027501436)
# TDSMSOM Mean: 0.7671
# TDSMSOM  95% ARI Confidence Interval: (0.6295129181128082, 0.9046060999344704)
# TDSMSOM Mean: 0.7442
# TDSMSOM  95% NMI Confidence Interval: (0.6057084123407673, 0.8827259338452079)
#  tdsm-som  seconds_difference 0.5713242000000001
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 3
# TDSM Mean: 0.7942
# TDSM  95% Purity Confidence Interval: (0.7370597671489866, 0.851298960463951)
# TDSM Mean: 0.2974
# TDSM  95% ARI Confidence Interval: (0.14831653611323758, 0.44643751225746764)
# TDSM Mean: 0.3026
# TDSM  95% NMI Confidence Interval: (0.1604294710380915, 0.444674730149498)
#  tdsm  seconds_difference 0.4151670500000001
# tdsm perfection neuron numbers 4.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# TDSMSOM Mean: 0.9612
# TDSMSOM  95% Purity Confidence Interval: (0.9346453941223503, 0.9877283027501436)
# TDSMSOM Mean: 0.7671
# TDSMSOM  95% ARI Confidence Interval: (0.6295129181128082, 0.9046060999344704)
# TDSMSOM Mean: 0.7442
# TDSMSOM  95% NMI Confidence Interval: (0.6057084123407673, 0.8827259338452079)
#  tdsm-som  seconds_difference 0.5727459500000001
# best purity baseline  0.7941793638064688
# best ari  baseline 0.2973770241853526
# best nmi  baseline0.3025521005937947
# best purity proposed 0.9611868484362469
# best ari proposed  0.7670595090236393
# best nmi proposed 0.7442171730929876
# all_purity_score_baseline mean 0.7941793638064688
# all_ari_score_ba seline mean 0.2973770241853526
# all_nmi_score_baseline mean 0.3025521005937947
# all_purity_score_tdsmsog mean 0.9611868484362469
# all_ari_score_tdsmsog mean 0.7670595090236393
# all_nmi_score_tdsmsog mean 0.7442171730929876
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
#Unnormalized
import experiment
class_num= 2
dim_num = X.shape[1]
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,5,"Car")
# Out:
# TDSM !!!!!!!!!!!!!!
#  0  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 2
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 4
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 6
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 8
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 10
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 12
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 14
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 16
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 20
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 22
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 24
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 26
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 28
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 30
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 32
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 34
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 36
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 38
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 40
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 42
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 44
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 46
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 48
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 50
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# best purity baseline  0.7690072882633827
# best ari  baseline 0.37584361767902186
# best nmi  baseline0.35261257917502886
# best purity proposed 0.8760794169389292
# best ari proposed  0.5616712440547087
# best nmi proposed 0.4833916539951398
# all_purity_score_baseline mean 0.7690072882633827
# all_ari_score_ba seline mean 0.37584361767902186
# all_nmi_score_baseline mean 0.3526125791750288
# all_purity_score_tdsmsog mean 0.8316418530619084
# all_ari_score_tdsmsog mean 0.46112492308617986
# all_nmi_score_tdsmsog mean 0.378089697621727
# Accuracy Score T-Test
# [-11.46107529]
# [2.42194149e-15]
# ARI Score T-Test
# [-7.24031114]
# [3.15115156e-09]
# NMI Score T-Test
# [-1.97466886]
# [0.05407349]
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
#normalized
import experiment
class_num= 2
dim_num = X.shape[1]
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,5,"Car")
# Out:
# TDSM !!!!!!!!!!!!!!
#  0  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 2
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 4
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 6
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 8
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 10
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 12
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 14
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 16
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 20
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 22
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 24
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 26
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 28
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 30
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 32
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 34
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 36
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 38
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 40
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 42
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 44
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 46
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 48
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 50
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# best purity baseline  0.895826422049091
# best ari  baseline 0.6540457299023812
# best nmi  baseline0.5882111912004625
# best purity proposed 0.8732328055625367
# best ari proposed  0.5332202719218054
# best nmi proposed 0.5008211755368205
# all_purity_score_baseline mean 0.8958264220490909
# all_ari_score_ba seline mean 0.6540457299023812
# all_nmi_score_baseline mean 0.5882111912004625
# all_purity_score_tdsmsog mean 0.831141626874424
# all_ari_score_tdsmsog mean 0.43261960740477867
# all_nmi_score_tdsmsog mean 0.39802168832144047
# Accuracy Score T-Test
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 scope_num = 50
#       5 experiment = experiment.Experiment()
# ----> 6 experiment.Ttest(dataread,class_num, dim_num,scope_num,5,"Car")
#
# File C:\JupyterDoc\FCG\experiment.py:307, in Experiment.Ttest(self, dataread, initial_neuron_num, dim_num, scope_num, nfolder, PltName)
#     302 df2 = pd.DataFrame(all_test_score_tdsmsog_purity, columns = ['all_purity_score_tdsmsog'])
#     305 print("Accuracy Score T-Test")
# --> 307 summary, results = rp.ttest(group1= df1['all_purity_score_baseline'], group1_name= "all_purity_score_baseline",
#     308                                 group2= df2['all_purity_score_tdsmsog'], group2_name= "all_purity_score_tdsmsog")
#     309 print(summary)
#     310 print(results)
#
# File ~\anaconda3\lib\site-packages\researchpy\ttest.py:18, in ttest(group1, group2, group1_name, group2_name, equal_variances, paired, correction)
#      15 def ttest(group1, group2, group1_name= None, group2_name= None, equal_variances= True, paired= False, correction= None):
#      16
#      17     # Joining groups for table and calculating group mean difference
# ---> 18     groups = group1.append(group2, ignore_index= True)
#      19     groups_diff = numpy.mean(group1) - numpy.mean(group2)
#      23     # Deciding which test to use
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6293, in NDFrame.__getattr__(self, name)
#    6286 if (
#    6287     name not in self._internal_names_set
#    6288     and name not in self._metadata
#    6289     and name not in self._accessors
#    6290     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291 ):
#    6292     return self[name]
# -> 6293 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'
