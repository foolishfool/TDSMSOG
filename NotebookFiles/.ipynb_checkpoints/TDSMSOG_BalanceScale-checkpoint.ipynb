# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve()             
CODES_DIR = BASE_DIR.parent / "Codes"
sys.path.insert(0, str(CODES_DIR))

import pandas as pd
import numpy as np
import dataset_read
import experiment
dataread = dataset_read.DATAREAD()
# Out:
# C:\Users\qiang\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=12) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
for item in X.columns:
    dataread.label_encoding(X,item)
dataread.label_encoding(y,"class")

grouped = y.groupby('class')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    
# Calculate sparsity
total_elements = X.size
zero_elements = (X == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

print("Sparsity (%):", sparsity)

dataread.readucidata(X,y,"class")
# Out:
# Category: 0
# 49
# Category: 1
# 288
# Category: 2
# 288
# Sparsity (%): 20.0
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])

# %%
import experiment
class_num=1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,20,"BalanceScale")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM Mean: 0.8273
# TDSM  95% Purity Confidence Interval: (np.float64(0.7993106301535511), np.float64(0.8552256601690298))
# TDSM Mean: 0.5129
# TDSM  95% ARI Confidence Interval: (np.float64(0.4411177000393839), np.float64(0.5846657222121295))
# TDSM Mean: 0.5165
# TDSM  95% NMI Confidence Interval: (np.float64(0.4727904718738947), np.float64(0.5602903415749144))
#  tdsm  seconds_difference 0.12103869999999999
# tdsm perfection neuron numbers 3.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# TDSMSOM Mean: 0.8847
# TDSMSOM  95% Purity Confidence Interval: (np.float64(0.8606786056789133), np.float64(0.9087770394823766))
# TDSMSOM Mean: 0.5838
# TDSMSOM  95% ARI Confidence Interval: (np.float64(0.4888326396665037), np.float64(0.678803097252656))
# TDSMSOM Mean: 0.5614
# TDSMSOM  95% NMI Confidence Interval: (np.float64(0.46965115520664064), np.float64(0.6531561185010198))
#  tdsm-som  seconds_difference 0.13486855
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM Mean: 0.8273
# TDSM  95% Purity Confidence Interval: (np.float64(0.7993106301535511), np.float64(0.8552256601690298))
# TDSM Mean: 0.5129
# TDSM  95% ARI Confidence Interval: (np.float64(0.4411177000393839), np.float64(0.5846657222121295))
# TDSM Mean: 0.5165
# TDSM  95% NMI Confidence Interval: (np.float64(0.4727904718738947), np.float64(0.5602903415749144))
#  tdsm  seconds_difference 0.11502220000000003
# tdsm perfection neuron numbers 3.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# TDSMSOM Mean: 0.8847
# TDSMSOM  95% Purity Confidence Interval: (np.float64(0.8606786056789133), np.float64(0.9087770394823766))
# TDSMSOM Mean: 0.5838
# TDSMSOM  95% ARI Confidence Interval: (np.float64(0.4888326396665037), np.float64(0.678803097252656))
# TDSMSOM Mean: 0.5614
# TDSMSOM  95% NMI Confidence Interval: (np.float64(0.46965115520664064), np.float64(0.6531561185010198))
#  tdsm-som  seconds_difference 0.14752395000000001
# best purity baseline  0.8272681451612904
# best ari  baseline 0.5128917111257567
# best nmi  baseline0.5165404067244046
# best purity proposed 0.884727822580645
# best ari proposed  0.5838178684595798
# best nmi proposed 0.5614036368538302
# all_purity_score_baseline mean 0.8272681451612904
# all_ari_score_ba seline mean 0.5128917111257567
# all_nmi_score_baseline mean 0.5165404067244046
# all_purity_score_tdsmsog mean 0.884727822580645
# all_ari_score_tdsmsog mean 0.5838178684595798
# all_nmi_score_tdsmsog mean 0.5614036368538302
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\qiang\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
