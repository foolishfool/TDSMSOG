# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()
# Out:
# C:\Users\fooli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=76) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
    
print(X.shape)
    
print(y)
# metadata 
#print(car_evaluation.metadata) 
  
# variable information 
#print(car_evaluation.variables)
# Out:
# (12960, 8)
#             class
# 0       recommend
# 1        priority
# 2       not_recom
# 3       recommend
# 4        priority
# ...           ...
# 12955  spec_prior
# 12956   not_recom
# 12957  spec_prior
# 12958  spec_prior
# 12959   not_recom
#
# [12960 rows x 1 columns]

# %%
#csv = pd.read_csv("car.data")

#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))
#Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'], dtype='object')
#Index(['class'], dtype='object')
for item in X.columns:
   # print(item)
    dataread.label_encoding(X,item)
#dataread.label_encoding(X,"maint")
#dataread.label_encoding(X,"doors")
#dataread.label_encoding(X,"persons")
#dataread.label_encoding(X,"lug_boot")
#dataread.label_encoding(X,"safety")
dataread.label_encoding(y,"class")

grouped = y.groupby('class')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = X.size
zero_elements = (X == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)
    
    


dataread.readucidata(X,y,"class")
# Out:
# Category: 0
# 4320
# Category: 1
# 4266
# Category: 2
# 2
# Category: 3
# 4044
# Category: 4
# 328
# Sparsity (%): 31.666666666666664
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# C:\JupyterDoc\FCG\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# C:\JupyterDoc\FCG\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])

# %%
import experiment
class_num=1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,20,"Nusery")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
# TDSM Mean: 0.8622
# TDSM  95% Purity Confidence Interval: (0.8154238498640394, 0.9089588661853436)
# TDSM Mean: 0.6583
# TDSM  95% ARI Confidence Interval: (0.5963911812234287, 0.7201730717464744)
# TDSM Mean: 0.7611
# TDSM  95% NMI Confidence Interval: (0.7239846020130294, 0.7982893887484421)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# TDSMSOM Mean: 0.8971
# TDSMSOM  95% Purity Confidence Interval: (0.8470854427743508, 0.947050359694785)
# TDSMSOM Mean: 0.7653
# TDSMSOM  95% ARI Confidence Interval: (0.6664776522183288, 0.864084368933795)
# TDSMSOM Mean: 0.8128
# TDSMSOM  95% NMI Confidence Interval: (0.7383959140095909, 0.8871798724719445)
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
# TDSM Mean: 0.8622
# TDSM  95% Purity Confidence Interval: (0.8154238498640394, 0.9089588661853436)
# TDSM Mean: 0.6583
# TDSM  95% ARI Confidence Interval: (0.5963911812234287, 0.7201730717464744)
# TDSM Mean: 0.7611
# TDSM  95% NMI Confidence Interval: (0.7239846020130294, 0.7982893887484421)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# TDSMSOM Mean: 0.8971
# TDSMSOM  95% Purity Confidence Interval: (0.8470854427743508, 0.947050359694785)
# TDSMSOM Mean: 0.7653
# TDSMSOM  95% ARI Confidence Interval: (0.6664776522183288, 0.864084368933795)
# TDSMSOM Mean: 0.8128
# TDSMSOM  95% NMI Confidence Interval: (0.7383959140095909, 0.8871798724719445)
# best purity baseline  0.8621913580246915
# best ari  baseline 0.6582821264849515
# best nmi  baseline0.7611369953807358
# best purity proposed 0.8970679012345679
# best ari proposed  0.7652810105760619
# best nmi proposed 0.8127878932407677
# all_purity_score_baseline mean 0.8621913580246915
# all_ari_score_ba seline mean 0.6582821264849515
# all_nmi_score_baseline mean 0.7611369953807358
# all_purity_score_tdsmsog mean 0.8970679012345679
# all_ari_score_tdsmsog mean 0.7652810105760619
# all_nmi_score_tdsmsog mean 0.8127878932407677
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
import experiment
class_num=1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,20,"Nusery")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
# TDSM Mean: 0.8622
# TDSM  95% Purity Confidence Interval: (0.8154238498640394, 0.9089588661853436)
# TDSM Mean: 0.6583
# TDSM  95% ARI Confidence Interval: (0.5963911812234287, 0.7201730717464744)
# TDSM Mean: 0.7611
# TDSM  95% NMI Confidence Interval: (0.7239846020130294, 0.7982893887484421)
#  tdsm  seconds_difference 6.16480835
# tdsm perfection neuron numbers 4.95
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# TDSMSOM Mean: 0.8971
# TDSMSOM  95% Purity Confidence Interval: (0.8470854427743508, 0.947050359694785)
# TDSMSOM Mean: 0.7653
# TDSMSOM  95% ARI Confidence Interval: (0.6664776522183288, 0.864084368933795)
# TDSMSOM Mean: 0.8128
# TDSMSOM  95% NMI Confidence Interval: (0.7383959140095909, 0.8871798724719445)
#  tdsm-som  seconds_difference 14.898661449999997
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 3
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
#  NO Error Data, Finish Training!
# total split_number 4
# TDSM Mean: 0.8622
# TDSM  95% Purity Confidence Interval: (0.8154238498640394, 0.9089588661853436)
# TDSM Mean: 0.6583
# TDSM  95% ARI Confidence Interval: (0.5963911812234287, 0.7201730717464744)
# TDSM Mean: 0.7611
# TDSM  95% NMI Confidence Interval: (0.7239846020130294, 0.7982893887484421)
#  tdsm  seconds_difference 6.8653735
# tdsm perfection neuron numbers 4.95
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# TDSMSOM Mean: 0.8971
# TDSMSOM  95% Purity Confidence Interval: (0.8470854427743508, 0.947050359694785)
# TDSMSOM Mean: 0.7653
# TDSMSOM  95% ARI Confidence Interval: (0.6664776522183288, 0.864084368933795)
# TDSMSOM Mean: 0.8128
# TDSMSOM  95% NMI Confidence Interval: (0.7383959140095909, 0.8871798724719445)
#  tdsm-som  seconds_difference 17.50305865
# best purity baseline  0.8621913580246915
# best ari  baseline 0.6582821264849515
# best nmi  baseline0.7611369953807358
# best purity proposed 0.8970679012345679
# best ari proposed  0.7652810105760619
# best nmi proposed 0.8127878932407677
# all_purity_score_baseline mean 0.8621913580246915
# all_ari_score_ba seline mean 0.6582821264849515
# all_nmi_score_baseline mean 0.7611369953807358
# all_purity_score_tdsmsog mean 0.8970679012345679
# all_ari_score_tdsmsog mean 0.7652810105760619
# all_nmi_score_tdsmsog mean 0.8127878932407677
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
