# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("bi.csv")


dataread.label_encoding(csv,"fNAME")
dataread.label_encoding(csv,"lNAME")
dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"country")
dataread.label_encoding(csv,"residence")
dataread.label_encoding(csv,"prevEducation")

grouped = csv.groupby('prevEducation')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = csv.size
zero_elements = (csv == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)


#dataread.initializedataset(csv,"booking_status")
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,"prevEducation")
# Out:
# Category: 0
# 24
# Category: 1
# 1
# Category: 2
# 1
# Category: 3
# 9
# Category: 4
# 1
# Category: 5
# 5
# Category: 6
# 18
# Category: 7
# 1
# Category: 8
# 16
# Category: 9
# 1
# Sparsity (%): 7.201889020070838

# %%
#confidence interval
import experiment
class_num= 1
dim_num = 10
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,40,"BI")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 7
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
# TDSM Mean: 0.9375
# TDSM  95% Purity Confidence Interval: (0.8856026927163735, 0.9893973072836265)
# TDSM Mean: 0.5500
# TDSM  95% ARI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# TDSM Mean: 0.5500
# TDSM  95% NMI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# TDSMSOM Mean: 0.9500
# TDSMSOM  95% Purity Confidence Interval: (0.9029231878446707, 0.9970768121553292)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% ARI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% NMI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 7
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
# TDSM Mean: 0.9375
# TDSM  95% Purity Confidence Interval: (0.8856026927163735, 0.9893973072836265)
# TDSM Mean: 0.5500
# TDSM  95% ARI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# TDSM Mean: 0.5500
# TDSM  95% NMI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# TDSMSOM Mean: 0.9500
# TDSMSOM  95% Purity Confidence Interval: (0.9029231878446707, 0.9970768121553292)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% ARI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% NMI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# best purity baseline  0.9375
# best ari  baseline 0.55
# best nmi  baseline0.55
# best purity proposed 0.95
# best ari proposed  0.65
# best nmi proposed 0.65
# all_purity_score_baseline mean 0.9375
# all_ari_score_ba seline mean 0.55
# all_nmi_score_baseline mean 0.55
# all_purity_score_tdsmsog mean 0.95
# all_ari_score_tdsmsog mean 0.65
# all_nmi_score_tdsmsog mean 0.65
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
#confidence interval
import experiment
class_num= 1
dim_num = 10
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,40,"BI")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 7
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
# TDSM Mean: 0.9375
# TDSM  95% Purity Confidence Interval: (0.8856026927163735, 0.9893973072836265)
# TDSM Mean: 0.5500
# TDSM  95% ARI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# TDSM Mean: 0.5500
# TDSM  95% NMI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
#  tdsm  seconds_difference 0.041500224999999995
# tdsm perfection neuron numbers 9.875
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# TDSMSOM Mean: 0.9500
# TDSMSOM  95% Purity Confidence Interval: (0.9029231878446707, 0.9970768121553292)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% ARI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% NMI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
#  tdsm-som  seconds_difference 0.15158529999999998
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 7
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
#  NO Error Data, Finish Training!
# total split_number 9
# TDSM Mean: 0.9375
# TDSM  95% Purity Confidence Interval: (0.8856026927163735, 0.9893973072836265)
# TDSM Mean: 0.5500
# TDSM  95% ARI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
# TDSM Mean: 0.5500
# TDSM  95% NMI Confidence Interval: (0.39386387775473086, 0.7061361222452692)
#  tdsm  seconds_difference 0.042688575
# tdsm perfection neuron numbers 9.875
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# TDSMSOM Mean: 0.9500
# TDSMSOM  95% Purity Confidence Interval: (0.9029231878446707, 0.9970768121553292)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% ARI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
# TDSMSOM Mean: 0.6500
# TDSMSOM  95% NMI Confidence Interval: (0.5003052780242991, 0.7996947219757009)
#  tdsm-som  seconds_difference 0.16382655000000002
# best purity baseline  0.9375
# best ari  baseline 0.55
# best nmi  baseline0.55
# best purity proposed 0.95
# best ari proposed  0.65
# best nmi proposed 0.65
# all_purity_score_baseline mean 0.9375
# all_ari_score_ba seline mean 0.55
# all_nmi_score_baseline mean 0.55
# all_purity_score_tdsmsog mean 0.95
# all_ari_score_tdsmsog mean 0.65
# all_nmi_score_tdsmsog mean 0.65
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
import experiment
class_num= 3
dim_num = 10
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,10,"BI")
# Out:
# TDSM !!!!!!!!!!!!!!
#  0  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 5
#  1  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 5
#  2  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  3  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  4  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 5
#  5  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  6  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  7  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  8  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 6
#  9  folder tdsm
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 33
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
#  0  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  1  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  2  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  3  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  4  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
#  5  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  6  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  7  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  8  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
#  9  folder tdsmsog
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# best purity baseline  0.7446428571428572
# best ari  baseline 0.11850240022591448
# best nmi  baseline0.5557665279714292
# best purity proposed 0.7678571428571428
# best ari proposed  0.15845418295878222
# best nmi proposed 0.5592199257462338
# all_purity_score_baseline mean 0.7446428571428573
# all_ari_score_ba seline mean 0.11850240022591448
# all_nmi_score_baseline mean 0.5557665279714292
# all_purity_score_tdsmsog mean 0.7173363095238093
# all_ari_score_tdsmsog mean 0.05867090689629459
# all_nmi_score_tdsmsog mean 0.4897967156505569
# Accuracy Score T-Test
# [6.39830952]
# [7.30559318e-08]
# ARI Score T-Test
# [4.94041876]
# [1.07330147e-05]
# NMI Score T-Test
# [10.48463682]
# [8.842994e-14]
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
