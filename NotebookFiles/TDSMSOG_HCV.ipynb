# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("hcvdat0.csv")
csv = csv.drop(columns=['ID'])
dataread.label_encoding(csv,"Category")
dataread.label_encoding(csv,"Sex")
dataread.replaceNANinDataset(csv)
#dataread.stringToIntHCVDataSet(csv,"Sex")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Category")

# %%
import experiment
class_num= 200
dim_num = 12
scope_num = 300
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
# initila self.weigts shape (200, 12)
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
# neuron number: 200
# initila self.weigts shape (200, 12)
# ***************************SOG ************************
# initila self.weigts shape (200, 2400)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 205
# initila self.weigts shape (205, 12)
# ***************************SOG ************************
# initila self.weigts shape (205, 2460)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 210
# initila self.weigts shape (210, 12)
# ***************************SOG ************************
# initila self.weigts shape (210, 2520)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 215
# initila self.weigts shape (215, 12)
# ***************************SOG ************************
# initila self.weigts shape (215, 2580)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 220
# initila self.weigts shape (220, 12)
# ***************************SOG ************************
# initila self.weigts shape (220, 2640)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 225
# initila self.weigts shape (225, 12)
# ***************************SOG ************************
# initila self.weigts shape (225, 2700)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 230
# initila self.weigts shape (230, 12)
# ***************************SOG ************************
# initila self.weigts shape (230, 2760)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 235
# initila self.weigts shape (235, 12)
# ***************************SOG ************************
# initila self.weigts shape (235, 2820)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 240
# initila self.weigts shape (240, 12)
# ***************************SOG ************************
# initila self.weigts shape (240, 2880)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 245
# initila self.weigts shape (245, 12)
# ***************************SOG ************************
# initila self.weigts shape (245, 2940)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 250
# initila self.weigts shape (250, 12)
# ***************************SOG ************************
# initila self.weigts shape (250, 3000)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 255
# initila self.weigts shape (255, 12)
# ***************************SOG ************************
# initila self.weigts shape (255, 3060)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 260
# initila self.weigts shape (260, 12)
# ***************************SOG ************************
# initila self.weigts shape (260, 3120)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 265
# initila self.weigts shape (265, 12)
# ***************************SOG ************************
# initila self.weigts shape (265, 3180)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 270
# initila self.weigts shape (270, 12)
# ***************************SOG ************************
# initila self.weigts shape (270, 3240)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 275
# initila self.weigts shape (275, 12)
# ***************************SOG ************************
# initila self.weigts shape (275, 3300)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 280
# initila self.weigts shape (280, 12)
# ***************************SOG ************************
# initila self.weigts shape (280, 3360)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 285
# initila self.weigts shape (285, 12)
# ***************************SOG ************************
# initila self.weigts shape (285, 3420)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 290
# initila self.weigts shape (290, 12)
# ***************************SOG ************************
# initila self.weigts shape (290, 3480)
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 295
# initila self.weigts shape (295, 12)
# ***************************SOG ************************
# initila self.weigts shape (295, 3540)
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 300
# initila self.weigts shape (300, 12)
# ***************************SOG ************************
# initila self.weigts shape (300, 3600)
#  NO Error Data, Finish Training!
# total split_number 2
# all_purity_score_baseline mean 0.951086956521739
# all_ari_score_baseline mean 0.8056008123971002
# all_nmi_score_baseline mean 0.6513566339696966
# all_purity_score_tdsmsog mean 0.8923395445134574
# all_ari_score_tdsmsog mean 0.28692805835678387
# all_nmi_score_tdsmsog mean 0.16721386302621374
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  21.0  0.951087  1.137640e-16  2.482534e-17
# 1   all_purity_score_tdsmsog  21.0  0.892340  6.571155e-03  1.433944e-03
# 2                   combined  42.0  0.921713  3.008193e-02  4.641742e-03
#
#    95% Conf.  Interval
# 0   0.951087  0.951087
# 1   0.889348  0.895331
# 2   0.912339  0.931087
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  5.870000e-02
# 1                              Degrees of freedom =   4.000000e+01
# 2                                               t =   4.096910e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.264330e+01
# 7                                       Hedge's g =   1.240480e+01
# 8                                  Glass's delta1 =   5.163972e+14
# 9                                Point-Biserial r =   9.883000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  21.0  0.805601  1.137640e-16  2.482534e-17
# 1   all_ari_score_tdsmsog  21.0  0.286928  6.864454e-02  1.497947e-02
# 2                combined  42.0  0.546264  2.668226e-01  4.117162e-02
#
#    95% Conf.  Interval
# 0   0.805601  0.805601
# 1   0.255681  0.318175
# 2   0.463117  0.629412
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s...  5.187000e-01
# 1                              Degrees of freedom =   4.000000e+01
# 2                                               t =   3.462560e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.068570e+01
# 7                                       Hedge's g =   1.048410e+01
# 8                                  Glass's delta1 =   4.559199e+15
# 9                                Point-Biserial r =   9.837000e-01
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  21.0  0.651357  1.137640e-16  2.482534e-17
# 1   all_nmi_score_tdsmsog  21.0  0.167214  5.043998e-02  1.100691e-02
# 2                combined  42.0  0.409285  2.475255e-01  3.819401e-02
#
#    95% Conf.  Interval
# 0   0.651357  0.651357
# 1   0.144254  0.190174
# 2   0.332151  0.486420
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  4.841000e-01
# 1                              Degrees of freedom =   4.000000e+01
# 2                                               t =   4.398540e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.357420e+01
# 7                                       Hedge's g =   1.331810e+01
# 8                                  Glass's delta1 =   4.255676e+15
# 9                                Point-Biserial r =   9.898000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
class_num= 100
dim_num = 12
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
# initila self.weigts shape (2000, 12)
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.9021739130434783
#  self.test_score_W0_n 0.5074478755379034
#  self.test_score_W0_a 0.7236896925256229
# SOG TDSM !!!!!!!!!!!!!!
# initila self.weigts shape (2000, 12)
# ***************************  TDSMSOG ************************
# Comparision.train_data_embedding_tdsmsog shape (431, 24)
# initila self.weigts shape (2000, 24)
#  NO Error Data, Finish Training!
# total split_number 3
#  self.test_score_W1_p 0.8641304347826086
#  self.test_score_W1_n 0.05156500109061844
#  self.test_score_W1_a -0.04827218856115587
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 100
dim_num = 12
scope_num = 120
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 4
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.907608695652174
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 5
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 7
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 9
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 11
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 13
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 15
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 17
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 19
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 21
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 23
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 25
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 27
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 29
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 31
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 33
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 35
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 37
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 39
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 41
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 43
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 45
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 47
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 49
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# all_purity_score_baseline mean 0.9076086956521744
# all_ari_score_baseline mean 0.8631086877339377
# all_nmi_score_baseline mean 0.6142532601307632
# all_purity_score_tdsmsog mean 0.8435727788279772
# all_ari_score_tdsmsog mean 0.20181480669163113
# all_nmi_score_tdsmsog mean 0.12925588387529247
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  23.0  0.907609  4.540700e-16  9.468014e-17
# 1   all_purity_score_tdsmsog  23.0  0.843573  7.501454e-03  1.564161e-03
# 2                   combined  46.0  0.875591  3.279392e-02  4.835200e-03
#
#    95% Conf.  Interval
# 0   0.907609  0.907609
# 1   0.840329  0.846817
# 2   0.865852  0.885329
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  6.400000e-02
# 1                              Degrees of freedom =   4.400000e+01
# 2                                               t =   4.093950e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.207240e+01
# 7                                       Hedge's g =   1.186540e+01
# 8                                  Glass's delta1 =   1.410265e+14
# 9                                Point-Biserial r =   9.871000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  23.0  0.863109  1.135175e-16  2.367003e-17
# 1   all_ari_score_tdsmsog  23.0  0.201815  5.009279e-02  1.044507e-02
# 2                combined  46.0  0.532462  3.361304e-01  4.955973e-02
#
#    95% Conf.  Interval
# 0   0.863109  0.863109
# 1   0.180153  0.223477
# 2   0.432643  0.632280
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s...  6.613000e-01
# 1                              Degrees of freedom =   4.400000e+01
# 2                                               t =   6.331160e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.866960e+01
# 7                                       Hedge's g =   1.834950e+01
# 8                                  Glass's delta1 =   5.825480e+15
# 9                                Point-Biserial r =   9.946000e-01
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  23.0  0.614253  2.270350e-16  4.734007e-17
# 1   all_nmi_score_tdsmsog  23.0  0.129256  3.689031e-02  7.692161e-03
# 2                combined  46.0  0.371755  2.465314e-01  3.634907e-02
#
#    95% Conf.  Interval
# 0   0.614253  0.614253
# 1   0.113303  0.145208
# 2   0.298544  0.444965
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  4.850000e-01
# 1                              Degrees of freedom =   4.400000e+01
# 2                                               t =   6.305090e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.859270e+01
# 7                                       Hedge's g =   1.827400e+01
# 8                                  Glass's delta1 =   2.136223e+15
# 9                                Point-Biserial r =   9.945000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
