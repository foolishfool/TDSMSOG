# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"Hair Loss")

# %%
import experiment
class_num= 2
dim_num = 11
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
# neuron number: 2
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 4
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 6
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 8
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 10
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 12
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 14
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 16
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 20
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 22
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 24
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 26
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 28
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 30
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 32
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 34
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 36
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 38
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 40
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 42
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 44
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 46
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 48
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 50
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# best purity baseline  0.5250836120401338
# best ari  baseline 0
# best nmi  baseline0.0015649982348836852
# best purity proposed 0.5752508361204013
# best ari proposed  0.019373160158391623
# best nmi proposed 0.01747367644785559
# all_purity_score_baseline mean 0.5250836120401339
# all_ari_score_ba seline mean -0.0008283632772760083
# all_nmi_score_baseline mean 0.0015649982348836852
# all_purity_score_tdsmsog mean 0.5307023411371237
# all_ari_score_tdsmsog mean -0.0005970429229931086
# all_nmi_score_tdsmsog mean 0.0038490562100799443
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  25.0  0.525084  1.133117e-16  2.266233e-17
# 1   all_purity_score_tdsmsog  25.0  0.530702  1.242870e-02  2.485740e-03
# 2                   combined  50.0  0.527893  9.149515e-03  1.293937e-03
#
#    95% Conf.  Interval
# 0   0.525084  0.525084
# 1   0.525572  0.535833
# 2   0.525293  0.530493
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu... -5.600000e-03
# 1                              Degrees of freedom =   4.800000e+01
# 2                                               t =  -2.260400e+00
# 3                           Two side test p value =   2.840000e-02
# 4                          Difference < 0 p value =   1.420000e-02
# 5                          Difference > 0 p value =   9.858000e-01
# 6                                       Cohen's d =  -6.393000e-01
# 7                                       Hedge's g =  -6.293000e-01
# 8                                  Glass's delta1 =  -4.958650e+13
# 9                                Point-Biserial r =  -3.102000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  25.0 -0.000828  1.106559e-19  2.213118e-20
# 1   all_ari_score_tdsmsog  25.0 -0.000597  5.300762e-03  1.060152e-03
# 2                combined  50.0 -0.000713  3.711600e-03  5.248995e-04
#
#    95% Conf.  Interval
# 0  -0.000828 -0.000828
# 1  -0.002785  0.001591
# 2  -0.001768  0.000342
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -2.000000e-04
# 1                              Degrees of freedom =   4.800000e+01
# 2                                               t =  -2.182000e-01
# 3                           Two side test p value =   8.282000e-01
# 4                          Difference < 0 p value =   4.141000e-01
# 5                          Difference > 0 p value =   5.859000e-01
# 6                                       Cohen's d =  -6.170000e-02
# 7                                       Hedge's g =  -6.070000e-02
# 8                                  Glass's delta1 =  -2.090447e+15
# 9                                Point-Biserial r =  -3.150000e-02
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  25.0  0.001565  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  25.0  0.003849  0.004705  0.000941   0.001907
# 2                combined  50.0  0.002707  0.003489  0.000493   0.001716
#
#    Interval
# 0       NaN
# 1  0.005791
# 2  0.003699
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0023
# 1                              Degrees of freedom =   48.0000
# 2                                               t =   -2.4274
# 3                           Two side test p value =    0.0190
# 4                          Difference < 0 p value =    0.0095
# 5                          Difference > 0 p value =    0.9905
# 6                                       Cohen's d =   -0.6866
# 7                                       Hedge's g =   -0.6758
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.3307
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 2
dim_num = 11
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.5652173913043478
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 2
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 4
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 6
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 10
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 12
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 14
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 16
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 18
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 4
# neuron number: 20
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 22
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 24
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 26
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 28
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 30
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 32
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 34
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 36
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 38
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 40
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 42
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 44
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 46
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 48
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 50
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# all_purity_score_baseline mean 0.5652173913043478
# all_ari_score_baseline mean 0.013704747758459614
# all_nmi_score_baseline mean 0.01234608861730489
# all_purity_score_tdsmsog mean 0.5359197324414715
# all_ari_score_tdsmsog mean 0.003653686921398438
# all_nmi_score_tdsmsog mean 0.006238274672597927
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  25.0  0.565217  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  25.0  0.535920  0.023177  0.004635   0.526353
# 2                   combined  50.0  0.550569  0.021956  0.003105   0.544329
#
#    Interval
# 0       NaN
# 1  0.545487
# 2  0.556808
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...   0.0293
# 1                              Degrees of freedom =   48.0000
# 2                                               t =    6.3204
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    1.7877
# 7                                       Hedge's g =    1.7596
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.6740
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  25.0  0.013705  1.770495e-18  3.540989e-19
# 1   all_ari_score_tdsmsog  25.0  0.003654  8.250663e-03  1.650133e-03
# 2                combined  50.0  0.008679  7.688529e-03  1.087322e-03
#
#    95% Conf.  Interval
# 0   0.013705  0.013705
# 1   0.000248  0.007059
# 2   0.006494  0.010864
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s...  1.010000e-02
# 1                              Degrees of freedom =   4.800000e+01
# 2                                               t =   6.091100e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.722800e+00
# 7                                       Hedge's g =   1.695800e+00
# 8                                  Glass's delta1 =   5.676979e+15
# 9                                Point-Biserial r =   6.603000e-01
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  25.0  0.012346  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  25.0  0.006238  0.006491  0.001298   0.003559
# 2                combined  50.0  0.009292  0.005491  0.000777   0.007732
#
#    Interval
# 0       NaN
# 1  0.008918
# 2  0.010853
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...   0.0061
# 1                              Degrees of freedom =   48.0000
# 2                                               t =    4.7050
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    1.3308
# 7                                       Hedge's g =    1.3099
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.5618
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
