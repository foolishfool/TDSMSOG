# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve()             
CODES_DIR = BASE_DIR.parent / "Codes"
sys.path.insert(0, str(CODES_DIR))

import pandas as pd
import numpy as np
import dataset_read
import experiment
dataread = dataset_read.DATAREAD()
# Out:
# C:\Users\qiang\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
csv = pd.read_csv(r"..\Datasets\Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])

dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")

grouped = csv.groupby('Hair Loss')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = csv.size
zero_elements = (csv == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)

dataread.initializedataset(csv,"Hair Loss")
# Out:
# Category: 0
# 502
# Category: 1
# 497
# Sparsity (%): 34.22589255922589

# %%
import experiment
class_num= 1
dim_num = 11
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,25,"HairFall")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM Mean: 0.5897
# TDSM  95% Purity Confidence Interval: (np.float64(0.565407399924534), np.float64(0.6139772154600814))
# TDSM Mean: 0.0026
# TDSM  95% ARI Confidence Interval: (np.float64(-0.0163191156325296), np.float64(0.021560585527203864))
# TDSM Mean: 0.0213
# TDSM  95% NMI Confidence Interval: (np.float64(0.006483777130269106), np.float64(0.03602413627546332))
#  tdsm  seconds_difference 0.18128747999999997
# tdsm perfection neuron numbers 2.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# TDSMSOM Mean: 0.5967
# TDSMSOM  95% Purity Confidence Interval: (np.float64(0.5770727207702804), np.float64(0.6163118946143349))
# TDSMSOM Mean: 0.0059
# TDSMSOM  95% ARI Confidence Interval: (np.float64(-0.007471005887218694), np.float64(0.01919812151103915))
# TDSMSOM Mean: 0.0221
# TDSMSOM  95% NMI Confidence Interval: (np.float64(0.012638884959256642), np.float64(0.03153517824109459))
#  tdsm-som  seconds_difference 0.2505
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM Mean: 0.5897
# TDSM  95% Purity Confidence Interval: (np.float64(0.565407399924534), np.float64(0.6139772154600814))
# TDSM Mean: 0.0026
# TDSM  95% ARI Confidence Interval: (np.float64(-0.0163191156325296), np.float64(0.021560585527203864))
# TDSM Mean: 0.0213
# TDSM  95% NMI Confidence Interval: (np.float64(0.006483777130269106), np.float64(0.03602413627546332))
#  tdsm  seconds_difference 0.2166708
# tdsm perfection neuron numbers 2.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# TDSMSOM Mean: 0.5967
# TDSMSOM  95% Purity Confidence Interval: (np.float64(0.5770727207702804), np.float64(0.6163118946143349))
# TDSMSOM Mean: 0.0059
# TDSMSOM  95% ARI Confidence Interval: (np.float64(-0.007471005887218694), np.float64(0.01919812151103915))
# TDSMSOM Mean: 0.0221
# TDSMSOM  95% NMI Confidence Interval: (np.float64(0.012638884959256642), np.float64(0.03153517824109459))
#  tdsm-som  seconds_difference 0.27925048
# best purity baseline  0.5896923076923077
# best ari  baseline 0.002620734947337133
# best nmi  baseline0.02125395670286621
# best purity proposed 0.5966923076923076
# best ari proposed  0.005863557811910228
# best nmi proposed 0.022087031600175618
# all_purity_score_baseline mean 0.5896923076923077
# all_ari_score_ba seline mean 0.002620734947337133
# all_nmi_score_baseline mean 0.02125395670286621
# all_purity_score_tdsmsog mean 0.5966923076923076
# all_ari_score_tdsmsog mean 0.005863557811910228
# all_nmi_score_tdsmsog mean 0.022087031600175618
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\qiang\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:611: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)
