# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
#csv = pd.read_csv("hcvdat0.csv")
#csv = csv.drop(columns=['ID'])
#dataread.replaceNANinDataset(csv)
#dataread.stringToIntHCVDataSet(csv,"Category")
#dataread.stringToIntHCVDataSet(csv,"Sex")
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)
#dataread.initializedataset(csv_training,csv_test,"Category")


csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"time_spent")

# %%
import experiment
class_num= 3
dim_num = 11
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 12
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 16
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 15
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 14
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 14
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 12
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 12
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 33
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# best purity baseline  0.19333333333333333
# best ari  baseline 0
# best nmi  baseline0.03878588366201631
# best purity proposed 0.23
# best ari proposed  0.01257322501092358
# best nmi proposed 0.0764075974188271
# all_purity_score_baseline mean 0.19333333333333333
# all_ari_score_ba seline mean -0.005929744721504269
# all_nmi_score_baseline mean 0.03878588366201631
# all_purity_score_tdsmsog mean 0.20666666666666664
# all_ari_score_tdsmsog mean 0.002039934257147377
# all_nmi_score_tdsmsog mean 0.05899993016830642
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  24.0  0.193333  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  24.0  0.206667  0.012158  0.002482   0.201533
# 2                   combined  48.0  0.200000  0.010850  0.001566   0.196849
#
#    Interval
# 0       NaN
# 1  0.211801
# 2  0.203151
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0133
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -5.3724
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.5509
# 7                                       Hedge's g =   -1.5255
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.6209
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  24.0 -0.005930  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  24.0  0.002040  0.005367  0.001096  -0.000227
# 2                combined  48.0 -0.001945  0.005506  0.000795  -0.003544
#
#    Interval
# 0       NaN
# 1  0.004306
# 2 -0.000346
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.0080
# 1                              Degrees of freedom =   46.0000
# 2                                               t =   -7.2741
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.0999
# 7                                       Hedge's g =   -2.0654
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7314
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  24.0  0.038786  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  24.0  0.059000  0.009775  0.001995   0.054872
# 2                combined  48.0  0.048893  0.012292  0.001774   0.045324
#
#    Interval
# 0       NaN
# 1  0.063127
# 2  0.052462
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.0202
# 1                              Degrees of freedom =   46.0000
# 2                                               t =  -10.1309
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.9246
# 7                                       Hedge's g =   -2.8766
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8310
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment
class_num= 3
dim_num = 11
scope_num = 150
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 12
# TDSM !!!!!!!!!!!!!!
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 16
# neuron number: 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 13
# neuron number: 13
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 12
# neuron number: 18
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 23
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 28
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 33
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 38
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 43
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 48
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 53
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 58
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 63
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 68
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 73
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 78
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 83
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 88
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 93
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 98
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 103
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 108
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 113
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 118
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 123
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 128
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 133
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 138
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 143
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 148
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# all_purity_score_baseline mean 0.1966666666666666
# all_ari_score_baseline mean -0.0051535231460692835
# all_nmi_score_baseline mean 0.04248406545897751
# all_purity_score_tdsmsog mean 0.20199999999999999
# all_ari_score_tdsmsog mean -0.0016047975723217764
# all_nmi_score_tdsmsog mean 0.053518530175666344
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  30.0  0.196667  5.646013e-17  1.030816e-17
# 1   all_purity_score_tdsmsog  30.0  0.202000  8.469010e-03  1.546223e-03
# 2                   combined  60.0  0.199333  6.518119e-03  8.414855e-04
#
#    95% Conf.  Interval
# 0   0.196667  0.196667
# 1   0.198838  0.205162
# 2   0.197650  0.201017
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu... -5.300000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.449300e+00
# 3                           Two side test p value =   1.100000e-03
# 4                          Difference < 0 p value =   5.000000e-04
# 5                          Difference > 0 p value =   9.995000e-01
# 6                                       Cohen's d =  -8.906000e-01
# 7                                       Hedge's g =  -8.790000e-01
# 8                                  Glass's delta1 =  -9.446194e+13
# 9                                Point-Biserial r =  -4.126000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  30.0 -0.005154  1.764379e-18  3.221301e-19
# 1   all_ari_score_tdsmsog  30.0 -0.001605  3.966987e-03  7.242693e-04
# 2                combined  60.0 -0.003379  3.307091e-03  4.269436e-04
#
#    95% Conf.  Interval
# 0  -0.005154 -0.005154
# 1  -0.003086 -0.000124
# 2  -0.004233 -0.002525
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -3.500000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -4.899700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.265100e+00
# 7                                       Hedge's g =  -1.248700e+00
# 8                                  Glass's delta1 =  -2.011317e+15
# 9                                Point-Biserial r =  -5.411000e-01
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  30.0  0.042484  1.411503e-17  2.577041e-18
# 1   all_nmi_score_tdsmsog  30.0  0.053519  8.816334e-03  1.609635e-03
# 2                combined  60.0  0.048001  8.316306e-03  1.073631e-03
#
#    95% Conf.  Interval
# 0   0.042484  0.042484
# 1   0.050226  0.056811
# 2   0.045853  0.050150
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s... -1.100000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -6.855300e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.770000e+00
# 7                                       Hedge's g =  -1.747000e+00
# 8                                  Glass's delta1 =  -7.817527e+14
# 9                                Point-Biserial r =  -6.690000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
