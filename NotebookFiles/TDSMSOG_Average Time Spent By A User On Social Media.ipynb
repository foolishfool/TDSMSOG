# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
#csv = pd.read_csv("hcvdat0.csv")
#csv = csv.drop(columns=['ID'])
#dataread.replaceNANinDataset(csv)
#dataread.stringToIntHCVDataSet(csv,"Category")
#dataread.stringToIntHCVDataSet(csv,"Sex")
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)
#dataread.initializedataset(csv_training,csv_test,"Category")


csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")

grouped = csv.groupby('time_spent')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = csv.size
zero_elements = (csv == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)
#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,"time_spent")

#csv_test = csv.sample(int(csv.shape[0]*0.3))
#csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,"time_spent")
# Out:
# Category: 1
# 99
# Category: 2
# 112
# Category: 3
# 107
# Category: 4
# 120
# Category: 5
# 125
# Category: 6
# 110
# Category: 7
# 107
# Category: 8
# 109
# Category: 9
# 111
# Sparsity (%): 29.025000000000002

# %%
#N1

import experiment
class_num= 1
dim_num = 11
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,50,"Average")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM Mean: 0.4980
# TDSM  95% Purity Confidence Interval: (0.4837339942388208, 0.5122660057611793)
# TDSM Mean: -0.0096
# TDSM  95% ARI Confidence Interval: (-0.025046476389471314, 0.005811421805282298)
# TDSM Mean: 0.5413
# TDSM  95% NMI Confidence Interval: (0.5273272399454664, 0.5552978262634446)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# TDSMSOM Mean: 0.5080
# TDSMSOM  95% Purity Confidence Interval: (0.4897766579576339, 0.5262233420423661)
# TDSMSOM Mean: -0.0018
# TDSMSOM  95% ARI Confidence Interval: (-0.02289909844700255, 0.01924493122267906)
# TDSMSOM Mean: 0.5499
# TDSMSOM  95% NMI Confidence Interval: (0.5327592581765771, 0.5669459344561495)
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM Mean: 0.4980
# TDSM  95% Purity Confidence Interval: (0.4837339942388208, 0.5122660057611793)
# TDSM Mean: -0.0096
# TDSM  95% ARI Confidence Interval: (-0.025046476389471314, 0.005811421805282298)
# TDSM Mean: 0.5413
# TDSM  95% NMI Confidence Interval: (0.5273272399454664, 0.5552978262634446)
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# TDSMSOM Mean: 0.5080
# TDSMSOM  95% Purity Confidence Interval: (0.4897766579576339, 0.5262233420423661)
# TDSMSOM Mean: -0.0018
# TDSMSOM  95% ARI Confidence Interval: (-0.02289909844700255, 0.01924493122267906)
# TDSMSOM Mean: 0.5499
# TDSMSOM  95% NMI Confidence Interval: (0.5327592581765771, 0.5669459344561495)
# best purity baseline  0.49800000000000005
# best ari  baseline 0
# best nmi  baseline0.5413125331044555
# best purity proposed 0.508
# best ari proposed  0
# best nmi proposed 0.5498525963163633
# all_purity_score_baseline mean 0.49800000000000005
# all_ari_score_ba seline mean -0.009617527292094507
# all_nmi_score_baseline mean 0.5413125331044555
# all_purity_score_tdsmsog mean 0.508
# all_ari_score_tdsmsog mean -0.001827083612161745
# all_nmi_score_tdsmsog mean 0.5498525963163633
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
#N1

import experiment
class_num= 1
dim_num = 11
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,50,"Average")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM Mean: 0.4980
# TDSM  95% Purity Confidence Interval: (0.4837339942388208, 0.5122660057611793)
# TDSM Mean: -0.0096
# TDSM  95% ARI Confidence Interval: (-0.025046476389471314, 0.005811421805282298)
# TDSM Mean: 0.5413
# TDSM  95% NMI Confidence Interval: (0.5273272399454664, 0.5552978262634446)
#  tdsm  seconds_difference 0.8875363199999999
# tdsm perfection neuron numbers 9.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# TDSMSOM Mean: 0.5080
# TDSMSOM  95% Purity Confidence Interval: (0.4897766579576339, 0.5262233420423661)
# TDSMSOM Mean: -0.0018
# TDSMSOM  95% ARI Confidence Interval: (-0.02289909844700255, 0.01924493122267906)
# TDSMSOM Mean: 0.5499
# TDSMSOM  95% NMI Confidence Interval: (0.5327592581765771, 0.5669459344561495)
#  tdsm-som  seconds_difference 1.9536847
# experiment number: 2
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM Mean: 0.4980
# TDSM  95% Purity Confidence Interval: (0.4837339942388208, 0.5122660057611793)
# TDSM Mean: -0.0096
# TDSM  95% ARI Confidence Interval: (-0.025046476389471314, 0.005811421805282298)
# TDSM Mean: 0.5413
# TDSM  95% NMI Confidence Interval: (0.5273272399454664, 0.5552978262634446)
#  tdsm  seconds_difference 0.91632524
# tdsm perfection neuron numbers 9.0
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# TDSMSOM Mean: 0.5080
# TDSMSOM  95% Purity Confidence Interval: (0.4897766579576339, 0.5262233420423661)
# TDSMSOM Mean: -0.0018
# TDSMSOM  95% ARI Confidence Interval: (-0.02289909844700255, 0.01924493122267906)
# TDSMSOM Mean: 0.5499
# TDSMSOM  95% NMI Confidence Interval: (0.5327592581765771, 0.5669459344561495)
#  tdsm-som  seconds_difference 1.90938438
# best purity baseline  0.49800000000000005
# best ari  baseline 0
# best nmi  baseline0.5413125331044555
# best purity proposed 0.508
# best ari proposed  0
# best nmi proposed 0.5498525963163633
# all_purity_score_baseline mean 0.49800000000000005
# all_ari_score_ba seline mean -0.009617527292094507
# all_nmi_score_baseline mean 0.5413125331044555
# all_purity_score_tdsmsog mean 0.508
# all_ari_score_tdsmsog mean -0.001827083612161745
# all_nmi_score_tdsmsog mean 0.5498525963163633
# Accuracy Score T-Test
# [-inf]
# [0.]
# ARI Score T-Test
# [-inf]
# [0.]
# NMI Score T-Test
# [-inf]
# [0.]
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:551: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
import experiment
class_num= 3
dim_num = 11
scope_num = 150
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 12
# TDSM !!!!!!!!!!!!!!
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 3
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 16
# neuron number: 8
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 13
# neuron number: 13
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 12
# neuron number: 18
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 23
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 28
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 33
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 38
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 43
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 48
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 53
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 58
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 63
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 68
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 73
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 78
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 83
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 88
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 93
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 98
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 103
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 108
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 113
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 118
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 7
# neuron number: 123
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# neuron number: 128
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 133
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 138
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 143
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 5
# neuron number: 148
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 6
# all_purity_score_baseline mean 0.1966666666666666
# all_ari_score_baseline mean -0.0051535231460692835
# all_nmi_score_baseline mean 0.04248406545897751
# all_purity_score_tdsmsog mean 0.20199999999999999
# all_ari_score_tdsmsog mean -0.0016047975723217764
# all_nmi_score_tdsmsog mean 0.053518530175666344
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  30.0  0.196667  5.646013e-17  1.030816e-17
# 1   all_purity_score_tdsmsog  30.0  0.202000  8.469010e-03  1.546223e-03
# 2                   combined  60.0  0.199333  6.518119e-03  8.414855e-04
#
#    95% Conf.  Interval
# 0   0.196667  0.196667
# 1   0.198838  0.205162
# 2   0.197650  0.201017
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu... -5.300000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.449300e+00
# 3                           Two side test p value =   1.100000e-03
# 4                          Difference < 0 p value =   5.000000e-04
# 5                          Difference > 0 p value =   9.995000e-01
# 6                                       Cohen's d =  -8.906000e-01
# 7                                       Hedge's g =  -8.790000e-01
# 8                                  Glass's delta1 =  -9.446194e+13
# 9                                Point-Biserial r =  -4.126000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  30.0 -0.005154  1.764379e-18  3.221301e-19
# 1   all_ari_score_tdsmsog  30.0 -0.001605  3.966987e-03  7.242693e-04
# 2                combined  60.0 -0.003379  3.307091e-03  4.269436e-04
#
#    95% Conf.  Interval
# 0  -0.005154 -0.005154
# 1  -0.003086 -0.000124
# 2  -0.004233 -0.002525
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s... -3.500000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -4.899700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.265100e+00
# 7                                       Hedge's g =  -1.248700e+00
# 8                                  Glass's delta1 =  -2.011317e+15
# 9                                Point-Biserial r =  -5.411000e-01
# NMI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_nmi_score_baseline  30.0  0.042484  1.411503e-17  2.577041e-18
# 1   all_nmi_score_tdsmsog  30.0  0.053519  8.816334e-03  1.609635e-03
# 2                combined  60.0  0.048001  8.316306e-03  1.073631e-03
#
#    95% Conf.  Interval
# 0   0.042484  0.042484
# 1   0.050226  0.056811
# 2   0.045853  0.050150
#                                   Independent t-test       results
# 0  Difference (all_nmi_score_baseline - all_nmi_s... -1.100000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -6.855300e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.770000e+00
# 7                                       Hedge's g =  -1.747000e+00
# 8                                  Glass's delta1 =  -7.817527e+14
# 9                                Point-Biserial r =  -6.690000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
