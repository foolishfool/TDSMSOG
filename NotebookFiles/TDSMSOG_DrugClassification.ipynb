# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("drug200.csv")
#csv = csv.drop(columns=['ID'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"BP")
dataread.label_encoding(csv,"Cholesterol")
dataread.label_encoding(csv,"Drug")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"Drug")

# %%
import experiment
class_num= 100
dim_num = 5
scope_num = 150
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
# initila self.weigts shape (100, 5)
#  NO Error Data, Finish Training!
# total split_number 2
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.6
#  self.test_score_W0_n 0.29124180179948594
#  self.test_score_W0_a 0.26775413365941836
# SOG TDSM !!!!!!!!!!!!!!
# initila self.weigts shape (100, 5)
# ***************************  TDSMSOG ************************
# Comparision.train_data_embedding_tdsmsog shape (140, 15)
# initila self.weigts shape (100, 15)
#  NO Error Data, Finish Training!
# total split_number 2
#  self.test_score_W1_p 0.5166666666666667
#  self.test_score_W1_n 0.18422216443905273
#  self.test_score_W1_a 0.006221511330292731
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 100
dim_num = 5
scope_num = 150
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 3
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.8
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 100
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 102
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 104
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 106
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 108
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 110
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 112
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 114
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 116
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 118
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 120
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 122
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 124
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 126
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 128
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 130
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 132
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 134
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 136
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 138
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 140
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 142
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 144
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 146
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 148
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 150
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# all_purity_score_baseline mean 0.8000000000000002
# all_ari_score_baseline mean 0.6505821795663997
# all_nmi_score_baseline mean 0.5834633584406722
# all_purity_score_tdsmsog mean 0.5461538461538461
# all_ari_score_tdsmsog mean 0.024893621866805042
# all_nmi_score_tdsmsog mean 0.21460719399704734
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  26.0  0.800000  1.132210e-16  2.220446e-17
# 1   all_purity_score_tdsmsog  26.0  0.546154  2.955511e-02  5.796233e-03
# 2                   combined  52.0  0.673077  1.298211e-01  1.800295e-02
#
#    95% Conf.  Interval
# 0   0.800000  0.800000
# 1   0.534216  0.558091
# 2   0.636934  0.709219
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  2.538000e-01
# 1                              Degrees of freedom =   5.000000e+01
# 2                                               t =   4.379500e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.214660e+01
# 7                                       Hedge's g =   1.196340e+01
# 8                                  Glass's delta1 =   2.242042e+15
# 9                                Point-Biserial r =   9.872000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  26.0  0.650582  1.132210e-16  2.220446e-17
# 1   all_ari_score_tdsmsog  26.0  0.024894  3.525163e-02  6.913414e-03
# 2                combined  52.0  0.337738  3.168592e-01  4.394046e-02
#
#    95% Conf.  Interval
# 0   0.650582  0.650582
# 1   0.010655  0.039132
# 2   0.249524  0.425952
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s...  6.257000e-01
# 1                              Degrees of freedom =   5.000000e+01
# 2                                               t =   9.050360e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.510120e+01
# 7                                       Hedge's g =   2.472280e+01
# 8                                  Glass's delta1 =   5.526260e+15
# 9                                Point-Biserial r =   9.970000e-01
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  26.0  0.583463  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  26.0  0.214607  0.032395  0.006353   0.201523
# 2                combined  52.0  0.399035  0.187604  0.026016   0.346806
#
#    Interval
# 0       NaN
# 1  0.227692
# 2  0.451264
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...   0.3689
# 1                              Degrees of freedom =   50.0000
# 2                                               t =   58.0586
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =   16.1026
# 7                                       Hedge's g =   15.8598
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.9927
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
