# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve()             
CODES_DIR = BASE_DIR.parent / "Codes"
sys.path.insert(0, str(CODES_DIR))

import pandas as pd
import numpy as np
import dataset_read

import experiment
dataread = dataset_read.DATAREAD()

# %%
from ucimlrepo import fetch_ucirepo  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
for item in X.columns:
    dataread.label_encoding(X,item)

dataread.label_encoding(y,"poisonous")

grouped = y.groupby('poisonous')

# Iterate through groups
for category, group in grouped:
    print(f"Category: {category}")
    print(len(group))
    


# Calculate sparsity
total_elements = X.size
zero_elements = (X == 0).sum().sum()
sparsity = (zero_elements / total_elements) * 100

#print("Class Distribution:", class_distribution)
print("Sparsity (%):", sparsity)
    

dataread.readucidata(X,y,"poisonous")
# Out:
# Category: 0
# 4208
# Category: 1
# 3916
# Sparsity (%): 25.94445190457007
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = X[name].astype(str).str.strip()
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[name] = le.fit_transform(X[name])
# D:\JupyterDoc\TDSMSOG\Codes\dataset_read.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import experiment
class_num= 1
dim_num = X.shape[1]
scope_num = 2
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num,15,"Mushroom")
# Out:
# experiment number: 1
# TDSM !!!!!!!!!!!!!!
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM Mean: 0.9989
# ...
