# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   

#csv = csv.sample(int(csv.shape[0]*1))
#csv2 = csv2.sample(int(csv.shape[0]*1))



csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])



dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Ever_Married")
dataread.label_encoding(csv,"Graduated")
dataread.label_encoding(csv,"Profession")
dataread.label_encoding(csv,"Spending_Score")
dataread.label_encoding(csv,"Var_1")
dataread.label_encoding(csv,"Family_Size")
dataread.label_encoding(csv,"Work_Experience")



dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Ever_Married")
dataread.label_encoding(csv2,"Graduated")
dataread.label_encoding(csv2,"Profession")
dataread.label_encoding(csv2,"Spending_Score")
dataread.label_encoding(csv2,"Var_1")
dataread.label_encoding(csv2,"Family_Size")
dataread.label_encoding(csv2,"Work_Experience")



csv_training = csv.sample(int(csv.shape[0]))

csv_test = csv2


dataread.initializedataset(csv_training,csv_test,"Var_1")

# %%
import experiment
class_num= 3
dim_num = 8
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 8
# TDSM !!!!!!!!!!!!!!
# neuron number: 3
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 8
# neuron number: 5
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 7
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 9
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 11
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 13
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 15
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 17
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 19
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 21
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 11
# neuron number: 23
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 25
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 27
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 29
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 31
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 35
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 37
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 39
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 41
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 43
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 45
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# neuron number: 47
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 10
# neuron number: 49
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 9
# best purity baseline  0.6372287780738485
# best ari  baseline 0.16095147858542017
# best nmi  baseline0.06791047486314453
# best purity proposed 0.6969927674153026
# best ari proposed  0.3391970806185601
# best nmi proposed 0.20198662101592565
# all_purity_score_baseline mean 0.6372287780738485
# all_ari_score_ba seline mean 0.16095147858542017
# all_nmi_score_baseline mean 0.06791047486314453
# all_purity_score_tdsmsog mean 0.6765321659687856
# all_ari_score_tdsmsog mean 0.28920828946993976
# all_nmi_score_tdsmsog mean 0.16923668234872294
# Accuracy Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_purity_score_baseline  24.0  0.637229  0.000000  0.000000        NaN
# 1   all_purity_score_tdsmsog  24.0  0.676532  0.012020  0.002454   0.671457
# 2                   combined  48.0  0.656880  0.021566  0.003113   0.650618
#
#    Interval
# 0       NaN
# 1  0.681608
# 2  0.663143
#                                   Independent t-test  results
# 0  Difference (all_purity_score_baseline - all_pu...  -0.0393
# 1                              Degrees of freedom =   46.0000
# 2                                               t =  -16.0189
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -4.6243
# 7                                       Hedge's g =   -4.5485
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9209
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  24.0  0.160951  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  24.0  0.289208  0.023358  0.004768   0.279345
# 2                combined  48.0  0.225080  0.066835  0.009647   0.205673
#
#    Interval
# 0       NaN
# 1  0.299071
# 2  0.244487
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...  -0.1283
# 1                              Degrees of freedom =   46.0000
# 2                                               t =  -26.9003
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -7.7654
# 7                                       Hedge's g =   -7.6381
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9697
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  24.0  0.067910  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  24.0  0.169237  0.019141  0.003907   0.161154
# 2                combined  48.0  0.118574  0.052921  0.007639   0.103207
#
#    Interval
# 0       NaN
# 1  0.177319
# 2  0.133940
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...  -0.1013
# 1                              Degrees of freedom =   46.0000
# 2                                               t =  -25.9335
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -7.4863
# 7                                       Hedge's g =   -7.3636
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9675
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)
