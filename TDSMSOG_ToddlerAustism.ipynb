# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.drop(columns=['Case_No'])
csv = csv.sample(int(csv.shape[0]*1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv_training,csv_test,"Class/ASD Traits ")

# %%
import experiment
class_num= 2
dim_num = 17
scope_num = 50
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM !!!!!!!!!!!!!!
# neuron number: 2
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 4
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 6
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 8
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 10
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 12
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 3
# neuron number: 14
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 16
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 18
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 20
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 22
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 24
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 26
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 28
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 30
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 32
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 34
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 36
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 38
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 40
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 42
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 44
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 46
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 48
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 50
# SOG TDSM !!!!!!!!!!!!!!
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# best purity baseline  0.9493670886075949
# best ari  baseline 0.8036918707845225
# best nmi  baseline0.6851833115851254
# best purity proposed 0.9620253164556962
# best ari proposed  0.8511657994390565
# best nmi proposed 0.7507592617613859
# all_purity_score_baseline mean 0.949367088607595
# all_ari_score_ba seline mean 0.8036918707845225
# all_nmi_score_baseline mean 0.6851833115851254
# all_purity_score_tdsmsog mean 0.9408860759493671
# all_ari_score_tdsmsog mean 0.7695625696464878
# all_nmi_score_tdsmsog mean 0.6468253715074872
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  25.0  0.949367  1.133117e-16  2.266233e-17
# 1   all_purity_score_tdsmsog  25.0  0.940886  1.584176e-02  3.168352e-03
# 2                   combined  50.0  0.945127  1.188565e-02  1.680885e-03
#
#    95% Conf.  Interval
# 0   0.949367  0.949367
# 1   0.934347  0.947425
# 2   0.941749  0.948504
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  8.500000e-03
# 1                              Degrees of freedom =   4.800000e+01
# 2                                               t =   2.676800e+00
# 3                           Two side test p value =   1.010000e-02
# 4                          Difference < 0 p value =   9.949000e-01
# 5                          Difference > 0 p value =   5.100000e-03
# 6                                       Cohen's d =   7.571000e-01
# 7                                       Hedge's g =   7.452000e-01
# 8                                  Glass's delta1 =   7.484678e+13
# 9                                Point-Biserial r =   3.604000e-01
# ARI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_ari_score_baseline  25.0  0.803692  0.000000  0.000000        NaN
# 1   all_ari_score_tdsmsog  25.0  0.769563  0.055291  0.011058   0.746740
# 2                combined  50.0  0.786627  0.042361  0.005991   0.774588
#
#    Interval
# 0       NaN
# 1  0.792385
# 2  0.798666
#                                   Independent t-test  results
# 0  Difference (all_ari_score_baseline - all_ari_s...   0.0341
# 1                              Degrees of freedom =   48.0000
# 2                                               t =    3.0864
# 3                           Two side test p value =    0.0034
# 4                          Difference < 0 p value =    0.9983
# 5                          Difference > 0 p value =    0.0017
# 6                                       Cohen's d =    0.8730
# 7                                       Hedge's g =    0.8592
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.4069
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  25.0  0.685183  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  25.0  0.646825  0.063951  0.012790   0.620428
# 2                combined  50.0  0.666004  0.048770  0.006897   0.652144
#
#    Interval
# 0       NaN
# 1  0.673223
# 2  0.679865
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...   0.0384
# 1                              Degrees of freedom =   48.0000
# 2                                               t =    2.9990
# 3                           Two side test p value =    0.0043
# 4                          Difference < 0 p value =    0.9979
# 5                          Difference > 0 p value =    0.0021
# 6                                       Cohen's d =    0.8482
# 7                                       Hedge's g =    0.8349
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.3972
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#import experiment
#scope_num = 30
#topology_ratio =2
#
#
#experiment = experiment.Experiment()
#experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
class_num= 30
dim_num = 17
scope_num = 100
experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num,scope_num)
# Out:
#  NO Error Data, Finish Training!
# total split_number 1
# TDSM !!!!!!!!!!!!!!
#  self.test_score_W0_p 0.9354838709677419
# SOG TDSM !!!!!!!!!!!!!!
# neuron number: 30
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 32
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 34
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 36
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 38
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 40
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 42
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 44
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 46
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 48
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 50
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 52
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 54
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 56
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 58
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 60
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 62
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 64
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 66
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 68
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 70
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 72
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 74
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 2
# neuron number: 76
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 78
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 80
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 82
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 84
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 86
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 88
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 90
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 92
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 94
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 96
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 98
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# neuron number: 100
# ***************************SOG ************************
#  NO Error Data, Finish Training!
# total split_number 1
# all_purity_score_baseline mean 0.9354838709677418
# all_ari_score_baseline mean 0.675482093663912
# all_nmi_score_baseline mean 0.628088790013123
# all_purity_score_tdsmsog mean 0.9094982078853047
# all_ari_score_tdsmsog mean 0.642284146671447
# all_nmi_score_tdsmsog mean 0.5560496537864406
# Accuracy Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_purity_score_baseline  36.0  0.935484  1.125972e-16  1.876619e-17
# 1   all_purity_score_tdsmsog  36.0  0.909498  3.763441e-02  6.272401e-03
# 2                   combined  72.0  0.922491  2.948544e-02  3.474893e-03
#
#    95% Conf.  Interval
# 0   0.935484  0.935484
# 1   0.896765  0.922232
# 2   0.915562  0.929420
#                                   Independent t-test       results
# 0  Difference (all_purity_score_baseline - all_pu...  2.600000e-02
# 1                              Degrees of freedom =   7.000000e+01
# 2                                               t =   4.142900e+00
# 3                           Two side test p value =   1.000000e-04
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   9.765000e-01
# 7                                       Hedge's g =   9.660000e-01
# 8                                  Glass's delta1 =   2.307843e+14
# 9                                Point-Biserial r =   4.437000e-01
# ARI Score T-Test
#                  Variable     N      Mean            SD            SE  \
# 0  all_ari_score_baseline  36.0  0.675482  1.125972e-16  1.876619e-17
# 1   all_ari_score_tdsmsog  36.0  0.642284  1.310944e-01  2.184906e-02
# 2                combined  72.0  0.658883  9.354810e-02  1.102475e-02
#
#    95% Conf.  Interval
# 0   0.675482  0.675482
# 1   0.597928  0.686640
# 2   0.636900  0.680866
#                                   Independent t-test       results
# 0  Difference (all_ari_score_baseline - all_ari_s...  3.320000e-02
# 1                              Degrees of freedom =   7.000000e+01
# 2                                               t =   1.519400e+00
# 3                           Two side test p value =   1.332000e-01
# 4                          Difference < 0 p value =   9.334000e-01
# 5                          Difference > 0 p value =   6.660000e-02
# 6                                       Cohen's d =   3.581000e-01
# 7                                       Hedge's g =   3.543000e-01
# 8                                  Glass's delta1 =   2.948382e+14
# 9                                Point-Biserial r =   1.787000e-01
# NMI Score T-Test
#                  Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_nmi_score_baseline  36.0  0.628089  0.000000  0.000000        NaN
# 1   all_nmi_score_tdsmsog  36.0  0.556050  0.141765  0.023628   0.508083
# 2                combined  72.0  0.592069  0.105938  0.012485   0.567175
#
#    Interval
# 0       NaN
# 1  0.604016
# 2  0.616963
#                                   Independent t-test  results
# 0  Difference (all_nmi_score_baseline - all_nmi_s...   0.0720
# 1                              Degrees of freedom =   70.0000
# 2                                               t =    3.0490
# 3                           Two side test p value =    0.0032
# 4                          Difference < 0 p value =    0.9984
# 5                          Difference > 0 p value =    0.0016
# 6                                       Cohen's d =    0.7186
# 7                                       Hedge's g =    0.7109
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.3424
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
